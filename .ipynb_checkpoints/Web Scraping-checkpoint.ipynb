# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # SCRAPING THE WEBSITE FOR REVIEWS

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 10
page_size = 100

reviews = []

for i in range(1, pages + 1):

    print(f"Scraping page {i}")
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    response = requests.get(url)
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
    
    print(f"   ---> {len(reviews)} total reviews")
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified |  4 Hours before takeoff we r...
# 1  ✅ Trip Verified |  I recently had a delay on B...
# 2  Not Verified |  Boarded on time, but it took a...
# 3  ✅ Trip Verified |  5 days before the flight, w...
# 4  Not Verified |  \r\nWe traveled to Lisbon for ...

# %% [markdown]
# # CLEANING STRUCTURE OF DATA

# %%
df.reviews= df.reviews.str.split('|',expand=True)[1]

# %%
df
# Out:
#                                                reviews
# 0      4 Hours before takeoff we received a Mail st...
# 1      I recently had a delay on British Airways fr...
# 2      Boarded on time, but it took ages to get to ...
# 3      5 days before the flight, we were advised by...
# 4      \r\nWe traveled to Lisbon for our dream vaca...
# ..                                                 ...
# 995   Boarding was fairly quick, the well turned ou...
# 996    Bangalore to London. Ground experience not g...
# 997    Barcelona to New York via London. I was in B...
# 998    Gatwick to Fort Lauderdale. Charging to choo...
# 999    We recently flew from London to Bologna, the...
#
# [1000 rows x 1 columns]

# %%
import re
def clean(text):
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text
df['Cleaned Reviews'] = df['reviews'].apply(clean)
df.head()
# Out:
#                                              reviews
# 0    4 Hours before takeoff we received a Mail st...  \
# 1    I recently had a delay on British Airways fr...
# 2    Boarded on time, but it took ages to get to ...
# 3    5 days before the flight, we were advised by...
# 4    \r\nWe traveled to Lisbon for our dream vaca...
#
#                                      Cleaned Reviews
# 0   Hours before takeoff we received a Mail stati...
# 1   I recently had a delay on British Airways fro...
# 2   Boarded on time but it took ages to get to th...
# 3   days before the flight we were advised by BA ...
# 4   We traveled to Lisbon for our dream vacation ...

# %% [markdown]
# # IMPORTING REQUIRED LIBRARIES

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Rishitha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rishitha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rishitha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## CLEANING DATA USING NLP TECHNIQUES
# ### 1. POS TAGGING

# %%
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
          newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist 

df['POS tagged'] = df['Cleaned Reviews'].apply(token_stop_pos)
df.head()
# Out:
#                                              reviews
# 0    4 Hours before takeoff we received a Mail st...  \
# 1    I recently had a delay on British Airways fr...
# 2    Boarded on time, but it took ages to get to ...
# 3    5 days before the flight, we were advised by...
# 4    \r\nWe traveled to Lisbon for our dream vaca...
#
#                                      Cleaned Reviews
# 0   Hours before takeoff we received a Mail stati...  \
# 1   I recently had a delay on British Airways fro...
# 2   Boarded on time but it took ages to get to th...
# 3   days before the flight we were advised by BA ...
# 4   We traveled to Lisbon for our dream vacation ...
#
#                                           POS tagged
# 0  [(Hours, n), (takeoff, n), (received, v), (Mai...
# 1  [(recently, r), (delay, n), (British, a), (Air...
# 2  [(Boarded, v), (time, n), (took, v), (ages, n)...
# 3  [(days, n), (flight, n), (advised, v), (BA, n)...
# 4  [(traveled, v), (Lisbon, n), (dream, n), (vaca...

# %% [markdown]
# ### 2. LEMMATIZATION

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
     if not pos:
        lemma = word
        lemma_rew = lemma_rew + " " + lemma
     else:
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

df['Lemma'] = df['POS tagged'].apply(lemmatize)
df.head()
# Out:
#                                              reviews
# 0    4 Hours before takeoff we received a Mail st...  \
# 1    I recently had a delay on British Airways fr...
# 2    Boarded on time, but it took ages to get to ...
# 3    5 days before the flight, we were advised by...
# 4    \r\nWe traveled to Lisbon for our dream vaca...
#
#                                      Cleaned Reviews
# 0   Hours before takeoff we received a Mail stati...  \
# 1   I recently had a delay on British Airways fro...
# 2   Boarded on time but it took ages to get to th...
# 3   days before the flight we were advised by BA ...
# 4   We traveled to Lisbon for our dream vacation ...
#
#                                           POS tagged
# 0  [(Hours, n), (takeoff, n), (received, v), (Mai...  \
# 1  [(recently, r), (delay, n), (British, a), (Air...
# 2  [(Boarded, v), (time, n), (took, v), (ages, n)...
# 3  [(days, n), (flight, n), (advised, v), (BA, n)...
# 4  [(traveled, v), (Lisbon, n), (dream, n), (vaca...
#
#                                                Lemma
# 0    Hours takeoff receive Mail state cryptic mes...
# 1    recently delay British Airways BRU LHR due s...
# 2    Boarded time take age get runway due congest...
# 3    day flight advise BA cancel ask us rebook fl...
# 4    travel Lisbon dream vacation cruise Portugal...

# %%
df[['reviews','Lemma']]
# Out:
#                                                reviews
# 0      4 Hours before takeoff we received a Mail st...  \
# 1      I recently had a delay on British Airways fr...
# 2      Boarded on time, but it took ages to get to ...
# 3      5 days before the flight, we were advised by...
# 4      \r\nWe traveled to Lisbon for our dream vaca...
# ..                                                 ...
# 995   Boarding was fairly quick, the well turned ou...
# 996    Bangalore to London. Ground experience not g...
# 997    Barcelona to New York via London. I was in B...
# 998    Gatwick to Fort Lauderdale. Charging to choo...
# 999    We recently flew from London to Bologna, the...
#
#                                                  Lemma
# 0      Hours takeoff receive Mail state cryptic mes...
# 1      recently delay British Airways BRU LHR due s...
# 2      Boarded time take age get runway due congest...
# 3      day flight advise BA cancel ask us rebook fl...
# 4      travel Lisbon dream vacation cruise Portugal...
# ..                                                 ...
# 995    Boarding fairly quick well turn staff quickl...
# 996    Bangalore London Ground experience great LHR...
# 997    Barcelona New York via London Barcelona four...
# 998    Gatwick Fort Lauderdale Charging choose seat...
# 999    recently fly London Bologna aircraft full re...
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## GETTING SENTIMENT OF THE CLEANED REVIEWS

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

df['Sentiment'] = df['Lemma'].apply(vadersentimentanalysis)

def vader_analysis(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound < 0 :
        return 'Negative'
    else:
        return 'Neutral'
df['Analysis'] = df['Sentiment'].apply(vader_analysis)
df.head()
# Out:
#                                              reviews
# 0    4 Hours before takeoff we received a Mail st...  \
# 1    I recently had a delay on British Airways fr...
# 2    Boarded on time, but it took ages to get to ...
# 3    5 days before the flight, we were advised by...
# 4    \r\nWe traveled to Lisbon for our dream vaca...
#
#                                      Cleaned Reviews
# 0   Hours before takeoff we received a Mail stati...  \
# 1   I recently had a delay on British Airways fro...
# 2   Boarded on time but it took ages to get to th...
# 3   days before the flight we were advised by BA ...
# 4   We traveled to Lisbon for our dream vacation ...
#
#                                           POS tagged
# 0  [(Hours, n), (takeoff, n), (received, v), (Mai...  \
# 1  [(recently, r), (delay, n), (British, a), (Air...
# 2  [(Boarded, v), (time, n), (took, v), (ages, n)...
# 3  [(days, n), (flight, n), (advised, v), (BA, n)...
# 4  [(traveled, v), (Lisbon, n), (dream, n), (vaca...
#
#                                                Lemma  Sentiment  Analysis
# 0    Hours takeoff receive Mail state cryptic mes...    -0.8046  Negative
# 1    recently delay British Airways BRU LHR due s...    -0.7165  Negative
# 2    Boarded time take age get runway due congest...     0.4404   Neutral
# 3    day flight advise BA cancel ask us rebook fl...    -0.3167  Negative
# 4    travel Lisbon dream vacation cruise Portugal...     0.8020  Positive

# %% [markdown]
# ## OUTPUT VISUALISATION

# %%
vader_counts = df['Analysis'].value_counts()
vader_counts
# Out:
# Analysis
# Positive    479
# Negative    413
# Neutral     108
# Name: count, dtype: int64

# %% [markdown]
# ### 1. PIE - CHART

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,7))

plt.subplot(1,3,2)
plt.title("Reviews Analysis")
plt.pie(vader_counts.values, labels = vader_counts.index,explode = (0,0,0.25), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1eddc894a30>,
#   <matplotlib.patches.Wedge at 0x1eddc80faf0>,
#   <matplotlib.patches.Wedge at 0x1eddc895720>],
#  [Text(0.07251815034740818, 1.0976069960920398, 'Positive'),
#   Text(-0.4336890225212467, -1.0108975377082317, 'Negative'),
#   Text(1.2730371984675077, -0.44930645590509777, 'Neutral')],
#  [Text(0.039555354734949914, 0.5986947251411125, '47.9%'),
#   Text(-0.2365576486479527, -0.5513986569317627, '41.3%'),
#   Text(0.8015419397758381, -0.2828966574217282, '10.8%')])

# %% [markdown]
# ### 2. WORDCLOUD

# %%
df.to_csv("BA_reviews.csv")

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

def show_wordcloud(data):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=100,
        max_font_size=30,
        scale=3,
        random_state=1)
    wordcloud=wordcloud.generate(str(data))
    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    plt.imshow(wordcloud)
    plt.show()
show_wordcloud(df.Lemma)

# %%
# Filter the DataFrame to include only 'Negative' sentiment reviews
negative_reviews_df = df[df['Analysis'] == 'Negative']

# Tokenize and process the words in negative reviews
negative_words = []
for index, row in negative_reviews_df.iterrows():
    tokens = word_tokenize(row['Lemma'])
    for token in tokens:
        negative_words.append(token.lower())  # Convert to lowercase for consistency

# Analyze the frequency of each word
negative_word_freq = nltk.FreqDist(negative_words)

# Display the top 10 negative words
top_negative_words = negative_word_freq.most_common(10)
print("Top 10 Negative Words:")
for word, freq in top_negative_words:
    print(f"{word}: {freq}")

# You can also visualize the word frequencies using a bar plot
plt.figure(figsize=(10, 6))
negative_word_freq.plot(30, cumulative=False)
plt.title('Top 30 Negative Words')
plt.show()
# Out:
# Top 10 Negative Words:
# flight: 929
# ba: 510
# seat: 341
# hour: 304
# service: 288
# get: 283
# london: 240
# time: 219
# fly: 206
# us: 195

# %%
import nltk
#nltk.download('vaderSentiment')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Define the negative words list
negative_words = ['bad', 'poor', 'terrible', 'awful', 'horrible', 'disappointed', 'unsatisfied', 'unhappy', 'frustrated', 'angry', 'disgusted']

# Create a function to identify negative words in a review
def identify_negative_words(review):
    negative_words_found = []
    for word in review.lower().split():
        if word in negative_words:
            negative_words_found.append(word)
    return negative_words_found

# Analyze the sentiment of each review and identify negative words
analyzer = SentimentIntensityAnalyzer()
for review in reviews:
    sentiment = analyzer.polarity_scores(review)
    if sentiment['compound'] < 0:
        negative_words_found = identify_negative_words(review)
        print(f"Review: {review}")
        print(f"Negative words found: {negative_words_found}")
# Out:
# Review: ✅ Trip Verified |  4 Hours before takeoff we received a Mail stating a cryptic message that there are disruptions to be expected as there is a limit on how many planes can leave at the same time. So did the capacity of the Heathrow Airport really hit British Airways by surprise, 4h before departure? Anyhow - we took the one hour delay so what - but then we have been forced to check in our Hand luggage. I travel only with hand luggage to avoid waiting for the ultra slow processing of the checked in luggage. Overall 2h later at home than planed, with really no reason, just due to incompetent people. Service level far worse then Ryanair and triple the price. Really never again. Thanks for nothing.
# Negative words found: []
# Review: ✅ Trip Verified |  I recently had a delay on British Airways from BRU to LHR that was due to staff shortages. They announced that there was a 2 hour holding delay but they would board us immediately in hopes of clearing the gate and leaving early. We had to wait the full 2 hours inside the airplane. The plane was old, dirty, had no power at the seats. The staff provided a small bag of pretzels and 250ml of water to the passengers for 2 hour delay and 2 hour flight. There were no options to purchase food or drink. There were no entertainment options available. I am a OneWorld emerald elite member but they do not upgrade members based on status. First class lounges at Heathrow are overcrowded, understaffed and poorly equipped. The help desk is completely unhelpful when an error arises with delays and cancellations - even when having the top status. The Avios points system has been devalued to near worthlessness and requires fees to book reward that nearly equal the price of the revenue ticket. British has lost its way in recent years and has a moved from a world-class airline to a budget airline with much worse service and timeliness than Ryanair or EasyJet.
# Negative words found: []
# Review: ✅ Trip Verified |  5 days before the flight, we were advised by BA that it had been cancelled and asked us to rebook. There were flights 1 hour before and 1 hour after our original flight but they made us take one 3 hours earlier. Our original ticket (and the return flight a week later) included a checked bag. When we arrive at Heathrow to check in we are told our ticket doesn't included a bag and we will have to pay 75 pounds each to take them. We explained that the original ticket had the bags and when they checked the system they confirmed that it did- but not this one! They would make no effort to sort it out and just told us to pay up or they would remove us from the flight. So we had no choice but to pay up, thinking it should be pretty easy to get a refund. 15 months and 10 emails later we have still not seen a penny. Every time I ask where my refund is and state how long we have been waiting I get an inane email saying some departments take longer than others to respond!  Absolutely hopeless airline to stuff up the booking in the first place and even worse customer service to not even attempt to solve the problem at check in even when they could see the mistake THEY had made in their system, compounded by being be unable to investigate a very simple claim, and refund me 150 pounds in 15 months.
# Negative words found: []
# Review: ✅ Trip Verified |  Booked a flight from Bucharest to Manchester with a 2h 45’ layover at Heathrow. Flight was delayed from Bucharest because of ATC strike. Arrived at Heathrow 40 minutes later than scheduled and still had enough time to catch my connecting flight. Unfortunately we were stranded in the plane and waited a very long time to disembark the plane due to lack of staff or slot shortage (it’s a common problem with BA at Heathrow). I missed my connecting flight because of their delays and they told me I had to wait all night in a freezing airport for the first flight the next day. There was just a shameful 10£ food voucher which is a joke considering the ridiculous prices at LHR. No accommodation offered and had to sleep in a very cold airport. I asked for compensation and they sent me a long text with the same lame excuses that they are sorry, but they will not compensate anything.  I can’t imagine a worst airline than BA regarding customer care. It is not about money here but rather than the way they treat customers. It is the last time in my lifetime that I will be flying this joke of an airline.
# Negative words found: []
# Review: ✅ Trip Verified |  Booked online months ago and the only hitch was replacement aircraft meaning chosen seats were different. I was informed of this prior to departure so could amend. Bag drop at MAN T3 wasn't smooth but I suspect that was MAN fault. Shuttle boarding was slow and delayed meaning a rush at LHR T5. The flight to CPT was full but we left more or less on time. The cabin was clean and PE was what we expected, sufficient leg and arm room plus a few little perks with drinks. Only complaint is the seats actually recline too far. Staff were very good during the first few hours of service, especially George. Food was quite tasty but one option wasn't loaded. Breakfast was also quite tasty and we landed on time. The fly in the ointment is both our cases arrived late on the carousel and only later did we notice both had been broken into, likely at CPT. All in all a pleasant surprise.
# Negative words found: []
# Review: ✅ Trip Verified |  As an infrequent flyer, British Airways was always my first choice. With some reassurance and comfort of service, quality, luggage allowance etc. In fact I’ve never flown with the budget airlines. My most recent flight has now changed my view and causes me to reflect on what am I actually getting for my money and is BA what they once were. While the flights were around an hour delayed both ways, the cabin and ground staff service were ok. It is the facilities (or lack of) that I am most disappointed by. The flight was Approx 4 and a half hours and the only thing offered was a half cup of water that was poured out and a bite sized banana slice of cake. In fact on my return journey I wasn’t even offered the water! To top it off BA no longer have a media screen from which you can select something to pass the time away. There wasn’t even the obligatory flight journey. The WiFi was poor. I couldn’t even access the shop. However, for a fee so much more was available. This explains BAs record profit of £1.52bn. So, the question is, what am I paying for? I will now for sure opt for the budget airlines. They are transparent with what they offer and what you have to pay for, which I can decide to choose or not. As BA now stands for Basic Airways I’ll go elsewhere and get basic for cheaper.
# Negative words found: ['disappointed']
# Review: Not Verified |  A totally unremarkable flight, on time, as comfortable as European configuration goes. No catering due to the storm - effect greatly exaggerated. This was advised by email, and a euro 15 was provided - not easy to use - but lounge made up for this loss.
# Negative words found: []
# Review: ✅ Trip Verified |   1. Ground crew in Heathrow left 60 passengers luggage. We had 3 bags. 2. The Heathrow ground crew left 1 of ours behind after the 1st two were received the next day. 3. The Heathrow ground crew lost our 3rd bag 4 times and we were on the phone with them for over 3 hrs over the course of the week! 4. Due to this, we had to spend $500 on health and beauty items for my wife on our cruise. 5. British Airways said they MIGHT reimburse after 3 months. 6. We had to spend $100 in cab fare to Barcelona because the Bacelona ground crew (Iberia) claimed they had delivered it to us. 7. Heathrow ground crew made us 15 minutes late arriving back into Heathrow after our cruise. We actually landed 10 minutes early, but those incompetent people still were not ready for us. 8. The Heathrow ground crew caused us to leave 45 minutes late even though ALL passengers were boarded and ready 15 minutes before the departure time. This will probably mean we will miss our connection in Anchorage. BA clearly does not care or know how to operate a ground base...shameful. BA is a joke and should be embarrassed they can't operate like a normal airline. They do not grasp the concept that even a small hiccup can cause mass ripples of chaos to other people.
# Negative words found: []
# Review: ✅ Trip Verified |  London Heathrow to Gibraltar on 24th October 2023. I shall start by reference to the booking process. I used the BA website to reserve the seat and food the website to be easy to use and clear in every aspect. The flight was due to depart from terminal 3 but the passengers were bussed for a good 15 minutes to a different part of the airport where the aircraft was on a stand. When boarding the flight the cabin-crew kept a very low profile and this was maintained during the entire flight. The captain made 3 brief announcements during the flight. There was no in-flight entertainment. The seats were clean and comfortable enough for a short flight. The lack of catering was overt. Other than a tiny bottle of water and an inedible “breakfast bar” one had to use an online system to order even a drink and of course pay for it too. The passengers next to me could not use the online system as it doe not seem to work and the cabin refused to sell them a coffee because of this fault. Moreover, the USB charge points did not work either. Given the early hour of the flight it is a poor show that there are not even for sale items available from a trolley service. The system BA have in place is not good enough. The flight arrived on-time. The disembarkation was inefficient though and poorly managed and the crew were not to be seen. The crew were wearing the new BA uniform and it seems to reflect a downward trend of the airline. To be candid, there was any difference between this BA service and that of so-called “budget” rivals. On this route BA have a monopoly and so I did not have an option to use the services of a different company.
# Negative words found: ['poor']
# Review: Not Verified |  Absolutely the worst experience ever.  Flew into Heathrow, no problem. Waited for 5 hours, three extra hours, for our connection to Porto then the cancelled the flight. Scrambled for a hotel and a new flight the next day. They routed us through Madrid the next morning. That flight was 1.5 hours late so we missed our connection to Porto. Because we missed the connection (their fault), they cancelled our return flights. After two hours on the phone with customer service from the Madrid airport, they booked us a new return flight, then they made is pay $ 1300 to fly from Madrid to Porto. Then, for no reason they cancelled our return flight again! After hours, and hours and hours with customer service, we finally got a return flight five days after our original return flight. Meanwhile, they lost my wife's luggage. We finally got 15 DAYS after they lost it. Return flight? More problems with our reservations. At no point was British Airways helpful. They left the onus on us to fix their mistakes at every turn. They completely ruined a three week vacation and they don't care. They wouldn't even let us speak to a supervisor or manager. Awful, bordering on passenger abuse.
# Negative words found: []
# Review: ✅ Trip Verified |   I flew from Istanbul to London in Business class. For more than half of the flight a child was watching an iPad very loud with no phones plugged in - it was three rows in front of me and disrupted my flight as I could hear it above my headphones. Staff thought this was fine and refused to tell the mom to turn it down. Why is this acceptable on a flight especially in business class? Has this airline turned into a zoo? Are staff given no training in customer service? Why is a child allowed to disrupt other passengers? When I told the staff she just laughed at me. BA customer service is a disgrace. I've not even mentioned the food but it was bad, really bad.
# Negative words found: []
# Review: ✅ Trip Verified |   The flight departed over an hour late due to a late inbound plane. The plane was very full, and half of the economy class passengers were forced to check in their larger cabin baggage at the gate when boarding, making a complete mockery of the hand luggage allowance advertised. Lots of passengers on board were stressed out about missing onwards connections due to the delays (and some did miss them as their next gates had closed by the time we disembarked at Heathrow). Onboard service was ok but minimal  - BA gave up being a full-service airline some time ago. More concerning is that trying to get hold of customers services to make changes to bookings and deal with problems was non-existent. The airline seems to make it deliberately hard for its customers to contact it.
# Negative words found: []
# Review: ✅ Trip Verified |   I hate British Airways! We get to London on Oct 3 and our next flight is cancelled. We stand in line with 1200 other people to get it fixed and they tell everyone to leave the airport and call them to fix. They book us the next day..via online. Don't offer vouchers for hotel, we will miss our tour. Now trying to get home from Istanbul. Plane is here but should have started loading an hour ago. No explanations. May miss next flight. Will never travel with them again. Was this same problem April 2022 flight.
# Negative words found: []
# Review: ✅ Trip Verified |   Our BA flight from Porto to London Heathrow T5 was operated by Finnair using a Finnair plane and crew. This had been advised by BA shortly after booking, with the option to change flights if we preferred. Although the business class cabin was of a similar layout to BA Club Europe, i.e. with the middle seat kept free, my wife and I felt the seats were more comfortable and the legroom slightly better. Service was good on board and the meal was very tasty (we chose the beef cheeks). All was good until we landed at Heathrow! Although we passed through passport control without delay, once we were at the designated baggage reclaim, we just waited and waited! After an hour and ten minutes I went to the BA baggage counter to ask what was going on. They seemed unaware of an issue, but said they would find out! Over the next hour or so various other passengers also requested information and despite various announcements and a list of different excuses it was almost 2½ hours before the bags finally arrived. Frustrating to say the least. I subsequently complained to BA, but after 4 weeks there has been no explanation just the automated message from customer services ‘we are experiencing exceptionally high volumes’. This response says a lot!
# Negative words found: []
# Review: ✅ Trip Verified | The customer services (call centres etc) are atrocious and sometimes callous. They just don’t care. Long waits to speak to anybody, who then have no power to actually solve anything, and the calls just cut halfway without resolution anyway. If the flights are cancelled (as were my original ones) you’re really left on your own and nobody cares. The onboard services are so-so but for short haul it’s now “semi-low cost” which is confusing as you never know what to expect. This time we were given a bottle of water and a (very) small snack, whilst anything else had to be paid for. And yet on some other flights apparently you have to pre-order any additional food. It’s confusing, which makes it not dependable. Cabin baggage is in theory generous compared to competitors in economy but then they asked more than half the passengers on this flight to check in the cabin baggage at the gate due to lack of space in the overhead cabins, leading to long boarding delays. Their whole offering hasn’t been thought through very well . The USB power supply did not work throughout the flight (contrary to the announcement that the power be available after the seatbelt sight was turned off ) so it was pointless providing the sockets in the first place. Not my first choice airline on this route and am just trying to use up most of my Avios points before I totally abandon them. I fail to see how it is deemed a 4 star airline.
# Negative words found: []
# Review: Not Verified |  Flew with BA to Punta Cana. Took the trouble to reserve seats for both outbound and inbound flights. On boarding at Gatwick, realised we had been moved to much less good seats with other people sitting in the seats we had spent a lot of money reserving. Apparently there has been a change of aircraft and a number of passengers had been automatically reallocated seats for no particular reason. The crew said there was nothing they could do (although of course they could just have swapped us with the couple using our seats). We were told to claim a refund on return home. We did this via a complaint form Ns BA offered us £100 in vouchers. We didn't accept this as it was less than the cost of the seats and also naturally we wanted our money back. We eventually got it but not without a fight. Very second rate shoddy airline.
# Negative words found: []
# Review: ✅ Trip Verified |   They downgraded me from business to premium economy. They took three months to get back to me and offered me 200 pounds or 400 AUD. The difference between business class and premium economy (which I never fly) is $3000 AUD and the difference between economy and business is $6500 AUD. They owe me at least 1500 pounds and to be very fair 3250 pounds. The downgrade was insulting and incredibly painful as I had a recent cancer operation and have a back injury which I have pointed out to them - I need to lie down. The wait for them to get around to me has been numbing. The insult of their offer has been the slap in the face to continue my degradation. The people I have dealt with at the airport have been down to earth, honest hard working people. The actual staff on the plane were warm and friendly - and helpful. The systems under which BA operates are some sort of medieval torture.
# Negative words found: []
# Review: ✅ Trip Verified |   The already delayed aircraft landed and apart from the small BA logo on the rear of the fuselage, there was no indication as to whom the carrier really was. Boarding turned into a farce with passenger groups being told to wait in one queue in order to board, only to be informed we were on the wrong place and our boarding wasn't allowed yet. The interior cabin was reminiscent of a BA cabin from twenty years earlier except the tight legroom and uncomfortable seating which made a budget airline feel luxurious. The crew were not BA but from an unknown charter company. Service was slow, and as usual, choices of food to purchase ran out before they'd reached row 24. I requested a cup of tea which never appeared. Thank goodness for my airport purchased water and the tiny offering of pretzels. The over officious senior flight attendant, who'd been facilitating in 'Club Europe' appeared in economy and immediately slammed down the armrests (whilst still in mid flight) making an already uncomfortable journey feel worse. "Cattle class" was definitely that! To say I was happy to land and disembark was an understatement. Never again BA, never again!
# Negative words found: []
# Review: ✅ Trip Verified |   BA has a real problem with boarding it's flights. Those who get on first fill the luggage bins with 2 bags, one of which is supposed to be small and under seat only. Cabin staff don't bother implementing their own rules. Subsequent passengers mill up and down the aisle, bumping into each other, searching for space. Boarding this flight took an hour as a result of this nonsense. The incoming flight was late already so our 90 minute flight was 90 minutes late.
# Negative words found: []
# Review: ✅ Trip Verified | Our connecting flight from London to Glasgow was canceled and we were forced to wait 12 hours in the airport for a new flight. When we received our luggage at Glasgow we discovered that our luggage was soaking wet. My wife’s luggage contents were wet and had to be air dried.
# Negative words found: []
# Review: ✅ Trip Verified |   The worst airline I have ever flown with. Allocated the very back row next to the toilets and galley. No chance of getting any sleep, question asked of possible seat movement ignored and getting bumped the entire time by cabin crew walking or pushing kart up and down aisle without one apology. Would have been better sitting in the luggage compartment.
# Negative words found: []
# Review: ✅ Trip Verified |  BA standards continue to decline every time I fly with them. This time, a 45 min late departure, which seems the norm for BA, and no information from the rude and clueless boarding gate staff. The Club lounge was overcrowded, dirty and grubby and cleaning staff could not cope. How many more cutbacks is BA going to apply before they become truly low cost. As a 35 year veteran user of BA, while people complained of Alex Cruz cutting costs, the past 3 years has seen them decline very quickly under their latest CEO. One reads the occasional article about BA improving things, but I have yet to see anything substantive. There seem to be few British staff left amongst the cabin crew, so maybe time for a name change and give the flag carrier status to a proper low-cost - and sadly the staff service has declined year on year. Onboard, the catering remains poor and surprised that Do&Co can produce such rubbish meals when I have sampled their Turkish Airlines equivalent in August that was superb - guessing BA are too tight with their budget. Onboard WiFi service is a joke and should be avoided.
# Negative words found: ['poor']
# Review: Not Verified |  Awful. Business class check in queue just as long as for economy, probably because half of the desks were not staffed and Terminal 5 is chaotic. Business lounge overfull, couldn't get seats. Delayed flight, unmanaged chaos at the gate. No drink on boarding, first drink served an hour after take-off. The meal was poor, used to get better in economy on other airlines. British Airways has won the race to the bottom of the cheapskate stakes. Not looking forward to the flight home.
# Negative words found: []
# Review: ✅ Trip Verified |  Not a reliable airline. You cannot trust the timing at all. I had a 6.45am flight, boarding was on time, but then we are sitting in the plane for already (1.5 hours) and the expected departure is still not clear. They have discovered the engine is not working! I am risking to be late for a business meeting in Geneva. How come they bring a not working plane to the gate. The funny thing is that I had another business trip in spring 2023, also with BA to Amsterdam. When I arrived to the Airport that time - I was told I don't have a seat. I was put on the next flight in several hours, which should have get me to the business meeting late, but still not too much. A lot of stress. In the end, on the second plane we were sitting in the cabin for 1.5 hours and I have missed the meeting. I thought it was a dramatic unlucky case that time, but today I see it's routine for BA not to fly on time.
# Negative words found: []
# Review: ✅ Trip Verified |  I take comfort in reading the last ten or so reviews to see I'm not the only traveller to put in words, how absolutely abysmal British Airways are! The only reason we are stuck using this awful airline is to use up points. We booked Club Europe months ago. London to Athens, sat in row 3 and told they had run out of food options, only choice was lentil pie or green curry. Returning Athens to London Club Europe. Couldn't check in online as promised so arrived at the airport 3hrs early. To be told they had overbooked the flight and basically we were being 'bumped' to economy. This airline fails to deliver time and time again. It is a national disgrace and I implore everyone to choose an alternative.
# Negative words found: ['awful']
# Review: ✅ Trip Verified |  The worst journey in my life. The connection time at LHR was only 1 hour, but the flight from MXP was on delay. I had to rush to change terminal by train and arrived risking a heart attack. After that the plane just stayed there for another 40 minutes. Despite that, upon arrival at SJC my baggage was lost. I filled the form and gave to the employee. I was not given any receipt, so I did not have any reference number. BA phone number at SJC simply never answer. I called twice the toll free number and realized they did not record the delivery address. I had to enter myself online, dealing with a shitty website. They delivered the baggage three days later. I claimed for compensation online, as I had to buy clothes and other stuff and I did never get a receipt. I was expecting an upgrade for the flight back to MXP, but nothing happened, neither they allowed me to enter BA lounge at SJC. Bad customer service. The only positive side was price, but obviously this cannot justify this treatment and if I knew , I would never flown by BA. Never again!
# Negative words found: ['bad']
# Review: ✅ Trip Verified | The airplanes and the lounges are worn out, old and broken. From Dallas to Heathrow, multiple first class seating and electronics were non functional and poorly designed. The first class seating from Heathrow to Dubrovnik was nothing more than a tray blocking the middle seat of a standard coach ticket. Very disappointed.
# Negative words found: []
# Review: ✅ Trip Verified | One of the worst experiences on the worst airline. The flight was delayed due to earlier technical issues. The time slipped from 17:00 to 20:00 to 22:00 and finally cancelled. There was zero information given. Despite paying well over the odds for business class, we were booted out of the BA lounge two hours before the flight. When it was finally cancelled, the BA staff. Without explanation, told everyone to go to a gate. After another hour or so they made us re enter the UK via passport control, a further 40 minute wait. By now the airport was closing and there was no sign of our bags or any help from BA. A passing Gatwick engineer finally helped us locate the bags. BA completely washed their hands of us and in contravention of CAA rules refused to find us accommodation. Many slept in a bus stop overnight. There were people with young children who couldn’t find somewhere to stay and yet BA had closed down and left. The following day the replacement flight was also late and due to an admin mistake had no catering or liquids for a 2 1/2 hr flight. Overall the service was shockingly bad, the worst I have experienced from any airline. I will not ever use them again.
# Negative words found: []
# Review: ✅ Trip Verified | I had a flight from Miami, Florida to Dublin, Ireland, via London's Heathrow airport. The outbound flight from Miami was delayed and we were further delayed when our gate was occupied when we arrived in Heathrow. The total delay was roughly an hour, but it was enough to make our connection a challenge, where we had 73 minutes between original arrival time until the departure time to Dublin. When we headed to our connection flight, we were stopped by security personnel at a checkpoint and told us that the gate to our connection flight had already closed. This was twenty minutes prior to departure time. They ushered us to customer service to be rebooked. Given the busy weekend of travel, we were rebooked on a flight at a different airport and were told that our cost to get there would be reimbursed. We then waited 3 hours for our luggage, and then took a cab to London's City Airport. The cab fare was roughly $500. When I filed a claim with British Airways, they refused the claim and told me that we had plenty of time to make our connecting flight and therefore they denied my claim to be reimbursed for the cab fare. This is after I explained that it was British Airways employees who ushered us to rebook the flight despite the 20 minute timeframe to make the connecting flight. The person who rebooked us, told us it was policy that they close the gate 20 minutes prior to departure. I will never fly this awful airline again. Given the other feedback on this site, it appears that that is the overwhelming sentiment.
# Negative words found: ['awful']
# Review: ✅ Trip Verified |  We started our day with BA in Prague. The flight actually left on time! I came to find out that’s very unusual. We purchased business class seats. As you can see from the picture they hardly were business class. All they did was block off the middle seat in the first few rows and called it business class. Horrible flight. In addition I had a really rude rude check in clerk basically yell at me when I excused myself and asked if she could give a little bit of priority to the many business class passengers who weren’t being served. Then we got to Heathrow and the real fun began. We had a 4 hour delay. They gave us about 5 different excuses for the delay. I had a few employees walk away while I was asking them questions. They were very rude. At one point there were no employees left. And from the announcements it seems virtually every BA flight was delayed. And there were no weather issues. There was no place to comfortably store items in business class. I’ve never experienced that before. Not even a cup holder for my bottle of water. The seat controls didn’t work well. You had to keep pushing the buttons to get them to do anything. The power outlet didn’t work. There was no internet the entire flight. The overhead luggage bin was too heavy. I almost got a hernia having to close it. This is a horrible airline. I’ll never fly with them again. If I could give zero stars I would.
# Negative words found: ['horrible', 'horrible']
# Review: ✅ Trip Verified |  I fly British Airways weekly not because I want to but because they own the route there’s no other option therefore they frankly don’t have to care about the customer. The flights are always delayed and it’s always someone else’s fault be it weather delays to incoming aircraft or flight traffic control issues I’ve heard it all and for the life of me cannot understand why they are allowed to operate. I’ve been around the world and traveled with all of the world’s airlines but British Airways are really the worst of the worst. It’s such a shame to have watched what used to be a good company fall down a cliff. My advice is if you have an option to fly with anyone else then exercise the option but if you’re flying with different connections and you have a tight schedule do not expect BA to get you to your destination in time.
# Negative words found: []
# Review: Not Verified |  Everything was ok until our connecting flight in London, just before take off, we were on the runway, the pilot came on to announce an engine problem. After engineers tried to fix it while we waited on the plane for over an hour we were finally told that we would have to be evacuated and rebooked for another flight but not to worry because a special crew was waiting for us on the ground to help us and set us up in a hotel except that there was no one to help us. In fact everyone refused to help us. It was Saturday almost 8pm and they just wanted to go home. Anyone with a connecting flight couldn't rebook on the application because the app wouldn't disassociate our first flight with the connecting one in London and the staff saw this but still refused to help us. They gave us a phone number but there was only a message that said just to use the app. Finally I got someone on the phone who rebooked us for the next day. Now it's 10:30pm and I have to find a hotel room because the airline refused also to help us with that. So i had 2 choices either sleep in the airport or pay over 700GBP for a room. I don't have the money to pay for this but after a 10 hour flight, 8 hours of jet lag and the insane stress after the fact that no one from British Airways would help us I took the room. Of course I claimed reimbursement but that was over 3 weeks ago and I haven't heard anything since so I have no idea when or how much I'll be reimbursed, even though I'm not claiming any emotional compensation from the horrible situation they put me through due to their total indifference. It's financially difficult for me right now because the money I had to put out is equal to half my salary and of course it's impossible to reach them by phone. I feel still as i did on August 26 2023 completely trapped by them and their indifference with no solution or information
# Negative words found: ['horrible']
# Review: Not Verified |  My initial flight was cancelled 8 hours prior the flight. Then I was automatically rescheduled for next day. Next day, the flight was delayed leaving Hamburg and missed my connecting flight to Las Vegas. Me and several other passengers spent the night in London. British Airways provided us with vouchers but the transfer bus dropped us at the wrong hotel (closest to our hotel) and told us that we can walk there if we want to. As a result, I lost two nights hotel reservations that I made in las Vegas. I opened a claim and provided all receipts to British Airways to get refund of my hotel reservations, but over 5 weeks now, not a single feedback from British Airways. I will avoid all flights with them in future, and will share this story.
# Negative words found: []
# Review: Not Verified |  We will never fly British Airways again. Our flight on July 15 2023 from LHR to LAX was cancelled 20 hours before departure without any explanation. Since 8 weeks we are now waiting for the refund and BA does not pay us the cost caused by the cancellation. Very disappointing.
# Negative words found: []
# Review: Not Verified |  British Airways has confirmed itself as the worst airline in the UK. Last minute cancellation, no explanation, refusal to book with another airline “because we don’t have an arrangement with them”. What’s happened to what used to be our national airline?
# Negative words found: []
# Review: ✅ Trip Verified | Worst BA experience. I was supposed to fly out to Italy on 7 September 2023. I arrived at OR Tambo International airport ready to check my bags in (I already checked-in online the previous evening so I had my boarding pass ready). At the counter I was told that I had been off-loaded from the flight as my connecting flight has been cancelled. No information was sent regarding this beforehand. The team at the check-in counter tried to get me on another flight that evening, but there were no flights available. They did manage to get me another flight the following evening with Lufthansa to Italy via Frankfurt. However, I did miss the first part of my trip having arrived a day and a half later than I was supposed to. Upon moving the flights I did ask the BA staff whether my flights back are still valid and that everything is in order, which they assured me is correct. I have to fly back to South Africa on 18 September and upon checking my booking information I noticed on my BA account that my first flight (Milan to London) is just missing from my booking. My connecting from London to Johannesburg is still there. After spending the entire morning on the customer helpline two different operators picked up and in both instances, the moment I proceed to give my booking reference number, my call gets dropped. Currently it seems like I will be arriving at the airport again on Monday without a flight.
# Negative words found: []
# Review: ✅ Trip Verified |  My daughter and I were denied boarding on our business class flight from Madrid to Heathrow in March 25, 2023, the first leg on our return flight to Victoria, Canada. No reason was given for the denied boarding by the check in staff at the British Airways counter in Madrid, who said they were only agents and told us to call British Airways. We were three hours early for the flight and had valid passports. After many tries we finally reached British Airways by phone, but we were told to call Expedia which had booked the flights. Expedia confirmed that we had been bumped from the flight, with no explanation as to why. Expedia then began a long process of finding alternative flights. Over the next 24 hours we had numerous calls with both Expedia and British Airways. Incredibly, the next available flights were 9 days later on April 3. This was almost unbelievable, but after many many tries it was the best we could do. Even though these were Business Class tickets. Part of the problem was that apparently rules did not allow any changes to routing for any segment of the flight. This nine day delay was a major problem for us. I had to miss work and my daughter was missing school. Further, we received no compensation from British Airways, no penalty fee, and not any reimbursement of our expenses for staying the nine extra days. After our return I began the British Airways online complaint process, and submitted all supporting documents. I received an email reply and a case reference number. And then nothing. I sent numerous follow up emails, and received no replies. It is now months later, and still I have not heard from British Airways. This is shocking, and definitely the worst airline service I have received for my thousands of flights over many decades. I am a very patient person and this is the first time I have commented on this type of forum. I think the public should be made aware of extremely poor customer service at British Airways.
# Negative words found: ['poor']
# Review: Not Verified |  Flight cancelled, no crew! 9th September 2023, not peak holiday period so why such bad management by BA? Sent to the gate left standing of over and hour and then flight cancelled. As were other on that day. Why does BA continue to provide such poor service - a national disgrace.
# Negative words found: ['bad', 'poor']
# Review: Not Verified |  The worst service ever, my baggage did not arrive on time. Both my flights were delayed. I will never fly them again.  Even the food was bad and your service.
# Negative words found: ['bad']
# Review: ✅ Trip Verified |  4/4 flights we booked this holiday were delayed about 1-2 hours. No wifi available on 2 of 4 flights Food and drinks very basic and expensive. Cannot recommend
# Negative words found: []
# Review: ✅ Trip Verified |  British Airways has a total lack of respect for its customers. I was booked to fly from Frankfurt Main to London City Airport, and just a couple of hours before the scheduled departure the flight was suddenly cancelled by BA without explanation, when I was already at the airport. The worst thing was the utter callousness that staff showed towards customers. The ground staff’s attitude was that they are merely third party agents, not BA employees, and therefore they quickly washed their hands of us all, telling us we had to contact BA directly via phone if we wanted help. They couldn’t even provide us a phone number, telling us to look it up on ba.com ! So BA abandoned its passengers. They did tell us that the BA departure to Heathrow had also been cancelled, meaning there would be no further BA flight from Frankfurt to London that day (although other airlines were still operating the route- but BA refused to rebook us on them). The reason given for both cancellations was “technical reasons”. No assistance or information was provided on our rights due to cancellation, nor any information on help regarding food/ accommodation help etc. Their attitude was literally that the cancellation had nothing to do with them and it was our problem, not theirs. I received an email an hour later notifying me that I had been automatically rebooked on an alternative flight 24 hours later, which wasn’t acceptable as I had to get back to London that night. I rang BA’s call centre and again, they showed a high degree of callousness. 95% of the half-hour call was spent with me waiting on hold, with the phone just cutting off after half an hour, and no meaningful information given to me by that point. There was no attempt by the call operator to call me back when the line cut (and I had a solid phone signal and wifi as I was still standing in Terminal 2 of Frankfurt Main airport), even though my phone number is listed in my booking contact details. They just don’t care. In the end I had to arrange my own return to London by taking a coach to Hanh airport which was 112km away , waiting there for 5 hours and then booking an expensive last minute ticket with Ryanair to Stansted. At least that flight operated on time and got me back to London! BA is worse than a low cost carrier now.
# Negative words found: []
# Review: ✅ Trip Verified |  Care and support shocking. Written by a previously loyal BA traveller. Lies and misleading unprofessional service. Told that my flight was cancelled. Booked on to next available flight in downgraded cabin from business to premium economy. Called to ask why. Told technical fault with my original flight. My suspicion was another reason. At airport, check in staff said that not enough crew to staff original flight earlier in day. Why take my money and allow me to book a flight which would have allowed me to get to work as a doctor in the first place! How can you trust such an organisation to look after you as a flying customer.
# Negative words found: []
# Review: ✅ Trip Verified |  Flying A380 business class should be a pleasure but BA has made it a disaster with the worst seating and configuration imaginable. How could any sane person could jam so many seats into a limited space and expect passengers to be happy. Seats are narrower than economy on some airlines and you must face another person until a plastic screen is raised. The Tv screens are the size of a medium sized tablet and the controls are behind your head in a sitting position. There is no where to put anything except one small pull out draw at ground level that can not be reached when seated nor accessed when sleeping . The window seats and middle seats are accessed by having to jump over a passenger on an aisle seat and the seats are so low that they are hard for elderly to get out of. The whole business class set up is a sick joke. Eating is difficult because the seat is not close enough to the table and the tables are so flimsy that drinks can fall off. Are there any redeeming features - the answer is no. If you like a little comfort avoid BA like the plague.
# Negative words found: []
# Review: ✅ Trip Verified |  British Airways absolutely does not care. My reserved seat was change from an aisle to center seat for this overnight, full flight and it was quite awful. After enquiring at LAX check in, the agent said sorry, nothing we can do. Onboard the flight the attendants seemed to try and finish the meal service at a racing speed, with meals trays passed out with no proper questions about choice. Then back and clearing trays and they disappeared to rest in the kitchen for hours after that. No water runs, if you need anything do not bother with the call bell, as they simply ignore it. I used to like travelling British Airways 10-15 years ago, but the bean counters have been in and lowered it close to a lowcost carrier. I guess staff are badly paid from their terrible attitude and service. My last trip to London was with Delta, they are so much better than this very poor excuse of an airline that British Air has now become.
# Negative words found: ['terrible', 'poor']
# Review: ✅ Trip Verified |  I flew London to Malaga on 27 August in Club Europe. We stood around at Gate B45 in Terminal 5 for over an hour, with staff giving very different reasons for the delay, late inbound aircraft etc - but the plane we boarded had been sitting there for more than an hour! After boarding, the captain stated that because they had changed planes there would be no meals served. This is Club Europe, and we received one small packet of crisps throughout the flight. No effort to apologise. We smelt the hot meal for pilots being heated and then saw it being served to them on a Club Europe meal tray. Cabin crew also had warmed pastries ( and were very quick to use air freshener in the front galley!) while customers received zilch. BA sent an email the following morning to say sorry - nothing else. What a complete and utter rip off by an airline that is already cutting back on so many things. I paid a full Business class fare, did not receive any part of the onboard meal service and they expect an email to be sufficient. Avoid BA if you have any other option nowadays, they are the worst in Europe.
# Negative words found: []
# Review: ✅ Trip Verified |  I arrived at the airport about 2.5 hours before takeoff to have more than about time to get checked in, go through security, etc. All that went without any issues. Being that I was relatively early at the gate, I was one of the first passengers there. After some time boarding had opened. First the business class got called up, then families with children and disabled people. A couple minutes into the boarding they started to call up people, one by one, by name. Then there was an announcement: they won’t let anyone in anymore. Me and about fifty other people were still standing at the gate not being let in. The reason, they said, was that the plane was short staffed (Later I discovered, speaking to a manager, that not only the flight was short staffed but also it was overbooked). After the announcement people were getting angry because they wouldn’t be let in anymore. Nothing changed and everyone was sent away. I had a connecting flight later that day that I was going to miss because I was not let on the plane. First I tried to get my luggage back which I didn’t receive immediately but got a hold of later on thanks to the airport personnel. Then, just like everyone who was going to fly with the same plane, I wanted to talk to someone from British Airways. Since they don’t have a service center at Frankfurt Airport everyone went to the check-in counters where we received food vouchers but not a single person was either able to rebook my or anyone’s flight nor get anyone refunded. All the staff said was that we were going to receive an email in a couple hours with options to rebook the flight or get a refund. I waited four hours for the email at the airport that did not come until today. Trying to call the airline did not help either because they did not answer the phone or hung up in the middle of the conversation. After the four hours of waiting for the email me and some other people from the same flight went back to the check-in counter to get a confirmation from them that I will receive a refund. Being that there was a new shift the personell did not know what had happened. When they scanned my passport an looked at the flight they found out that the system was dying that it was my fault I could not attend the flight. It looked like I had missed it. For everyone standing there with me it was exactly the same. But the people at the counter said they could not do anything about it. Later on we were able to speak to the manager after many phone calls he said they were going to take care of it. We are supposed to get an email at some point in the future. I was not able to get a written confirmation that I will get refunded even after several times asking for it. I already flew a lot of times in my life but never ever has such a thing a happened to me. Not only that me and so many other people were not let into the plane but also the customer service being so horrible that they were not able to rebook or confirm a refund in any way. In the end the only option for me to get to my destination would have been to book a last minute flight for a lot of money which I would not know if I ever got it backed.
# Negative words found: ['angry', 'horrible']
# ...
# Negative words found: ['poor']
# Review: Not Verified |  London to Tampa. BA broke my suitcase and I did not make a fuss, I just got a new one. The new one was too large for the overhead bin on the return flight (the only suitcase I could purchase while abroad). So on top of the new suitcase, I had to actually pay BA to check the new bag. Cost me over $100 for their mistake. They also shovel off customer service to some company abroad. You will get an email a month later saying "I'd like to know you that we are unable to offer refund". Make a big fuss at the airport if they break your stuff so that you can avoid this black hole they call customer service.
#
# Negative words found: []
# Review: ✅ Trip Verified |  My husband and I flew on British Airways flight BA-228 from Baltimore to London Heathrow leaving on the 12th February 2019. Every aspect of the flight was poorer than what budget airlines have to offer. The plane was shabby and dated. The seat reclining facility did not operate properly, was not that comfortable, and we had less legroom than the equivalent with budget airlines. The touch screen TV monitor was not working properly. One ear bud on the headphones did not work. The audio socket was too loose for the headphones so the plug kept falling out making it difficult to enjoy the in-flight entertainment (which in itself had a dated choice). The pillow was disgusting and kept falling out of the flimsy cover. The air conditioning lacked consistency alternating between very hot and very cold air. The restroom occupied sign always lit up as vacant even if it was occupied. However what made the flight very unpleasant was the bad attitude of the cabin crew. They were abrupt, unfriendly and quite clearly did not want to be there. There was one exception, an extremely pleasant older crew member who greeted us on and off the flight. There did not appear to be any organisation or smooth co-ordination when distributing the meals. Our two trays of food where placed on top of each other and practically thrown at us by a sour faced crew member. This flight was one hour late making us nervous about catching our connecting flight. There was no information or instructions given to us about connecting flight gate numbers before we landed. Unlike all the other airlines that I have travelled with there were no staff member greeting the connecting customers to point them in the right direction or re-assure them. British Airways would be my last choice of an airline to travel with and I would only fly with them again if there was no other option.
# Negative words found: ['bad']
# Review: ✅ Trip Verified |  Bridgetown to Gatwick. I couldn't imagine that first class on BA would be the same as travelling in business class with for example Qatar, Emirates, Etihad, Singapore, Thai etc for double the price. Cabin, seats and food equals business class. One of the red wines on the wine list was out from start when I left London outbound. Cabin crew worked well and gave splendid service. But first class on BA is not worth the fare. When I complained to customer service after I got home, all I got was they are in the process of upgrading world traveller.
# Negative words found: []
# Review: ✅ Trip Verified |  London to Athens. Classic BA love and hate relationship where one flight is perfect and another one is a total disaster. Problems in December 2018 at Heathrow check-in when BA check-in and baggage management IT systems went down for at least 90 minutes. Total chaos with people like myself arrived at the airport 2:30 hours before the flight and queuing while others arriving 45 minutes prior to their departure and given priority. Even though we were checked in at some point, the flight was delayed by 2+ hours on top of the problems. Then flight does not have enough food onboard. At least the crew clearly attempted to reduce flight time to the minimum.
# Negative words found: []
# Review: ✅ Trip Verified |  I booked a British Airways flight from Amsterdam to London Heathrow. In the beginning everything went normal and smooth. Check-in and boarding was easy and on time and once everyone boarded the problems started one after another. First an announcement was made by the pilot about a flight delay due to strong winds in Heathrow (fair enough). Afterwards the wind problem was resolved but a passenger decided to leave so they had to take out his luggage. After that we received a 3rd announcement stating there is a computer malfunction at Schiphol Airport and they are doing their best to resolve it. This caused us already about 45-60 mins delay but me and other passenger still remained calm and relaxed and then the hell started. We received permission to take off after 7 mins and then the pilot offered passengers who do not wish to travel to leave the plane. Of course there were many passengers who were travelling on business and I guess too delayed to make it on time for their meetings so they decided to leave. The crew warned them that this might cause terrible delay and problems for the other passengers but they still decided to leave. So a group of passengers left and we missed our opportunity to take off. Then the pilot announced that we can take off after 2,5 or 3 hours. The flight was full of overseas travellers. We spent 2 hours sitting in a plane which was not moving anywhere, people unboarded the plane 4 times in total and no food or water was offered to us. We had to line up next to the bathroom to purchase food and drinks and pay for it. The overall experience was terrible and it ruined the whole plan for my first day in London.
# Negative words found: ['terrible', 'terrible']
# Review: ✅ Trip Verified | Flown with British Airways on numerous occasions with no issues. However on this occasion my baggage was lost on arrival at Gatwick. There was no British airways representative at the baggage claim however there was a phone that allowed me to call the baggage department. Reclaiming lost baggage was simple and my bag was put on the next flight to Singapore which I received the following day.
# Negative words found: []
# Review: ✅ Trip Verified | Flying last Sunday from Geneva to Piladelphia via London in business class. When I arrived at the boarding gate in London to take my flight to Philadelphia they told me that there was no sufficient business seat available! They overbooked! My choice was then either to fly ecenomy or to take the next flight! They just did not care about their customer. No phone call, no email, no indication at the lounge nothing until I was at the boarding gate. I kindly accepted to take the next flight. The plane was delayed by 1 hour due to technical issues. When I arrived at Philadelphia, no suitcase! No British Airways desk on arrival, it was late no one could help. I finally retrieve my suitcase 3 days later: broken! During these 3 days, it was impossible to get someone on the phone. On my flight back to Geneva, same issue! no sufficient business class seats available. It is clear that this company just don't care about their customers, they just care about their money !
# Negative words found: []
# Review: ✅ Trip Verified |
# Berlin to Johannesburg via London. The short haul flight between Berlin and London was oKay, they don't include drinks or snacks anymore on short distance flights and prices onboard for them are compared to some low-cost carriers high. Because of an engine problem, the flights from LHR to JNB was delayed by 2:45h. British Airways gave £5 vouchers out to compensate for snacks and drinks. Inside the A380, the IFE boxes under the window seats take a big part of the available leg space.
# Negative words found: []
# Review: ✅ Trip Verified | New York to London via Geneva with British Airways. The plane was late, not an issue. But some flight attendants were not really friendly in their manner, they seemed in a rush to finish the service and then chill loudly. On a 7 hour flight, they served us the food 40mins after departure, then 20mins at the most after started clearing, we were not even close to finish eating. Then 5 mins after another staff member just came by an took most of the food we didnt even had time to tell him not to. This was really poor service. Especially to realise that because the aircraft was only half booked, they were actually rushing us to be able to stop serving and take a nap comfortably on the raws of empty seats next to us. Thats what you call bad customer service! ps: i was charged 100$ for a luggage, after buying my ticket 350$
# Negative words found: ['poor', 'bad']
# Review: ✅ Trip Verified |  Miami to London. The breakfast served just before landing was terrible. A terrible croissant with some cream cheese with onions and a breakfast fruit bar. It was wrapped in cellophane. Hardly anyone ate it what a waste.
# Negative words found: ['terrible']
# Review: ✅ Trip Verified |  Antigua to Gatwick. Apparently it is necessary to pay extra to get a decent seat by priority booking despite having paid the full cost of world traveler plus. We checked in as soon as the online check in was available to find that only 4 seats (for the 4 of us) remained unbooked. We had to take 2 seats on the front row where the seats had no under seat storage and were as narrow as the economy seats, and 2 on the back row where we were constantly bothered by the adjacent toilets. Only 1 loo each side between the economy and economy plus meant that there were always queues of people leaning against us. Cabin pressure was uncomfortably low, overnight temperature was stifling hot and few people got any sleep at all. Breakfast was a hard cold half sandwich with a hurried cup of tea or coffee. Impossible to get any drinks or refreshments between the service rounds. Tatty seat covers, broken foot rest, malfunctioning entertainment, broken tables requiring us to hold our food and drink between our knees. When asked for help the stewardess told us she didn't have a screw driver to fix these things and it was an old plane with lots of this type of issue.
# Negative words found: []
# Review: ✅ Trip Verified | I understand completely why there is air rage in the skies when companies such as BOAC go out of their way to make the travel experience an stressful and unpleasant as is humanly possible. I paid $813 to fly r/t LAX-BUH and yet they want an extra $150 to have a desirable seat. I understand if you check-in 24 hours before departure you receive a seat from those available, but why is it they assign you the worst seat available when betters are there? In my case, they assigned me a middle seat on a 787 when both of the adjacent aisle seats are available to assign. It is baffling. The ground crew and the inflight staff are excellent but can do little with the oppressive business decisions their executives make - everything comes down to make every penny they can. And why am I flying BOAC? They owed me £25 from the last flight b/c the inflight entertainment system was inop for 1/2 the cabin and so we all had to sit in the dark with nothing to do for a twelve-hour flight. On top of that, their seats have so little padding and cushion that only the plumpest can sit in their seats longer that 15". For normal-sized adults, it is as agonising as the rack must've been. And of course you only get compensation by patronising them again. Now I know: ever a free ticket on BOAC is overpriced.
# Negative words found: []
# Review: ✅ Trip Verified | London to Miami. Worst long haul business class. That annoying divider, the ridiculous fold down footstool and the worn out seats! The service is non-existent, unless they are serving you the meal. If you want a snack or drink get out your seat and hunt down a cabin member, they don’t ask you if you need anything between meals. The toilets are dirty and basic. I’m a Gold Member but giving it up to fly other more updated airlines. They’ve crammed as many business class seats as possible at the expense of comfort and it’s not like they’re cheap.
# Negative words found: []
# Review: ✅ Trip Verified |  Bangalore to London. Ground experience not great - at LHR automated bag drop didn't work and it wasn't clear why; slow-to-react assistance eventually came and identified travel visa to India needed to be validated. At BLR, no online check-in available and slow process. Plane decor extremely run down and shabby, various pieces of the interior trim (bulkheads etc) rattling  and latches for bassinet shelves not locking. Row 12 so bulkhead seat and legroom excellent, however this comes with the hassle of not being able to leave anything on the floor for takeoff and landing; the stowage racks are never big enough to hold the blanket and pillow provided. Seat itself could have more width (I kept bumping the VOD control and I'm quite slim), recline limited and footrest could extend more. No USB power in seat which seems crazy in this day and age. VOD itself is atrocious; tiny screen (folding out of armrest on bulkhead seats), low resolution, visible gridlines and very little choice (hardly the latest movies). To top it off, on outbound leg the VOD stopped working altogether and resisted many resets. Customer service forms were handed out so I await the outcome of that. Food volume OK, quality poor (scrambled eggs in breakfast smelled terrible!), plenty of drinks on outbound leg but not inbound, cabin staff seemed indifferent on inbound leg. Insufficient lavatories for Premium Economy and Economy.
# Negative words found: ['poor']
# Review: ✅ Trip Verified |  Barcelona to New York via London. I was in Barcelona for just four days so had one small bag which they asked me to check. My flight from Barcelona to London was delayed causing  passengers to miss their connections. When I finally got a flight, we taxied for an hour and then were told we needed to return to the gate as the luggage was loaded incorrectly. It took me nearly 24 hours to travel from Barcelona to JFK.  When I arrived, my luggage wasn't there so I filed a claim. I called and emailed every day and they couldn't find it even though I had a tag number and and documentation. Eight days later, they finally contacted me and gave me a six hour window for bag delivery. The final insult is that I was expected to file a claim for my missing personal property within seven days. As a result, they have offered me no compensation for damages.
# Negative words found: []
# Review: ✅ Trip Verified |  We recently flew from London to Bologna, the aircraft was full and they requested that people place their cabin bags into the hold with checked in luggage to save space. So we did, when we arrived my carry on bag which has accompanied me on many flights over the past 3 years was damaged and beyond repair or use for our further journeys. So I approached the damaged/lost baggage area, lodged a claim and provided all the evidence, explained that we were continuing to travel and needed to replace the bag asap. I was advised by the representatives to ring BA service line. Made the call spoke about replacing the bag and what was reasonable and did that and submitted a claim. Well it is still going, despite replacing the bag with a cheaper version the total cost has not been refunded. They instead asked me to produce receipts from 3 years ago and then offered me half the money due to depreciation. Despite a good flight etc have this ongoing angst of the money they refused to refund.
# Negative words found: []

# %%
from collections import Counter

# Define a function to extract negative words from a review
def extract_negative_words(review):
    # Tokenize the review into individual words
    tokens = nltk.word_tokenize(review)
    
    # Remove stopwords
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [token for token in tokens if token.lower() not in stop_words]
    
    # Perform sentence-level sentiment analysis
    sid = nltk.SentenceID(tokens)
    sentence = nltk.Sentence(sid, tokens)
    si = SentimentIntensityAnalyzer()
    sentiment = si.polarity_scores(sentence)
    
    # Extract negative words based on sentiment intensity
    negative_words = []
    for token in tokens:
        if sentiment[token] < 0:
            negative_words.append(token)
    
    return negative_words

# Define a function to analyze reviews and extract the top negative words
def analyze_reviews(reviews):
    negative_words = []
    for review in reviews:
        negative_words.extend(extract_negative_words(review))
    
    # Count the occurrences of each negative word
    negative_word_counts = Counter(negative_words)
    
    # Get the top 10 negative words based on frequency
    top_negative_words = negative_word_counts.most_common(10)
    
    return top_negative_words


print(top_negative_words)
# Out:
# [('flight', 2162), ('ba', 1211), ('seat', 886), ('service', 753), ('time', 626), ('get', 626), ('hour', 585), ('london', 561), ('good', 494), ('fly', 449)]

# %%
# Cleaning the reviews
def clean_review(review):
    review = review.lower()
    review = review.replace('<br/>', '')
    review = review.replace('"', '')
    review = review.replace("'", '')
    return review
cleaned_reviews = [clean_review(review) for review in reviews]

# Identifying the negative words

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
negative_words = []
for review in cleaned_reviews:
    sentiment = analyzer.polarity_scores(review)
    if sentiment['compound'] < 0:
        negative_words.extend(review.split())

# Counting the frequency of negative words
from collections import Counter
negative_word_counts = Counter(negative_words)

# Creating a word cloud
wordcloud = WordCloud(background_color='white', width=800, height=400)
wordcloud.generate_from_frequencies(negative_word_counts)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# Identifying the areas where the company needs to improve
from collections import defaultdict
areas_to_improve = defaultdict(int)
for review in cleaned_reviews:
    sentiment = analyzer.polarity_scores(review)
    if sentiment['compound'] < 0:
        for word in review.split():
            if word in negative_word_counts:
                areas_to_improve[word] += 1

# Printing the areas where the company needs to improve
for area, count in areas_to_improve.items():
    print(f"Area to improve: {area}")
    print(f"Number of mentions: {count}")
# Out:
# Area to improve: ✅
# Number of mentions: 395
# Area to improve: trip
# Number of mentions: 452
# Area to improve: verified
# Number of mentions: 509
# Area to improve: |
# Number of mentions: 505
# Area to improve: 4
# Number of mentions: 54
# Area to improve: hours
# Number of mentions: 185
# Area to improve: before
# Number of mentions: 114
# Area to improve: takeoff
# Number of mentions: 5
# Area to improve: we
# Number of mentions: 697
# Area to improve: received
# Number of mentions: 62
# Area to improve: a
# Number of mentions: 1615
# Area to improve: mail
# Number of mentions: 2
# Area to improve: stating
# Number of mentions: 5
# Area to improve: cryptic
# Number of mentions: 1
# Area to improve: message
# Number of mentions: 17
# Area to improve: that
# Number of mentions: 679
# Area to improve: there
# Number of mentions: 251
# Area to improve: are
# Number of mentions: 262
# Area to improve: disruptions
# Number of mentions: 1
# Area to improve: to
# Number of mentions: 2952
# Area to improve: be
# Number of mentions: 274
# Area to improve: expected
# Number of mentions: 10
# Area to improve: as
# Number of mentions: 359
# Area to improve: is
# Number of mentions: 542
# Area to improve: limit
# Number of mentions: 1
# Area to improve: on
# Number of mentions: 854
# Area to improve: how
# Number of mentions: 64
# Area to improve: many
# Number of mentions: 65
# Area to improve: planes
# Number of mentions: 10
# Area to improve: can
# Number of mentions: 88
# Area to improve: leave
# Number of mentions: 20
# Area to improve: at
# Number of mentions: 525
# Area to improve: the
# Number of mentions: 3587
# Area to improve: same
# Number of mentions: 68
# Area to improve: time.
# Number of mentions: 32
# Area to improve: so
# Number of mentions: 287
# Area to improve: did
# Number of mentions: 142
# Area to improve: capacity
# Number of mentions: 1
# Area to improve: of
# Number of mentions: 1012
# Area to improve: heathrow
# Number of mentions: 131
# Area to improve: airport
# Number of mentions: 121
# Area to improve: really
# Number of mentions: 52
# Area to improve: hit
# Number of mentions: 4
# Area to improve: british
# Number of mentions: 235
# Area to improve: airways
# Number of mentions: 174
# Area to improve: by
# Number of mentions: 204
# Area to improve: surprise,
# Number of mentions: 1
# Area to improve: 4h
# Number of mentions: 3
# Area to improve: departure?
# Number of mentions: 1
# Area to improve: anyhow
# Number of mentions: 1
# Area to improve: -
# Number of mentions: 223
# Area to improve: took
# Number of mentions: 69
# Area to improve: one
# Number of mentions: 226
# Area to improve: hour
# Number of mentions: 119
# Area to improve: delay
# Number of mentions: 34
# Area to improve: what
# Number of mentions: 115
# Area to improve: but
# Number of mentions: 417
# Area to improve: then
# Number of mentions: 177
# Area to improve: have
# Number of mentions: 462
# Area to improve: been
# Number of mentions: 193
# Area to improve: forced
# Number of mentions: 12
# Area to improve: check
# Number of mentions: 124
# Area to improve: in
# Number of mentions: 963
# Area to improve: our
# Number of mentions: 340
# Area to improve: hand
# Number of mentions: 19
# Area to improve: luggage.
# Number of mentions: 20
# Area to improve: i
# Number of mentions: 1636
# Area to improve: travel
# Number of mentions: 76
# Area to improve: only
# Number of mentions: 152
# Area to improve: with
# Number of mentions: 668
# Area to improve: luggage
# Number of mentions: 88
# Area to improve: avoid
# Number of mentions: 32
# Area to improve: waiting
# Number of mentions: 41
# Area to improve: for
# Number of mentions: 913
# Area to improve: ultra
# Number of mentions: 1
# Area to improve: slow
# Number of mentions: 8
# Area to improve: processing
# Number of mentions: 3
# Area to improve: checked
# Number of mentions: 36
# Area to improve: overall
# Number of mentions: 20
# Area to improve: 2h
# Number of mentions: 3
# Area to improve: later
# Number of mentions: 46
# Area to improve: home
# Number of mentions: 40
# Area to improve: than
# Number of mentions: 96
# Area to improve: planed,
# Number of mentions: 1
# Area to improve: no
# Number of mentions: 533
# Area to improve: reason,
# Number of mentions: 5
# Area to improve: just
# Number of mentions: 147
# Area to improve: due
# Number of mentions: 101
# Area to improve: incompetent
# Number of mentions: 8
# Area to improve: people.
# Number of mentions: 8
# Area to improve: service
# Number of mentions: 258
# Area to improve: level
# Number of mentions: 17
# Area to improve: far
# Number of mentions: 30
# Area to improve: worse
# Number of mentions: 15
# Area to improve: ryanair
# Number of mentions: 10
# Area to improve: and
# Number of mentions: 2124
# Area to improve: triple
# Number of mentions: 1
# Area to improve: price.
# Number of mentions: 8
# Area to improve: never
# Number of mentions: 128
# Area to improve: again.
# Number of mentions: 74
# Area to improve: thanks
# Number of mentions: 2
# Area to improve: nothing.
# Number of mentions: 12
# Area to improve: recently
# Number of mentions: 11
# Area to improve: had
# Number of mentions: 533
# Area to improve: from
# Number of mentions: 378
# Area to improve: bru
# Number of mentions: 2
# Area to improve: lhr
# Number of mentions: 44
# Area to improve: was
# Number of mentions: 1463
# Area to improve: staff
# Number of mentions: 184
# Area to improve: shortages.
# Number of mentions: 1
# Area to improve: they
# Number of mentions: 754
# Area to improve: announced
# Number of mentions: 13
# Area to improve: 2
# Number of mentions: 96
# Area to improve: holding
# Number of mentions: 5
# Area to improve: would
# Number of mentions: 181
# Area to improve: board
# Number of mentions: 30
# Area to improve: us
# Number of mentions: 223
# Area to improve: immediately
# Number of mentions: 8
# Area to improve: hopes
# Number of mentions: 1
# Area to improve: clearing
# Number of mentions: 3
# Area to improve: gate
# Number of mentions: 49
# Area to improve: leaving
# Number of mentions: 17
# Area to improve: early.
# Number of mentions: 4
# Area to improve: wait
# Number of mentions: 53
# Area to improve: full
# Number of mentions: 49
# Area to improve: inside
# Number of mentions: 4
# Area to improve: airplane.
# Number of mentions: 1
# Area to improve: plane
# Number of mentions: 102
# Area to improve: old,
# Number of mentions: 7
# Area to improve: dirty,
# Number of mentions: 5
# Area to improve: power
# Number of mentions: 6
# Area to improve: seats.
# Number of mentions: 23
# Area to improve: provided
# Number of mentions: 28
# Area to improve: small
# Number of mentions: 45
# Area to improve: bag
# Number of mentions: 72
# Area to improve: pretzels
# Number of mentions: 4
# Area to improve: 250ml
# Number of mentions: 3
# Area to improve: water
# Number of mentions: 40
# Area to improve: passengers
# Number of mentions: 98
# Area to improve: flight.
# Number of mentions: 140
# Area to improve: were
# Number of mentions: 474
# Area to improve: options
# Number of mentions: 17
# Area to improve: purchase
# Number of mentions: 13
# Area to improve: food
# Number of mentions: 161
# Area to improve: or
# Number of mentions: 244
# Area to improve: drink.
# Number of mentions: 5
# Area to improve: entertainment
# Number of mentions: 31
# Area to improve: available.
# Number of mentions: 16
# Area to improve: am
# Number of mentions: 69
# Area to improve: oneworld
# Number of mentions: 2
# Area to improve: emerald
# Number of mentions: 2
# Area to improve: elite
# Number of mentions: 2
# Area to improve: member
# Number of mentions: 30
# Area to improve: do
# Number of mentions: 99
# Area to improve: not
# Number of mentions: 740
# Area to improve: upgrade
# Number of mentions: 15
# Area to improve: members
# Number of mentions: 8
# Area to improve: based
# Number of mentions: 3
# Area to improve: status.
# Number of mentions: 4
# Area to improve: first
# Number of mentions: 108
# Area to improve: class
# Number of mentions: 158
# Area to improve: lounges
# Number of mentions: 13
# Area to improve: overcrowded,
# Number of mentions: 2
# Area to improve: understaffed
# Number of mentions: 1
# Area to improve: poorly
# Number of mentions: 5
# Area to improve: equipped.
# Number of mentions: 1
# Area to improve: help
# Number of mentions: 48
# Area to improve: desk
# Number of mentions: 26
# Area to improve: completely
# Number of mentions: 18
# Area to improve: unhelpful
# Number of mentions: 3
# Area to improve: when
# Number of mentions: 244
# Area to improve: an
# Number of mentions: 298
# Area to improve: error
# Number of mentions: 10
# Area to improve: arises
# Number of mentions: 1
# Area to improve: delays
# Number of mentions: 17
# Area to improve: cancellations
# Number of mentions: 9
# Area to improve: even
# Number of mentions: 158
# Area to improve: having
# Number of mentions: 41
# Area to improve: top
# Number of mentions: 21
# Area to improve: avios
# Number of mentions: 12
# Area to improve: points
# Number of mentions: 7
# Area to improve: system
# Number of mentions: 35
# Area to improve: has
# Number of mentions: 133
# Area to improve: devalued
# Number of mentions: 1
# Area to improve: near
# Number of mentions: 8
# Area to improve: worthlessness
# Number of mentions: 1
# Area to improve: requires
# Number of mentions: 2
# Area to improve: fees
# Number of mentions: 5
# Area to improve: book
# Number of mentions: 42
# Area to improve: reward
# Number of mentions: 1
# Area to improve: nearly
# Number of mentions: 12
# Area to improve: equal
# Number of mentions: 2
# Area to improve: price
# Number of mentions: 30
# Area to improve: revenue
# Number of mentions: 2
# Area to improve: ticket.
# Number of mentions: 14
# Area to improve: lost
# Number of mentions: 55
# Area to improve: its
# Number of mentions: 52
# Area to improve: way
# Number of mentions: 60
# Area to improve: recent
# Number of mentions: 10
# Area to improve: years
# Number of mentions: 35
# Area to improve: moved
# Number of mentions: 13
# Area to improve: world-class
# Number of mentions: 1
# Area to improve: airline
# Number of mentions: 124
# Area to improve: budget
# Number of mentions: 26
# Area to improve: much
# Number of mentions: 52
# Area to improve: timeliness
# Number of mentions: 1
# Area to improve: easyjet.
# Number of mentions: 2
# Area to improve: 5
# Number of mentions: 51
# Area to improve: days
# Number of mentions: 68
# Area to improve: flight,
# Number of mentions: 63
# Area to improve: advised
# Number of mentions: 21
# Area to improve: ba
# Number of mentions: 530
# Area to improve: it
# Number of mentions: 490
# Area to improve: cancelled
# Number of mentions: 119
# Area to improve: asked
# Number of mentions: 72
# Area to improve: rebook.
# Number of mentions: 2
# Area to improve: flights
# Number of mentions: 115
# Area to improve: 1
# Number of mentions: 32
# Area to improve: after
# Number of mentions: 207
# Area to improve: original
# Number of mentions: 24
# Area to improve: flight
# Number of mentions: 771
# Area to improve: made
# Number of mentions: 66
# Area to improve: take
# Number of mentions: 71
# Area to improve: 3
# Number of mentions: 87
# Area to improve: earlier.
# Number of mentions: 4
# Area to improve: ticket
# Number of mentions: 60
# Area to improve: (and
# Number of mentions: 6
# Area to improve: return
# Number of mentions: 99
# Area to improve: week
# Number of mentions: 20
# Area to improve: later)
# Number of mentions: 2
# Area to improve: included
# Number of mentions: 7
# Area to improve: bag.
# Number of mentions: 13
# Area to improve: arrive
# Number of mentions: 19
# Area to improve: told
# Number of mentions: 181
# Area to improve: doesnt
# Number of mentions: 6
# Area to improve: will
# Number of mentions: 140
# Area to improve: pay
# Number of mentions: 79
# Area to improve: 75
# Number of mentions: 2
# Area to improve: pounds
# Number of mentions: 12
# Area to improve: each
# Number of mentions: 32
# Area to improve: them.
# Number of mentions: 27
# Area to improve: explained
# Number of mentions: 15
# Area to improve: bags
# Number of mentions: 45
# Area to improve: confirmed
# Number of mentions: 13
# Area to improve: did-
# Number of mentions: 1
# Area to improve: this
# Number of mentions: 408
# Area to improve: one!
# Number of mentions: 3
# Area to improve: make
# Number of mentions: 80
# Area to improve: effort
# Number of mentions: 7
# Area to improve: sort
# Number of mentions: 7
# Area to improve: out
# Number of mentions: 163
# Area to improve: up
# Number of mentions: 148
# Area to improve: remove
# Number of mentions: 2
# Area to improve: choice
# Number of mentions: 28
# Area to improve: up,
# Number of mentions: 5
# Area to improve: thinking
# Number of mentions: 3
# Area to improve: should
# Number of mentions: 51
# Area to improve: pretty
# Number of mentions: 14
# Area to improve: easy
# Number of mentions: 11
# Area to improve: get
# Number of mentions: 207
# Area to improve: refund.
# Number of mentions: 24
# Area to improve: 15
# Number of mentions: 21
# Area to improve: months
# Number of mentions: 31
# Area to improve: 10
# Number of mentions: 33
# Area to improve: emails
# Number of mentions: 8
# Area to improve: still
# Number of mentions: 92
# Area to improve: seen
# Number of mentions: 9
# Area to improve: penny.
# Number of mentions: 1
# Area to improve: every
# Number of mentions: 37
# Area to improve: time
# Number of mentions: 159
# Area to improve: ask
# Number of mentions: 26
# Area to improve: where
# Number of mentions: 62
# Area to improve: my
# Number of mentions: 730
# Area to improve: refund
# Number of mentions: 69
# Area to improve: state
# Number of mentions: 7
# Area to improve: long
# Number of mentions: 71
# Area to improve: inane
# Number of mentions: 1
# Area to improve: email
# Number of mentions: 47
# Area to improve: saying
# Number of mentions: 16
# Area to improve: some
# Number of mentions: 69
# Area to improve: departments
# Number of mentions: 2
# Area to improve: longer
# Number of mentions: 19
# Area to improve: others
# Number of mentions: 10
# Area to improve: respond!
# Number of mentions: 1
# Area to improve: absolutely
# Number of mentions: 24
# Area to improve: hopeless
# Number of mentions: 2
# Area to improve: stuff
# Number of mentions: 5
# Area to improve: booking
# Number of mentions: 48
# Area to improve: place
# Number of mentions: 9
# Area to improve: customer
# Number of mentions: 173
# Area to improve: attempt
# Number of mentions: 7
# Area to improve: solve
# Number of mentions: 5
# Area to improve: problem
# Number of mentions: 24
# Area to improve: could
# Number of mentions: 141
# Area to improve: see
# Number of mentions: 28
# Area to improve: mistake
# Number of mentions: 7
# Area to improve: their
# Number of mentions: 211
# Area to improve: system,
# Number of mentions: 3
# Area to improve: compounded
# Number of mentions: 3
# Area to improve: being
# Number of mentions: 72
# Area to improve: unable
# Number of mentions: 16
# Area to improve: investigate
# Number of mentions: 1
# Area to improve: very
# Number of mentions: 172
# Area to improve: simple
# Number of mentions: 9
# Area to improve: claim,
# Number of mentions: 3
# Area to improve: me
# Number of mentions: 348
# Area to improve: 150
# Number of mentions: 1
# Area to improve: months.
# Number of mentions: 4
# Area to improve: booked
# Number of mentions: 120
# Area to improve: bucharest
# Number of mentions: 5
# Area to improve: manchester
# Number of mentions: 10
# Area to improve: 45’
# Number of mentions: 1
# Area to improve: layover
# Number of mentions: 12
# Area to improve: heathrow.
# Number of mentions: 28
# Area to improve: delayed
# Number of mentions: 109
# Area to improve: because
# Number of mentions: 111
# Area to improve: atc
# Number of mentions: 1
# Area to improve: strike.
# Number of mentions: 3
# Area to improve: arrived
# Number of mentions: 77
# Area to improve: 40
# Number of mentions: 18
# Area to improve: minutes
# Number of mentions: 74
# Area to improve: scheduled
# Number of mentions: 18
# Area to improve: enough
# Number of mentions: 33
# Area to improve: catch
# Number of mentions: 7
# Area to improve: connecting
# Number of mentions: 72
# Area to improve: unfortunately
# Number of mentions: 14
# Area to improve: stranded
# Number of mentions: 6
# Area to improve: waited
# Number of mentions: 36
# Area to improve: disembark
# Number of mentions: 3
# Area to improve: lack
# Number of mentions: 27
# Area to improve: slot
# Number of mentions: 2
# Area to improve: shortage
# Number of mentions: 3
# Area to improve: (it’s
# Number of mentions: 1
# Area to improve: common
# Number of mentions: 1
# Area to improve: heathrow).
# Number of mentions: 3
# Area to improve: missed
# Number of mentions: 55
# Area to improve: all
# Number of mentions: 148
# Area to improve: night
# Number of mentions: 25
# Area to improve: freezing
# Number of mentions: 3
# Area to improve: next
# Number of mentions: 94
# Area to improve: day.
# Number of mentions: 20
# Area to improve: shameful
# Number of mentions: 2
# Area to improve: 10£
# Number of mentions: 1
# Area to improve: voucher
# Number of mentions: 37
# Area to improve: which
# Number of mentions: 178
# Area to improve: joke
# Number of mentions: 9
# Area to improve: considering
# Number of mentions: 3
# Area to improve: ridiculous
# Number of mentions: 8
# Area to improve: prices
# Number of mentions: 8
# Area to improve: lhr.
# Number of mentions: 5
# Area to improve: accommodation
# Number of mentions: 9
# Area to improve: offered
# Number of mentions: 67
# Area to improve: sleep
# Number of mentions: 16
# Area to improve: cold
# Number of mentions: 11
# Area to improve: airport.
# Number of mentions: 22
# Area to improve: compensation
# Number of mentions: 29
# Area to improve: sent
# Number of mentions: 50
# Area to improve: text
# Number of mentions: 6
# Area to improve: lame
# Number of mentions: 1
# Area to improve: excuses
# Number of mentions: 3
# Area to improve: sorry,
# Number of mentions: 2
# Area to improve: compensate
# Number of mentions: 10
# Area to improve: anything.
# Number of mentions: 14
# Area to improve: can’t
# Number of mentions: 17
# Area to improve: imagine
# Number of mentions: 4
# Area to improve: worst
# Number of mentions: 78
# Area to improve: regarding
# Number of mentions: 9
# Area to improve: care.
# Number of mentions: 9
# Area to improve: about
# Number of mentions: 115
# Area to improve: money
# Number of mentions: 62
# Area to improve: here
# Number of mentions: 9
# Area to improve: rather
# Number of mentions: 19
# Area to improve: treat
# Number of mentions: 6
# Area to improve: customers.
# Number of mentions: 17
# Area to improve: last
# Number of mentions: 70
# Area to improve: lifetime
# Number of mentions: 1
# Area to improve: flying
# Number of mentions: 67
# Area to improve: airline.
# Number of mentions: 52
# Area to improve: online
# Number of mentions: 51
# Area to improve: ago
# Number of mentions: 17
# Area to improve: hitch
# Number of mentions: 2
# Area to improve: replacement
# Number of mentions: 13
# Area to improve: aircraft
# Number of mentions: 69
# Area to improve: meaning
# Number of mentions: 13
# Area to improve: chosen
# Number of mentions: 8
# Area to improve: seats
# Number of mentions: 146
# Area to improve: different.
# Number of mentions: 2
# Area to improve: informed
# Number of mentions: 25
# Area to improve: prior
# Number of mentions: 20
# Area to improve: departure
# Number of mentions: 36
# Area to improve: amend.
# Number of mentions: 1
# Area to improve: drop
# Number of mentions: 9
# Area to improve: man
# Number of mentions: 7
# Area to improve: t3
# Number of mentions: 3
# Area to improve: wasnt
# Number of mentions: 17
# Area to improve: smooth
# Number of mentions: 8
# Area to improve: suspect
# Number of mentions: 3
# Area to improve: fault.
# Number of mentions: 8
# Area to improve: shuttle
# Number of mentions: 4
# Area to improve: boarding
# Number of mentions: 99
# Area to improve: rush
# Number of mentions: 8
# Area to improve: t5.
# Number of mentions: 2
# Area to improve: cpt
# Number of mentions: 4
# Area to improve: left
# Number of mentions: 64
# Area to improve: more
# Number of mentions: 103
# Area to improve: less
# Number of mentions: 23
# Area to improve: cabin
# Number of mentions: 121
# Area to improve: clean
# Number of mentions: 9
# Area to improve: pe
# Number of mentions: 2
# Area to improve: expected,
# Number of mentions: 2
# Area to improve: sufficient
# Number of mentions: 8
# Area to improve: leg
# Number of mentions: 28
# Area to improve: arm
# Number of mentions: 3
# Area to improve: room
# Number of mentions: 25
# Area to improve: plus
# Number of mentions: 19
# Area to improve: few
# Number of mentions: 39
# Area to improve: little
# Number of mentions: 24
# Area to improve: perks
# Number of mentions: 1
# Area to improve: drinks.
# Number of mentions: 6
# Area to improve: complaint
# Number of mentions: 24
# Area to improve: actually
# Number of mentions: 16
# Area to improve: recline
# Number of mentions: 8
# Area to improve: too
# Number of mentions: 37
# Area to improve: far.
# Number of mentions: 2
# Area to improve: good
# Number of mentions: 59
# Area to improve: during
# Number of mentions: 36
# Area to improve: service,
# Number of mentions: 22
# Area to improve: especially
# Number of mentions: 21
# Area to improve: george.
# Number of mentions: 1
# Area to improve: quite
# Number of mentions: 29
# Area to improve: tasty
# Number of mentions: 3
# Area to improve: option
# Number of mentions: 32
# Area to improve: loaded.
# Number of mentions: 2
# Area to improve: breakfast
# Number of mentions: 30
# Area to improve: also
# Number of mentions: 73
# Area to improve: landed
# Number of mentions: 14
# Area to improve: fly
# Number of mentions: 102
# Area to improve: ointment
# Number of mentions: 1
# Area to improve: both
# Number of mentions: 47
# Area to improve: cases
# Number of mentions: 7
# Area to improve: late
# Number of mentions: 62
# Area to improve: carousel
# Number of mentions: 1
# Area to improve: notice
# Number of mentions: 6
# Area to improve: broken
# Number of mentions: 8
# Area to improve: into,
# Number of mentions: 1
# Area to improve: likely
# Number of mentions: 2
# Area to improve: cpt.
# Number of mentions: 1
# Area to improve: pleasant
# Number of mentions: 6
# Area to improve: surprise.
# Number of mentions: 2
# Area to improve: infrequent
# Number of mentions: 1
# Area to improve: flyer,
# Number of mentions: 2
# Area to improve: always
# Number of mentions: 13
# Area to improve: choice.
# Number of mentions: 8
# Area to improve: reassurance
# Number of mentions: 1
# Area to improve: comfort
# Number of mentions: 8
# Area to improve: quality,
# Number of mentions: 2
# Area to improve: allowance
# Number of mentions: 4
# Area to improve: etc.
# Number of mentions: 11
# Area to improve: fact
# Number of mentions: 24
# Area to improve: i’ve
# Number of mentions: 27
# Area to improve: flown
# Number of mentions: 26
# Area to improve: airlines.
# Number of mentions: 25
# Area to improve: most
# Number of mentions: 60
# Area to improve: now
# Number of mentions: 94
# Area to improve: changed
# Number of mentions: 23
# Area to improve: view
# Number of mentions: 2
# Area to improve: causes
# Number of mentions: 1
# Area to improve: reflect
# Number of mentions: 2
# Area to improve: getting
# Number of mentions: 43
# Area to improve: once
# Number of mentions: 46
# Area to improve: were.
# Number of mentions: 1
# Area to improve: while
# Number of mentions: 30
# Area to improve: around
# Number of mentions: 30
# Area to improve: ways,
# Number of mentions: 1
# Area to improve: ground
# Number of mentions: 37
# Area to improve: ok.
# Number of mentions: 4
# Area to improve: facilities
# Number of mentions: 2
# Area to improve: (or
# Number of mentions: 4
# Area to improve: of)
# Number of mentions: 2
# Area to improve: disappointed
# Number of mentions: 16
# Area to improve: by.
# Number of mentions: 1
# Area to improve: approx
# Number of mentions: 3
# Area to improve: half
# Number of mentions: 34
# Area to improve: thing
# Number of mentions: 16
# Area to improve: cup
# Number of mentions: 10
# Area to improve: poured
# Number of mentions: 1
# Area to improve: bite
# Number of mentions: 1
# Area to improve: sized
# Number of mentions: 2
# Area to improve: banana
# Number of mentions: 1
# Area to improve: slice
# Number of mentions: 2
# Area to improve: cake.
# Number of mentions: 1
# Area to improve: journey
# Number of mentions: 28
# Area to improve: wasn’t
# Number of mentions: 13
# Area to improve: water!
# Number of mentions: 1
# Area to improve: off
# Number of mentions: 76
# Area to improve: media
# Number of mentions: 2
# Area to improve: screen
# Number of mentions: 26
# Area to improve: you
# Number of mentions: 246
# Area to improve: select
# Number of mentions: 5
# Area to improve: something
# Number of mentions: 10
# Area to improve: pass
# Number of mentions: 12
# Area to improve: away.
# Number of mentions: 10
# Area to improve: obligatory
# Number of mentions: 1
# Area to improve: journey.
# Number of mentions: 2
# Area to improve: wifi
# Number of mentions: 11
# Area to improve: poor.
# Number of mentions: 14
# Area to improve: couldn’t
# Number of mentions: 18
# Area to improve: access
# Number of mentions: 10
# Area to improve: shop.
# Number of mentions: 1
# Area to improve: however,
# Number of mentions: 24
# Area to improve: fee
# Number of mentions: 17
# Area to improve: explains
# Number of mentions: 2
# Area to improve: bas
# Number of mentions: 21
# Area to improve: record
# Number of mentions: 3
# Area to improve: profit
# Number of mentions: 1
# Area to improve: £1.52bn.
# Number of mentions: 1
# Area to improve: so,
# Number of mentions: 5
# Area to improve: question
# Number of mentions: 7
# Area to improve: is,
# Number of mentions: 1
# Area to improve: paying
# Number of mentions: 18
# Area to improve: for?
# Number of mentions: 1
# Area to improve: sure
# Number of mentions: 14
# Area to improve: opt
# Number of mentions: 2
# Area to improve: transparent
# Number of mentions: 1
# Area to improve: offer
# Number of mentions: 45
# Area to improve: for,
# Number of mentions: 1
# Area to improve: decide
# Number of mentions: 2
# Area to improve: choose
# Number of mentions: 15
# Area to improve: not.
# Number of mentions: 4
# Area to improve: stands
# Number of mentions: 2
# Area to improve: basic
# Number of mentions: 8
# Area to improve: i’ll
# Number of mentions: 5
# Area to improve: go
# Number of mentions: 70
# Area to improve: elsewhere
# Number of mentions: 1
# Area to improve: cheaper.
# Number of mentions: 1
# Area to improve: totally
# Number of mentions: 18
# Area to improve: unremarkable
# Number of mentions: 1
# Area to improve: time,
# Number of mentions: 24
# Area to improve: comfortable
# Number of mentions: 9
# Area to improve: european
# Number of mentions: 9
# Area to improve: configuration
# Number of mentions: 10
# Area to improve: goes.
# Number of mentions: 1
# Area to improve: catering
# Number of mentions: 10
# Area to improve: storm
# Number of mentions: 4
# Area to improve: effect
# Number of mentions: 1
# Area to improve: greatly
# Number of mentions: 2
# Area to improve: exaggerated.
# Number of mentions: 1
# Area to improve: email,
# Number of mentions: 7
# Area to improve: euro
# Number of mentions: 6
# Area to improve: use
# Number of mentions: 48
# Area to improve: lounge
# Number of mentions: 51
# Area to improve: loss.
# Number of mentions: 2
# Area to improve: 1.
# Number of mentions: 1
# Area to improve: crew
# Number of mentions: 128
# Area to improve: 60
# Number of mentions: 2
# Area to improve: bags.
# Number of mentions: 8
# Area to improve: 2.
# Number of mentions: 2
# Area to improve: ours
# Number of mentions: 2
# Area to improve: behind
# Number of mentions: 14
# Area to improve: 1st
# Number of mentions: 5
# Area to improve: two
# Number of mentions: 93
# Area to improve: 3.
# Number of mentions: 4
# Area to improve: 3rd
# Number of mentions: 6
# Area to improve: times
# Number of mentions: 49
# Area to improve: phone
# Number of mentions: 57
# Area to improve: them
# Number of mentions: 171
# Area to improve: over
# Number of mentions: 111
# Area to improve: hrs
# Number of mentions: 7
# Area to improve: course
# Number of mentions: 16
# Area to improve: week!
# Number of mentions: 1
# Area to improve: 4.
# Number of mentions: 2
# Area to improve: this,
# Number of mentions: 11
# Area to improve: spend
# Number of mentions: 16
# Area to improve: $500
# Number of mentions: 3
# Area to improve: health
# Number of mentions: 1
# Area to improve: beauty
# Number of mentions: 1
# Area to improve: items
# Number of mentions: 8
# Area to improve: wife
# Number of mentions: 35
# Area to improve: cruise.
# Number of mentions: 2
# Area to improve: 5.
# Number of mentions: 2
# Area to improve: said
# Number of mentions: 100
# Area to improve: might
# Number of mentions: 16
# Area to improve: reimburse
# Number of mentions: 6
# Area to improve: 6.
# Number of mentions: 1
# Area to improve: $100
# Number of mentions: 3
# Area to improve: cab
# Number of mentions: 4
# Area to improve: fare
# Number of mentions: 9
# Area to improve: barcelona
# Number of mentions: 9
# Area to improve: bacelona
# Number of mentions: 1
# Area to improve: (iberia)
# Number of mentions: 1
# Area to improve: claimed
# Number of mentions: 11
# Area to improve: delivered
# Number of mentions: 9
# Area to improve: us.
# Number of mentions: 27
# Area to improve: 7.
# Number of mentions: 2
# Area to improve: arriving
# Number of mentions: 14
# Area to improve: back
# Number of mentions: 133
# Area to improve: into
# Number of mentions: 41
# Area to improve: early,
# Number of mentions: 1
# Area to improve: those
# Number of mentions: 22
# Area to improve: people
# Number of mentions: 87
# Area to improve: ready
# Number of mentions: 6
# Area to improve: 8.
# Number of mentions: 1
# Area to improve: caused
# Number of mentions: 22
# Area to improve: 45
# Number of mentions: 15
# Area to improve: though
# Number of mentions: 44
# Area to improve: boarded
# Number of mentions: 16
# Area to improve: probably
# Number of mentions: 13
# Area to improve: mean
# Number of mentions: 9
# Area to improve: miss
# Number of mentions: 19
# Area to improve: connection
# Number of mentions: 24
# Area to improve: anchorage.
# Number of mentions: 1
# Area to improve: clearly
# Number of mentions: 16
# Area to improve: does
# Number of mentions: 25
# Area to improve: care
# Number of mentions: 25
# Area to improve: know
# Number of mentions: 31
# Area to improve: operate
# Number of mentions: 5
# Area to improve: base...shameful.
# Number of mentions: 1
# Area to improve: embarrassed
# Number of mentions: 3
# Area to improve: cant
# Number of mentions: 17
# Area to improve: like
# Number of mentions: 61
# Area to improve: normal
# Number of mentions: 9
# Area to improve: grasp
# Number of mentions: 1
# Area to improve: concept
# Number of mentions: 2
# Area to improve: hiccup
# Number of mentions: 1
# Area to improve: cause
# Number of mentions: 3
# Area to improve: mass
# Number of mentions: 1
# Area to improve: ripples
# Number of mentions: 1
# Area to improve: chaos
# Number of mentions: 14
# Area to improve: other
# Number of mentions: 137
# Area to improve: london
# Number of mentions: 208
# Area to improve: gibraltar
# Number of mentions: 3
# Area to improve: 24th
# Number of mentions: 1
# Area to improve: october
# Number of mentions: 4
# Area to improve: 2023.
# Number of mentions: 7
# Area to improve: shall
# Number of mentions: 3
# Area to improve: start
# Number of mentions: 13
# Area to improve: reference
# Number of mentions: 10
# Area to improve: process.
# Number of mentions: 4
# Area to improve: used
# Number of mentions: 40
# Area to improve: website
# Number of mentions: 43
# Area to improve: reserve
# Number of mentions: 6
# Area to improve: seat
# Number of mentions: 170
# Area to improve: clear
# Number of mentions: 9
# Area to improve: aspect.
# Number of mentions: 1
# Area to improve: depart
# Number of mentions: 6
# Area to improve: terminal
# Number of mentions: 37
# Area to improve: bussed
# Number of mentions: 4
# Area to improve: different
# Number of mentions: 49
# Area to improve: part
# Number of mentions: 21
# Area to improve: stand.
# Number of mentions: 2
# Area to improve: cabin-crew
# Number of mentions: 1
# Area to improve: kept
# Number of mentions: 27
# Area to improve: low
# Number of mentions: 20
# Area to improve: profile
# Number of mentions: 1
# Area to improve: maintained
# Number of mentions: 1
# Area to improve: entire
# Number of mentions: 10
# Area to improve: captain
# Number of mentions: 8
# Area to improve: brief
# Number of mentions: 1
# Area to improve: announcements
# Number of mentions: 5
# Area to improve: in-flight
# Number of mentions: 6
# Area to improve: entertainment.
# Number of mentions: 3
# Area to improve: short
# Number of mentions: 24
# Area to improve: overt.
# Number of mentions: 1
# Area to improve: tiny
# Number of mentions: 15
# Area to improve: bottle
# Number of mentions: 20
# Area to improve: inedible
# Number of mentions: 8
# Area to improve: “breakfast
# Number of mentions: 1
# Area to improve: bar”
# Number of mentions: 1
# Area to improve: order
# Number of mentions: 15
# Area to improve: drink
# Number of mentions: 21
# Area to improve: too.
# Number of mentions: 5
# Area to improve: doe
# Number of mentions: 1
# Area to improve: seem
# Number of mentions: 9
# Area to improve: work
# Number of mentions: 32
# Area to improve: refused
# Number of mentions: 23
# Area to improve: sell
# Number of mentions: 2
# Area to improve: coffee
# Number of mentions: 14
# Area to improve: moreover,
# Number of mentions: 1
# Area to improve: usb
# Number of mentions: 7
# Area to improve: charge
# Number of mentions: 22
# Area to improve: either.
# Number of mentions: 4
# Area to improve: given
# Number of mentions: 80
# Area to improve: early
# Number of mentions: 16
# Area to improve: poor
# Number of mentions: 63
# Area to improve: show
# Number of mentions: 16
# Area to improve: sale
# Number of mentions: 1
# Area to improve: available
# Number of mentions: 43
# Area to improve: trolley
# Number of mentions: 3
# Area to improve: service.
# Number of mentions: 58
# Area to improve: enough.
# Number of mentions: 6
# Area to improve: on-time.
# Number of mentions: 2
# Area to improve: disembarkation
# Number of mentions: 3
# Area to improve: inefficient
# Number of mentions: 1
# Area to improve: managed
# Number of mentions: 23
# Area to improve: seen.
# Number of mentions: 5
# Area to improve: wearing
# Number of mentions: 9
# Area to improve: new
# Number of mentions: 85
# Area to improve: uniform
# Number of mentions: 2
# Area to improve: seems
# Number of mentions: 21
# Area to improve: downward
# Number of mentions: 1
# Area to improve: trend
# Number of mentions: 1
# Area to improve: candid,
# Number of mentions: 1
# Area to improve: any
# Number of mentions: 146
# Area to improve: difference
# Number of mentions: 12
# Area to improve: between
# Number of mentions: 28
# Area to improve: so-called
# Number of mentions: 3
# Area to improve: “budget”
# Number of mentions: 1
# Area to improve: rivals.
# Number of mentions: 1
# Area to improve: route
# Number of mentions: 21
# Area to improve: monopoly
# Number of mentions: 2
# Area to improve: services
# Number of mentions: 18
# Area to improve: company.
# Number of mentions: 5
# Area to improve: experience
# Number of mentions: 68
# Area to improve: ever.
# Number of mentions: 3
# Area to improve: flew
# Number of mentions: 43
# Area to improve: heathrow,
# Number of mentions: 13
# Area to improve: problem.
# Number of mentions: 14
# Area to improve: hours,
# Number of mentions: 17
# Area to improve: three
# Number of mentions: 35
# Area to improve: extra
# Number of mentions: 47
# Area to improve: porto
# Number of mentions: 2
# Area to improve: scrambled
# Number of mentions: 1
# Area to improve: hotel
# Number of mentions: 39
# Area to improve: routed
# Number of mentions: 2
# Area to improve: through
# Number of mentions: 71
# Area to improve: madrid
# Number of mentions: 17
# Area to improve: morning.
# Number of mentions: 3
# Area to improve: 1.5
# Number of mentions: 8
# Area to improve: porto.
# Number of mentions: 2
# Area to improve: (their
# Number of mentions: 2
# Area to improve: fault),
# Number of mentions: 1
# Area to improve: flights.
# Number of mentions: 25
# Area to improve: airport,
# Number of mentions: 16
# Area to improve: $
# Number of mentions: 1
# Area to improve: 1300
# Number of mentions: 1
# Area to improve: then,
# Number of mentions: 8
# Area to improve: reason
# Number of mentions: 11
# Area to improve: again!
# Number of mentions: 6
# Area to improve: finally
# Number of mentions: 57
# Area to improve: got
# Number of mentions: 99
# Area to improve: five
# Number of mentions: 4
# Area to improve: meanwhile,
# Number of mentions: 1
# Area to improve: wifes
# Number of mentions: 3
# Area to improve: it.
# Number of mentions: 54
# Area to improve: flight?
# Number of mentions: 2
# Area to improve: problems
# Number of mentions: 15
# Area to improve: reservations.
# Number of mentions: 1
# Area to improve: point
# Number of mentions: 22
# Area to improve: helpful.
# Number of mentions: 6
# Area to improve: onus
# Number of mentions: 1
# Area to improve: fix
# Number of mentions: 5
# Area to improve: mistakes
# Number of mentions: 1
# Area to improve: turn.
# Number of mentions: 2
# Area to improve: ruined
# Number of mentions: 9
# Area to improve: vacation
# Number of mentions: 5
# Area to improve: dont
# Number of mentions: 47
# Area to improve: wouldnt
# Number of mentions: 15
# Area to improve: let
# Number of mentions: 29
# Area to improve: speak
# Number of mentions: 25
# Area to improve: supervisor
# Number of mentions: 2
# Area to improve: manager.
# Number of mentions: 2
# Area to improve: awful,
# Number of mentions: 4
# Area to improve: bordering
# Number of mentions: 2
# Area to improve: passenger
# Number of mentions: 24
# Area to improve: abuse.
# Number of mentions: 1
# Area to improve: istanbul
# Number of mentions: 5
# Area to improve: business
# Number of mentions: 196
# Area to improve: class.
# Number of mentions: 37
# Area to improve: child
# Number of mentions: 5
# Area to improve: watching
# Number of mentions: 1
# Area to improve: ipad
# Number of mentions: 2
# Area to improve: loud
# Number of mentions: 1
# Area to improve: phones
# Number of mentions: 1
# Area to improve: plugged
# Number of mentions: 1
# Area to improve: rows
# Number of mentions: 15
# Area to improve: front
# Number of mentions: 30
# Area to improve: disrupted
# Number of mentions: 1
# Area to improve: hear
# Number of mentions: 5
# Area to improve: above
# Number of mentions: 3
# Area to improve: headphones.
# Number of mentions: 1
# Area to improve: thought
# Number of mentions: 24
# Area to improve: fine
# Number of mentions: 9
# Area to improve: tell
# Number of mentions: 24
# Area to improve: mom
# Number of mentions: 1
# Area to improve: turn
# Number of mentions: 9
# Area to improve: down.
# Number of mentions: 6
# Area to improve: why
# Number of mentions: 47
# Area to improve: acceptable
# Number of mentions: 4
# Area to improve: class?
# Number of mentions: 2
# Area to improve: turned
# Number of mentions: 19
# Area to improve: zoo?
# Number of mentions: 1
# Area to improve: training
# Number of mentions: 3
# Area to improve: service?
# Number of mentions: 1
# Area to improve: allowed
# Number of mentions: 15
# Area to improve: disrupt
# Number of mentions: 1
# Area to improve: passengers?
# Number of mentions: 1
# Area to improve: she
# Number of mentions: 50
# Area to improve: laughed
# Number of mentions: 2
# Area to improve: me.
# Number of mentions: 37
# Area to improve: disgrace.
# Number of mentions: 5
# Area to improve: ive
# Number of mentions: 20
# Area to improve: mentioned
# Number of mentions: 2
# Area to improve: bad,
# Number of mentions: 3
# Area to improve: bad.
# Number of mentions: 8
# Area to improve: departed
# Number of mentions: 9
# Area to improve: inbound
# Number of mentions: 10
# Area to improve: plane.
# Number of mentions: 25
# Area to improve: full,
# Number of mentions: 6
# Area to improve: economy
# Number of mentions: 79
# Area to improve: larger
# Number of mentions: 3
# Area to improve: baggage
# Number of mentions: 76
# Area to improve: boarding,
# Number of mentions: 6
# Area to improve: making
# Number of mentions: 15
# Area to improve: complete
# Number of mentions: 14
# Area to improve: mockery
# Number of mentions: 1
# Area to improve: advertised.
# Number of mentions: 1
# Area to improve: lots
# Number of mentions: 7
# Area to improve: stressed
# Number of mentions: 1
# Area to improve: missing
# Number of mentions: 19
# Area to improve: onwards
# Number of mentions: 1
# Area to improve: connections
# Number of mentions: 3
# Area to improve: gates
# Number of mentions: 2
# Area to improve: closed
# Number of mentions: 15
# Area to improve: disembarked
# Number of mentions: 1
# Area to improve: onboard
# Number of mentions: 17
# Area to improve: ok
# Number of mentions: 14
# Area to improve: minimal
# Number of mentions: 5
# Area to improve: gave
# Number of mentions: 44
# Area to improve: full-service
# Number of mentions: 2
# Area to improve: ago.
# Number of mentions: 6
# Area to improve: concerning
# Number of mentions: 1
# Area to improve: trying
# Number of mentions: 44
# Area to improve: hold
# Number of mentions: 19
# Area to improve: customers
# Number of mentions: 26
# Area to improve: changes
# Number of mentions: 8
# Area to improve: bookings
# Number of mentions: 10
# Area to improve: deal
# Number of mentions: 7
# Area to improve: non-existent.
# Number of mentions: 4
# Area to improve: deliberately
# Number of mentions: 1
# Area to improve: hard
# Number of mentions: 18
# Area to improve: contact
# Number of mentions: 34
# Area to improve: hate
# Number of mentions: 2
# Area to improve: airways!
# Number of mentions: 1
# Area to improve: oct
# Number of mentions: 1
# Area to improve: cancelled.
# Number of mentions: 29
# Area to improve: stand
# Number of mentions: 14
# Area to improve: line
# Number of mentions: 34
# Area to improve: 1200
# Number of mentions: 1
# Area to improve: fixed
# Number of mentions: 3
# Area to improve: everyone
# Number of mentions: 21
# Area to improve: call
# Number of mentions: 90
# Area to improve: fix.
# Number of mentions: 1
# Area to improve: day..via
# Number of mentions: 1
# Area to improve: online.
# Number of mentions: 13
# Area to improve: vouchers
# Number of mentions: 15
# Area to improve: hotel,
# Number of mentions: 3
# Area to improve: tour.
# Number of mentions: 1
# Area to improve: istanbul.
# Number of mentions: 2
# Area to improve: started
# Number of mentions: 18
# Area to improve: loading
# Number of mentions: 2
# Area to improve: explanations.
# Number of mentions: 1
# Area to improve: may
# Number of mentions: 23
# Area to improve: april
# Number of mentions: 7
# Area to improve: 2022
# Number of mentions: 7
# Area to improve: t5
# Number of mentions: 14
# Area to improve: operated
# Number of mentions: 7
# Area to improve: finnair
# Number of mentions: 4
# Area to improve: using
# Number of mentions: 25
# Area to improve: crew.
# Number of mentions: 7
# Area to improve: shortly
# Number of mentions: 5
# Area to improve: booking,
# Number of mentions: 4
# Area to improve: change
# Number of mentions: 46
# Area to improve: if
# Number of mentions: 143
# Area to improve: preferred.
# Number of mentions: 1
# Area to improve: although
# Number of mentions: 25
# Area to improve: similar
# Number of mentions: 7
# Area to improve: layout
# Number of mentions: 7
# Area to improve: club
# Number of mentions: 76
# Area to improve: europe,
# Number of mentions: 3
# Area to improve: i.e.
# Number of mentions: 1
# Area to improve: middle
# Number of mentions: 39
# Area to improve: free,
# Number of mentions: 2
# Area to improve: felt
# Number of mentions: 18
# Area to improve: legroom
# Number of mentions: 19
# Area to improve: slightly
# Number of mentions: 3
# Area to improve: better.
# Number of mentions: 10
# Area to improve: meal
# Number of mentions: 59
# Area to improve: (we
# Number of mentions: 2
# Area to improve: chose
# Number of mentions: 7
# Area to improve: beef
# Number of mentions: 3
# Area to improve: cheeks).
# Number of mentions: 1
# Area to improve: until
# Number of mentions: 36
# Area to improve: heathrow!
# Number of mentions: 1
# Area to improve: passed
# Number of mentions: 10
# Area to improve: passport
# Number of mentions: 12
# Area to improve: control
# Number of mentions: 9
# Area to improve: without
# Number of mentions: 59
# Area to improve: delay,
# Number of mentions: 7
# Area to improve: designated
# Number of mentions: 2
# Area to improve: reclaim,
# Number of mentions: 1
# Area to improve: waited!
# Number of mentions: 1
# Area to improve: ten
# Number of mentions: 6
# Area to improve: went
# Number of mentions: 44
# Area to improve: counter
# Number of mentions: 19
# Area to improve: going
# Number of mentions: 43
# Area to improve: on.
# Number of mentions: 11
# Area to improve: seemed
# Number of mentions: 21
# Area to improve: unaware
# Number of mentions: 1
# Area to improve: issue,
# Number of mentions: 3
# Area to improve: find
# Number of mentions: 64
# Area to improve: out!
# Number of mentions: 1
# Area to improve: various
# Number of mentions: 6
# Area to improve: requested
# Number of mentions: 16
# Area to improve: information
# Number of mentions: 37
# Area to improve: despite
# Number of mentions: 43
# Area to improve: list
# Number of mentions: 3
# Area to improve: almost
# Number of mentions: 30
# Area to improve: 2½
# Number of mentions: 1
# Area to improve: arrived.
# Number of mentions: 4
# Area to improve: frustrating
# Number of mentions: 3
# Area to improve: say
# Number of mentions: 27
# Area to improve: least.
# Number of mentions: 3
# Area to improve: subsequently
# Number of mentions: 1
# Area to improve: complained
# Number of mentions: 12
# Area to improve: ba,
# Number of mentions: 26
# Area to improve: weeks
# Number of mentions: 35
# Area to improve: explanation
# Number of mentions: 15
# Area to improve: automated
# Number of mentions: 6
# Area to improve: ‘we
# Number of mentions: 1
# Area to improve: experiencing
# Number of mentions: 2
# Area to improve: exceptionally
# Number of mentions: 3
# Area to improve: high
# Number of mentions: 10
# Area to improve: volumes’.
# Number of mentions: 1
# Area to improve: response
# Number of mentions: 23
# Area to improve: says
# Number of mentions: 11
# Area to improve: lot!
# Number of mentions: 1
# Area to improve: (call
# Number of mentions: 1
# Area to improve: centres
# Number of mentions: 2
# Area to improve: etc)
# Number of mentions: 2
# Area to improve: atrocious
# Number of mentions: 2
# Area to improve: sometimes
# Number of mentions: 3
# Area to improve: callous.
# Number of mentions: 1
# Area to improve: don’t
# Number of mentions: 31
# Area to improve: waits
# Number of mentions: 1
# Area to improve: anybody,
# Number of mentions: 1
# Area to improve: who
# Number of mentions: 92
# Area to improve: anything,
# Number of mentions: 1
# Area to improve: calls
# Number of mentions: 18
# Area to improve: cut
# Number of mentions: 12
# Area to improve: halfway
# Number of mentions: 3
# Area to improve: resolution
# Number of mentions: 2
# Area to improve: anyway.
# Number of mentions: 2
# Area to improve: (as
# Number of mentions: 4
# Area to improve: ones)
# Number of mentions: 1
# Area to improve: you’re
# Number of mentions: 6
# Area to improve: your
# Number of mentions: 72
# Area to improve: own
# Number of mentions: 21
# Area to improve: nobody
# Number of mentions: 6
# Area to improve: cares.
# Number of mentions: 1
# Area to improve: so-so
# Number of mentions: 1
# Area to improve: haul
# Number of mentions: 17
# Area to improve: it’s
# Number of mentions: 27
# Area to improve: “semi-low
# Number of mentions: 1
# Area to improve: cost”
# Number of mentions: 1
# Area to improve: confusing
# Number of mentions: 4
# Area to improve: expect.
# Number of mentions: 1
# Area to improve: (very)
# Number of mentions: 1
# Area to improve: snack,
# Number of mentions: 2
# Area to improve: whilst
# Number of mentions: 10
# Area to improve: anything
# Number of mentions: 32
# Area to improve: else
# Number of mentions: 17
# Area to improve: paid
# Number of mentions: 75
# Area to improve: for.
# Number of mentions: 9
# Area to improve: yet
# Number of mentions: 23
# Area to improve: apparently
# Number of mentions: 14
# Area to improve: pre-order
# Number of mentions: 2
# Area to improve: additional
# Number of mentions: 22
# Area to improve: food.
# Number of mentions: 10
# Area to improve: confusing,
# Number of mentions: 1
# Area to improve: makes
# Number of mentions: 9
# Area to improve: dependable.
# Number of mentions: 1
# Area to improve: theory
# Number of mentions: 2
# Area to improve: generous
# Number of mentions: 2
# Area to improve: compared
# Number of mentions: 8
# Area to improve: competitors
# Number of mentions: 2
# Area to improve: space
# Number of mentions: 14
# Area to improve: overhead
# Number of mentions: 8
# Area to improve: cabins,
# Number of mentions: 1
# Area to improve: leading
# Number of mentions: 3
# Area to improve: delays.
# Number of mentions: 8
# Area to improve: whole
# Number of mentions: 27
# Area to improve: offering
# Number of mentions: 14
# Area to improve: hasn’t
# Number of mentions: 1
# Area to improve: well
# Number of mentions: 31
# Area to improve: .
# Number of mentions: 7
# Area to improve: supply
# Number of mentions: 2
# Area to improve: throughout
# Number of mentions: 12
# Area to improve: (contrary
# Number of mentions: 1
# Area to improve: announcement
# Number of mentions: 9
# Area to improve: seatbelt
# Number of mentions: 2
# Area to improve: sight
# Number of mentions: 2
# Area to improve: )
# Number of mentions: 1
# Area to improve: pointless
# Number of mentions: 1
# Area to improve: providing
# Number of mentions: 5
# Area to improve: sockets
# Number of mentions: 1
# Area to improve: place.
# Number of mentions: 4
# Area to improve: abandon
# Number of mentions: 2
# Area to improve: fail
# Number of mentions: 4
# Area to improve: deemed
# Number of mentions: 1
# Area to improve: star
# Number of mentions: 2
# Area to improve: punta
# Number of mentions: 2
# Area to improve: cana.
# Number of mentions: 1
# Area to improve: trouble
# Number of mentions: 2
# Area to improve: outbound
# Number of mentions: 15
# Area to improve: gatwick,
# Number of mentions: 2
# Area to improve: realised
# Number of mentions: 5
# Area to improve: sitting
# Number of mentions: 20
# Area to improve: spent
# Number of mentions: 32
# Area to improve: lot
# Number of mentions: 24
# Area to improve: reserving.
# Number of mentions: 1
# Area to improve: number
# Number of mentions: 46
# Area to improve: automatically
# Number of mentions: 6
# Area to improve: reallocated
# Number of mentions: 1
# Area to improve: particular
# Number of mentions: 3
# Area to improve: reason.
# Number of mentions: 4
# Area to improve: nothing
# Number of mentions: 51
# Area to improve: (although
# Number of mentions: 2
# Area to improve: swapped
# Number of mentions: 1
# Area to improve: couple
# Number of mentions: 18
# Area to improve: seats).
# Number of mentions: 1
# Area to improve: claim
# ...
# Number of mentions: 1
# Area to improve: celebration.
# Number of mentions: 1
# Area to improve: spoil
# Number of mentions: 1
# Area to improve: wed
# Number of mentions: 1
# Area to improve: overbooking.
# Number of mentions: 1
# Area to improve: (defending
# Number of mentions: 1
# Area to improve: indefensible)
# Number of mentions: 1
# Area to improve: fuming
# Number of mentions: 1
# Area to improve: exacerbated
# Number of mentions: 1
# Area to improve: (tea
# Number of mentions: 1
# Area to improve: coffee)
# Number of mentions: 1
# Area to improve: webiste
# Number of mentions: 1
# Area to improve: overbooking
# Number of mentions: 1
# Area to improve: rare
# Number of mentions: 1
# Area to improve: occurrence
# Number of mentions: 2
# Area to improve: contradicts
# Number of mentions: 1
# Area to improve: season.
# Number of mentions: 1
# Area to improve: selling
# Number of mentions: 1
# Area to improve: higher
# Number of mentions: 1
# Area to improve: bidder.
# Number of mentions: 1
# Area to improve: dramatically
# Number of mentions: 1
# Area to improve: preserve
# Number of mentions: 1
# Area to improve: gloss
# Number of mentions: 1
# Area to improve: accountants
# Number of mentions: 1
# Area to improve: win
# Number of mentions: 1
# Area to improve: vote
# Number of mentions: 1
# Area to improve: feet.
# Number of mentions: 1
# Area to improve: can.
# Number of mentions: 2
# Area to improve: £40
# Number of mentions: 1
# Area to improve: laugh
# Number of mentions: 1
# Area to improve: public.
# Number of mentions: 1
# Area to improve: performance
# Number of mentions: 1
# Area to improve: cars
# Number of mentions: 1
# Area to improve: plate.
# Number of mentions: 1
# Area to improve: lumbar
# Number of mentions: 1
# Area to improve: seatback
# Number of mentions: 1
# Area to improve: inches.
# Number of mentions: 1
# Area to improve: claustrophobic.
# Number of mentions: 1
# Area to improve: $1200
# Number of mentions: 1
# Area to improve: bottled
# Number of mentions: 1
# Area to improve: deals
# Number of mentions: 1
# Area to improve: convenience
# Number of mentions: 1
# Area to improve: drug
# Number of mentions: 1
# Area to improve: stores
# Number of mentions: 1
# Area to improve: bos
# Number of mentions: 2
# Area to improve: edi
# Number of mentions: 1
# Area to improve: snippy
# Number of mentions: 1
# Area to improve: £56
# Number of mentions: 1
# Area to improve: bassinet
# Number of mentions: 2
# Area to improve: stowage.
# Number of mentions: 1
# Area to improve: differed,
# Number of mentions: 1
# Area to improve: condescending
# Number of mentions: 1
# Area to improve: platitudes
# Number of mentions: 1
# Area to improve: blank
# Number of mentions: 1
# Area to improve: scam
# Number of mentions: 1
# Area to improve: continuing
# Number of mentions: 2
# Area to improve: informed.
# Number of mentions: 1
# Area to improve: defects
# Number of mentions: 1
# Area to improve: noted
# Number of mentions: 1
# Area to improve: minor
# Number of mentions: 1
# Area to improve: airworthiness
# Number of mentions: 1
# Area to improve: licensed
# Number of mentions: 1
# Area to improve: engineer).
# Number of mentions: 1
# Area to improve: celebration
# Number of mentions: 1
# Area to improve: thanked
# Number of mentions: 1
# Area to improve: rips
# Number of mentions: 1
# Area to improve: disgrace,
# Number of mentions: 1
# Area to improve: famed
# Number of mentions: 1
# Area to improve: 52
# Number of mentions: 1
# Area to improve: 8st
# Number of mentions: 1
# Area to improve: cramp.
# Number of mentions: 1
# Area to improve: fashioned
# Number of mentions: 1
# Area to improve: streamed
# Number of mentions: 1
# Area to improve: loop.
# Number of mentions: 1
# Area to improve: edible.
# Number of mentions: 1
# Area to improve: mad
# Number of mentions: 1
# Area to improve: lockers
# Number of mentions: 1
# Area to improve: insist
# Number of mentions: 1
# Area to improve: loads
# Number of mentions: 1
# Area to improve: venice
# Number of mentions: 1
# Area to improve: deplorable.
# Number of mentions: 1
# Area to improve: chair
# Number of mentions: 1
# Area to improve: staring
# Number of mentions: 1
# Area to improve: maneuver
# Number of mentions: 1
# Area to improve: instructions.
# Number of mentions: 1
# Area to improve: wake
# Number of mentions: 1
# Area to improve: breakfast,
# Number of mentions: 1
# Area to improve: transition
# Number of mentions: 1
# Area to improve: venice,
# Number of mentions: 1
# Area to improve: chest.
# Number of mentions: 1
# Area to improve: airplanes,
# Number of mentions: 1
# Area to improve: circa
# Number of mentions: 1
# Area to improve: b747-400s,
# Number of mentions: 1
# Area to improve: perpetuate
# Number of mentions: 1
# Area to improve: ying/yang
# Number of mentions: 1
# Area to improve: passenger;~no
# Number of mentions: 1
# Area to improve: feat
# Number of mentions: 1
# Area to improve: appalling,
# Number of mentions: 1
# Area to improve: dumped
# Number of mentions: 1
# Area to improve: uneaten.
# Number of mentions: 1
# Area to improve: ohare
# Number of mentions: 1
# Area to improve: crowded,
# Number of mentions: 1
# Area to improve: facility,
# Number of mentions: 1
# Area to improve: wilted
# Number of mentions: 1
# Area to improve: insufficient
# Number of mentions: 2
# Area to improve: chairs,
# Number of mentions: 1
# Area to improve: single,
# Number of mentions: 1
# Area to improve: tv.
# Number of mentions: 1
# Area to improve: worse?
# Number of mentions: 1
# Area to improve: equipped
# Number of mentions: 1
# Area to improve: modern
# Number of mentions: 1
# Area to improve: elegant
# Number of mentions: 1
# Area to improve: demonstrate
# Number of mentions: 1
# Area to improve: sophistication.
# Number of mentions: 1
# Area to improve: dining
# Number of mentions: 1
# Area to improve: chain.
# Number of mentions: 1
# Area to improve: rebooted
# Number of mentions: 1
# Area to improve: joke,
# Number of mentions: 1
# Area to improve: extraordinarily
# Number of mentions: 1
# Area to improve: woeful.
# Number of mentions: 1
# Area to improve: concorde
# Number of mentions: 1
# Area to improve: refurbishment.
# Number of mentions: 1
# Area to improve: machine
# Number of mentions: 1
# Area to improve: forwards
# Number of mentions: 1
# Area to improve: trolley.
# Number of mentions: 1
# Area to improve: bright
# Number of mentions: 1
# Area to improve: doha
# Number of mentions: 1
# Area to improve: windows
# Number of mentions: 1
# Area to improve: blanked
# Number of mentions: 1
# Area to improve: mixed,
# Number of mentions: 1
# Area to improve: leathery
# Number of mentions: 1
# Area to improve: tissue
# Number of mentions: 1
# Area to improve: pocket.
# Number of mentions: 1
# Area to improve: newer
# Number of mentions: 1
# Area to improve: improved.
# Number of mentions: 1
# Area to improve: 19.25),
# Number of mentions: 1
# Area to improve: duly
# Number of mentions: 1
# Area to improve: achieved
# Number of mentions: 1
# Area to improve: consequence,
# Number of mentions: 1
# Area to improve: negligent
# Number of mentions: 1
# Area to improve: barrage
# Number of mentions: 1
# Area to improve: platitudes.
# Number of mentions: 1
# Area to improve: tampa.
# Number of mentions: 1
# Area to improve: fuss,
# Number of mentions: 1
# Area to improve: abroad).
# Number of mentions: 1
# Area to improve: shovel
# Number of mentions: 1
# Area to improve: abroad.
# Number of mentions: 1
# Area to improve: fuss
# Number of mentions: 1
# Area to improve: black
# Number of mentions: 1
# Area to improve: hole
# Number of mentions: 1
# Area to improve: ba-228
# Number of mentions: 1
# Area to improve: baltimore
# Number of mentions: 1
# Area to improve: aspect
# Number of mentions: 1
# Area to improve: shabby
# Number of mentions: 1
# Area to improve: dated.
# Number of mentions: 1
# Area to improve: reclining
# Number of mentions: 1
# Area to improve: properly,
# Number of mentions: 1
# Area to improve: comfortable,
# Number of mentions: 1
# Area to improve: monitor
# Number of mentions: 1
# Area to improve: socket
# Number of mentions: 1
# Area to improve: loose
# Number of mentions: 1
# Area to improve: plug
# Number of mentions: 1
# Area to improve: choice).
# Number of mentions: 1
# Area to improve: cover.
# Number of mentions: 1
# Area to improve: conditioning
# Number of mentions: 1
# Area to improve: consistency
# Number of mentions: 1
# Area to improve: alternating
# Number of mentions: 1
# Area to improve: restroom
# Number of mentions: 1
# Area to improve: lit
# Number of mentions: 1
# Area to improve: vacant
# Number of mentions: 1
# Area to improve: abrupt,
# Number of mentions: 1
# Area to improve: exception,
# Number of mentions: 1
# Area to improve: co-ordination
# Number of mentions: 1
# Area to improve: distributing
# Number of mentions: 1
# Area to improve: thrown
# Number of mentions: 1
# Area to improve: nervous
# Number of mentions: 1
# Area to improve: greeting
# Number of mentions: 1
# Area to improve: direction
# Number of mentions: 1
# Area to improve: re-assure
# Number of mentions: 1
# Area to improve: qatar,
# Number of mentions: 1
# Area to improve: etihad,
# Number of mentions: 1
# Area to improve: singapore,
# Number of mentions: 1
# Area to improve: equals
# Number of mentions: 1
# Area to improve: splendid
# Number of mentions: 1
# Area to improve: classic
# Number of mentions: 1
# Area to improve: love
# Number of mentions: 1
# Area to improve: relationship
# Number of mentions: 1
# Area to improve: priority.
# Number of mentions: 1
# Area to improve: 2+
# Number of mentions: 1
# Area to improve: reduce
# Number of mentions: 1
# Area to improve: minimum.
# Number of mentions: 1
# Area to improve: another.
# Number of mentions: 1
# Area to improve: strong
# Number of mentions: 1
# Area to improve: winds
# Number of mentions: 1
# Area to improve: (fair
# Number of mentions: 1
# Area to improve: enough).
# Number of mentions: 1
# Area to improve: afterwards
# Number of mentions: 1
# Area to improve: wind
# Number of mentions: 1
# Area to improve: schiphol
# Number of mentions: 1
# Area to improve: 45-60
# Number of mentions: 1
# Area to improve: calm
# Number of mentions: 1
# Area to improve: relaxed
# Number of mentions: 1
# Area to improve: started.
# Number of mentions: 1
# Area to improve: warned
# Number of mentions: 1
# Area to improve: 2,5
# Number of mentions: 1
# Area to improve: overseas
# Number of mentions: 1
# Area to improve: anywhere,
# Number of mentions: 1
# Area to improve: unboarded
# Number of mentions: 1
# Area to improve: reclaiming
# Number of mentions: 1
# Area to improve: piladelphia
# Number of mentions: 1
# Area to improve: philadelphia
# Number of mentions: 1
# Area to improve: available!
# Number of mentions: 1
# Area to improve: overbooked!
# Number of mentions: 1
# Area to improve: ecenomy
# Number of mentions: 1
# Area to improve: call,
# Number of mentions: 1
# Area to improve: kindly
# Number of mentions: 1
# Area to improve: philadelphia,
# Number of mentions: 1
# Area to improve: suitcase!
# Number of mentions: 1
# Area to improve: later:
# Number of mentions: 1
# Area to improve: broken!
# Number of mentions: 1
# Area to improve: geneva,
# Number of mentions: 1
# Area to improve: issue!
# Number of mentions: 1
# Area to improve: high.
# Number of mentions: 1
# Area to improve: 2:45h.
# Number of mentions: 1
# Area to improve: £5
# Number of mentions: 1
# Area to improve: boxes
# Number of mentions: 1
# Area to improve: manner,
# Number of mentions: 1
# Area to improve: chill
# Number of mentions: 1
# Area to improve: loudly.
# Number of mentions: 1
# Area to improve: 40mins
# Number of mentions: 1
# Area to improve: 20mins
# Number of mentions: 1
# Area to improve: clearing,
# Number of mentions: 1
# Area to improve: eating.
# Number of mentions: 1
# Area to improve: rushing
# Number of mentions: 1
# Area to improve: nap
# Number of mentions: 1
# Area to improve: raws
# Number of mentions: 1
# Area to improve: ps:
# Number of mentions: 1
# Area to improve: 100$
# Number of mentions: 1
# Area to improve: buying
# Number of mentions: 1
# Area to improve: 350$
# Number of mentions: 1
# Area to improve: cellophane.
# Number of mentions: 1
# Area to improve: ate
# Number of mentions: 1
# Area to improve: waste.
# Number of mentions: 1
# Area to improve: us)
# Number of mentions: 1
# Area to improve: unbooked.
# Number of mentions: 1
# Area to improve: loo
# Number of mentions: 1
# Area to improve: leaning
# Number of mentions: 1
# Area to improve: uncomfortably
# Number of mentions: 1
# Area to improve: low,
# Number of mentions: 1
# Area to improve: stifling
# Number of mentions: 1
# Area to improve: hurried
# Number of mentions: 1
# Area to improve: rounds.
# Number of mentions: 1
# Area to improve: covers,
# Number of mentions: 1
# Area to improve: malfunctioning
# Number of mentions: 1
# Area to improve: knees.
# Number of mentions: 1
# Area to improve: screw
# Number of mentions: 1
# Area to improve: driver
# Number of mentions: 1
# Area to improve: rage
# Number of mentions: 1
# Area to improve: skies
# Number of mentions: 1
# Area to improve: companies
# Number of mentions: 1
# Area to improve: boac
# Number of mentions: 2
# Area to improve: humanly
# Number of mentions: 1
# Area to improve: $813
# Number of mentions: 1
# Area to improve: r/t
# Number of mentions: 1
# Area to improve: lax-buh
# Number of mentions: 1
# Area to improve: $150
# Number of mentions: 1
# Area to improve: available,
# Number of mentions: 1
# Area to improve: assign
# Number of mentions: 1
# Area to improve: betters
# Number of mentions: 1
# Area to improve: there?
# Number of mentions: 1
# Area to improve: assign.
# Number of mentions: 1
# Area to improve: baffling.
# Number of mentions: 1
# Area to improve: oppressive
# Number of mentions: 1
# Area to improve: decisions
# Number of mentions: 1
# Area to improve: boac?
# Number of mentions: 1
# Area to improve: owed
# Number of mentions: 1
# Area to improve: £25
# Number of mentions: 1
# Area to improve: b/c
# Number of mentions: 1
# Area to improve: inop
# Number of mentions: 1
# Area to improve: twelve-hour
# Number of mentions: 1
# Area to improve: cushion
# Number of mentions: 1
# Area to improve: plumpest
# Number of mentions: 1
# Area to improve: 15.
# Number of mentions: 1
# Area to improve: normal-sized
# Number of mentions: 1
# Area to improve: agonising
# Number of mentions: 1
# Area to improve: rack
# Number of mentions: 1
# Area to improve: mustve
# Number of mentions: 1
# Area to improve: patronising
# Number of mentions: 1
# Area to improve: know:
# Number of mentions: 1
# Area to improve: divider,
# Number of mentions: 1
# Area to improve: fold
# Number of mentions: 1
# Area to improve: footstool
# Number of mentions: 1
# Area to improve: hunt
# Number of mentions: 1
# Area to improve: they’ve
# Number of mentions: 1
# Area to improve: cheap.
# Number of mentions: 1
# Area to improve: why;
# Number of mentions: 1
# Area to improve: slow-to-react
# Number of mentions: 1
# Area to improve: validated.
# Number of mentions: 1
# Area to improve: blr,
# Number of mentions: 1
# Area to improve: decor
# Number of mentions: 1
# Area to improve: trim
# Number of mentions: 1
# Area to improve: (bulkheads
# Number of mentions: 1
# Area to improve: rattling
# Number of mentions: 1
# Area to improve: latches
# Number of mentions: 1
# Area to improve: shelves
# Number of mentions: 1
# Area to improve: locking.
# Number of mentions: 1
# Area to improve: landing;
# Number of mentions: 1
# Area to improve: racks
# Number of mentions: 1
# Area to improve: vod
# Number of mentions: 3
# Area to improve: slim),
# Number of mentions: 1
# Area to improve: footrest
# Number of mentions: 1
# Area to improve: atrocious;
# Number of mentions: 1
# Area to improve: (folding
# Number of mentions: 1
# Area to improve: armrest
# Number of mentions: 1
# Area to improve: resolution,
# Number of mentions: 1
# Area to improve: gridlines
# Number of mentions: 1
# Area to improve: (hardly
# Number of mentions: 1
# Area to improve: movies).
# Number of mentions: 1
# Area to improve: altogether
# Number of mentions: 1
# Area to improve: resisted
# Number of mentions: 1
# Area to improve: resets.
# Number of mentions: 1
# Area to improve: await
# Number of mentions: 1
# Area to improve: outcome
# Number of mentions: 1
# Area to improve: terrible!),
# Number of mentions: 1
# Area to improve: inbound,
# Number of mentions: 1
# Area to improve: lavatories
# Number of mentions: 1
# Area to improve: taxied
# Number of mentions: 1
# Area to improve: incorrectly.
# Number of mentions: 1
# Area to improve: damages.
# Number of mentions: 1
# Area to improve: bologna,
# Number of mentions: 1
# Area to improve: accompanied
# Number of mentions: 1
# Area to improve: repair
# Number of mentions: 1
# Area to improve: damaged/lost
# Number of mentions: 1
# Area to improve: area,
# Number of mentions: 1
# Area to improve: evidence,
# Number of mentions: 1
# Area to improve: replace
# Number of mentions: 1
# Area to improve: asap.
# Number of mentions: 1
# Area to improve: depreciation.
# Number of mentions: 1
# Area to improve: angst
# Number of mentions: 1

# %%
#import nltk
#from nltk.corpus import stopwords
#from nltk.stem import WordNetLemmatizer
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#from collections import Counter, defaultdict

#nltk.download('stopwords')
#nltk.download('wordnet')

def clean_review(review):
    review = review.lower()
    review = review.replace('<br/>', '')
    review = review.replace('"', '')
    review = review.replace("'", '')
    return review

def extract_negative_words(review):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    
    tokens = nltk.word_tokenize(review)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    
    si = SentimentIntensityAnalyzer()
    sentiment = si.polarity_scores(review)
    
    negative_words = [token for token in tokens if sentiment['compound'] < 0]
    
    return negative_words

def analyze_reviews(reviews):
    negative_words = []
    for review in reviews:
        negative_words.extend(extract_negative_words(review))
    
    negative_word_counts = Counter(negative_words)
    
    top_negative_words = negative_word_counts.most_common(10)
    
    return top_negative_words

def areas_to_improve(reviews):
    areas = defaultdict(int)
    for review in reviews:
        negative_words = extract_negative_words(review)
        for word in negative_words:
            areas[word] += 1
    
    return areas


cleaned_reviews = [clean_review(review) for review in reviews]
top_negative_words = analyze_reviews(cleaned_reviews)
areas = areas_to_improve(cleaned_reviews)

print("Top 10 negative words:")
for word, count in top_negative_words:
    print(f"Word: {word}, Frequency: {count}")

print("\nAreas to improve:")
for area, count in areas.items():
    print(f"Area: {area}, Number of mentions: {count}")
# Out:
# Top 10 negative words:
# Word: ., Frequency: 4321
# Word: ,, Frequency: 2106
# Word: flight, Frequency: 1137
# Word: ba, Frequency: 632
# Word: verified, Frequency: 510
# Word: |, Frequency: 506
# Word: trip, Frequency: 470
# Word: seat, Frequency: 406
# Word: ✅, Frequency: 395
# Word: hour, Frequency: 368
#
# Areas to improve:
# Area: ✅, Number of mentions: 395
# Area: trip, Number of mentions: 470
# Area: verified, Number of mentions: 510
# Area: |, Number of mentions: 506
# Area: 4, Number of mentions: 57
# Area: hour, Number of mentions: 368
# Area: takeoff, Number of mentions: 6
# Area: received, Number of mentions: 63
# Area: mail, Number of mentions: 2
# Area: stating, Number of mentions: 5
# Area: cryptic, Number of mentions: 1
# Area: message, Number of mentions: 22
# Area: disruption, Number of mentions: 3
# Area: expected, Number of mentions: 12
# Area: limit, Number of mentions: 1
# Area: many, Number of mentions: 65
# Area: plane, Number of mentions: 151
# Area: leave, Number of mentions: 24
# Area: time, Number of mentions: 292
# Area: ., Number of mentions: 4321
# Area: capacity, Number of mentions: 1
# Area: heathrow, Number of mentions: 176
# Area: airport, Number of mentions: 161
# Area: really, Number of mentions: 55
# Area: hit, Number of mentions: 4
# Area: british, Number of mentions: 236
# Area: airway, Number of mentions: 232
# Area: surprise, Number of mentions: 5
# Area: ,, Number of mentions: 2106
# Area: 4h, Number of mentions: 3
# Area: departure, Number of mentions: 60
# Area: ?, Number of mentions: 78
# Area: anyhow, Number of mentions: 1
# Area: -, Number of mentions: 224
# Area: took, Number of mentions: 69
# Area: one, Number of mentions: 241
# Area: delay, Number of mentions: 85
# Area: forced, Number of mentions: 12
# Area: check, Number of mentions: 132
# Area: hand, Number of mentions: 29
# Area: luggage, Number of mentions: 120
# Area: travel, Number of mentions: 94
# Area: avoid, Number of mentions: 34
# Area: waiting, Number of mentions: 43
# Area: ultra, Number of mentions: 1
# Area: slow, Number of mentions: 15
# Area: processing, Number of mentions: 3
# Area: checked, Number of mentions: 36
# Area: overall, Number of mentions: 28
# Area: 2h, Number of mentions: 3
# Area: later, Number of mentions: 76
# Area: home, Number of mentions: 60
# Area: planed, Number of mentions: 1
# Area: reason, Number of mentions: 32
# Area: due, Number of mentions: 104
# Area: incompetent, Number of mentions: 8
# Area: people, Number of mentions: 96
# Area: service, Number of mentions: 362
# Area: level, Number of mentions: 22
# Area: far, Number of mentions: 33
# Area: worse, Number of mentions: 26
# Area: ryanair, Number of mentions: 12
# Area: triple, Number of mentions: 1
# Area: price, Number of mentions: 56
# Area: never, Number of mentions: 128
# Area: thanks, Number of mentions: 2
# Area: nothing, Number of mentions: 64
# Area: recently, Number of mentions: 12
# Area: bru, Number of mentions: 2
# Area: lhr, Number of mentions: 54
# Area: staff, Number of mentions: 206
# Area: shortage, Number of mentions: 4
# Area: announced, Number of mentions: 13
# Area: 2, Number of mentions: 99
# Area: holding, Number of mentions: 5
# Area: would, Number of mentions: 184
# Area: board, Number of mentions: 42
# Area: u, Number of mentions: 257
# Area: immediately, Number of mentions: 9
# Area: hope, Number of mentions: 10
# Area: clearing, Number of mentions: 4
# Area: gate, Number of mentions: 72
# Area: leaving, Number of mentions: 18
# Area: early, Number of mentions: 21
# Area: wait, Number of mentions: 57
# Area: full, Number of mentions: 61
# Area: inside, Number of mentions: 5
# Area: airplane, Number of mentions: 5
# Area: old, Number of mentions: 44
# Area: dirty, Number of mentions: 18
# Area: power, Number of mentions: 6
# Area: seat, Number of mentions: 406
# Area: provided, Number of mentions: 37
# Area: small, Number of mentions: 52
# Area: bag, Number of mentions: 149
# Area: pretzel, Number of mentions: 6
# Area: 250ml, Number of mentions: 3
# Area: water, Number of mentions: 59
# Area: passenger, Number of mentions: 149
# Area: flight, Number of mentions: 1137
# Area: option, Number of mentions: 63
# Area: purchase, Number of mentions: 16
# Area: food, Number of mentions: 182
# Area: drink, Number of mentions: 74
# Area: entertainment, Number of mentions: 38
# Area: available, Number of mentions: 62
# Area: oneworld, Number of mentions: 3
# Area: emerald, Number of mentions: 3
# Area: elite, Number of mentions: 2
# Area: member, Number of mentions: 44
# Area: upgrade, Number of mentions: 19
# Area: based, Number of mentions: 3
# Area: status, Number of mentions: 13
# Area: first, Number of mentions: 117
# Area: class, Number of mentions: 220
# Area: lounge, Number of mentions: 73
# Area: overcrowded, Number of mentions: 7
# Area: understaffed, Number of mentions: 1
# Area: poorly, Number of mentions: 5
# Area: equipped, Number of mentions: 2
# Area: help, Number of mentions: 57
# Area: desk, Number of mentions: 51
# Area: completely, Number of mentions: 20
# Area: unhelpful, Number of mentions: 5
# Area: error, Number of mentions: 14
# Area: arises, Number of mentions: 1
# Area: cancellation, Number of mentions: 32
# Area: even, Number of mentions: 160
# Area: top, Number of mentions: 21
# Area: avios, Number of mentions: 12
# Area: point, Number of mentions: 36
# Area: system, Number of mentions: 47
# Area: devalued, Number of mentions: 1
# Area: near, Number of mentions: 8
# Area: worthlessness, Number of mentions: 1
# Area: requires, Number of mentions: 2
# Area: fee, Number of mentions: 33
# Area: book, Number of mentions: 42
# Area: reward, Number of mentions: 1
# Area: nearly, Number of mentions: 12
# Area: equal, Number of mentions: 3
# Area: revenue, Number of mentions: 2
# Area: ticket, Number of mentions: 120
# Area: lost, Number of mentions: 57
# Area: way, Number of mentions: 76
# Area: recent, Number of mentions: 10
# Area: year, Number of mentions: 74
# Area: moved, Number of mentions: 15
# Area: world-class, Number of mentions: 1
# Area: airline, Number of mentions: 279
# Area: budget, Number of mentions: 31
# Area: much, Number of mentions: 54
# Area: timeliness, Number of mentions: 1
# Area: easyjet, Number of mentions: 6
# Area: 5, Number of mentions: 54
# Area: day, Number of mentions: 203
# Area: advised, Number of mentions: 21
# Area: ba, Number of mentions: 632
# Area: cancelled, Number of mentions: 160
# Area: asked, Number of mentions: 74
# Area: rebook, Number of mentions: 37
# Area: 1, Number of mentions: 36
# Area: original, Number of mentions: 24
# Area: made, Number of mentions: 71
# Area: take, Number of mentions: 74
# Area: 3, Number of mentions: 96
# Area: earlier, Number of mentions: 22
# Area: (, Number of mentions: 218
# Area: return, Number of mentions: 109
# Area: week, Number of mentions: 68
# Area: ), Number of mentions: 217
# Area: included, Number of mentions: 8
# Area: arrive, Number of mentions: 27
# Area: told, Number of mentions: 185
# Area: doesnt, Number of mentions: 6
# Area: pay, Number of mentions: 84
# Area: 75, Number of mentions: 2
# Area: pound, Number of mentions: 18
# Area: explained, Number of mentions: 15
# Area: confirmed, Number of mentions: 15
# Area: did-, Number of mentions: 1
# Area: !, Number of mentions: 145
# Area: make, Number of mentions: 90
# Area: effort, Number of mentions: 7
# Area: sort, Number of mentions: 8
# Area: remove, Number of mentions: 2
# Area: choice, Number of mentions: 53
# Area: thinking, Number of mentions: 3
# Area: pretty, Number of mentions: 14
# Area: easy, Number of mentions: 12
# Area: get, Number of mentions: 210
# Area: refund, Number of mentions: 108
# Area: 15, Number of mentions: 21
# Area: month, Number of mentions: 52
# Area: 10, Number of mentions: 36
# Area: email, Number of mentions: 74
# Area: still, Number of mentions: 94
# Area: seen, Number of mentions: 14
# Area: penny, Number of mentions: 6
# Area: every, Number of mentions: 37
# Area: ask, Number of mentions: 29
# Area: state, Number of mentions: 7
# Area: long, Number of mentions: 74
# Area: inane, Number of mentions: 1
# Area: saying, Number of mentions: 16
# Area: department, Number of mentions: 14
# Area: longer, Number of mentions: 20
# Area: others, Number of mentions: 11
# Area: respond, Number of mentions: 8
# Area: absolutely, Number of mentions: 24
# Area: hopeless, Number of mentions: 2
# Area: stuff, Number of mentions: 6
# Area: booking, Number of mentions: 67
# Area: place, Number of mentions: 15
# Area: customer, Number of mentions: 229
# Area: attempt, Number of mentions: 9
# Area: solve, Number of mentions: 5
# Area: problem, Number of mentions: 60
# Area: could, Number of mentions: 141
# Area: see, Number of mentions: 32
# Area: mistake, Number of mentions: 13
# Area: compounded, Number of mentions: 3
# Area: unable, Number of mentions: 16
# Area: investigate, Number of mentions: 1
# Area: simple, Number of mentions: 9
# Area: claim, Number of mentions: 48
# Area: 150, Number of mentions: 2
# Area: booked, Number of mentions: 129
# Area: bucharest, Number of mentions: 6
# Area: manchester, Number of mentions: 12
# Area: 45, Number of mentions: 16
# Area: ’, Number of mentions: 314
# Area: layover, Number of mentions: 13
# Area: delayed, Number of mentions: 127
# Area: atc, Number of mentions: 2
# Area: strike, Number of mentions: 9
# Area: arrived, Number of mentions: 84
# Area: 40, Number of mentions: 18
# Area: minute, Number of mentions: 109
# Area: scheduled, Number of mentions: 18
# Area: enough, Number of mentions: 43
# Area: catch, Number of mentions: 7
# Area: connecting, Number of mentions: 72
# Area: unfortunately, Number of mentions: 22
# Area: stranded, Number of mentions: 6
# Area: waited, Number of mentions: 39
# Area: disembark, Number of mentions: 3
# Area: lack, Number of mentions: 28
# Area: slot, Number of mentions: 5
# Area: common, Number of mentions: 1
# Area: missed, Number of mentions: 58
# Area: night, Number of mentions: 31
# Area: freezing, Number of mentions: 3
# Area: next, Number of mentions: 95
# Area: shameful, Number of mentions: 4
# Area: 10£, Number of mentions: 1
# Area: voucher, Number of mentions: 83
# Area: joke, Number of mentions: 15
# Area: considering, Number of mentions: 3
# Area: ridiculous, Number of mentions: 8
# Area: accommodation, Number of mentions: 15
# Area: offered, Number of mentions: 80
# Area: sleep, Number of mentions: 20
# Area: cold, Number of mentions: 15
# Area: compensation, Number of mentions: 39
# Area: sent, Number of mentions: 51
# Area: text, Number of mentions: 12
# Area: lame, Number of mentions: 1
# Area: excuse, Number of mentions: 15
# Area: sorry, Number of mentions: 14
# Area: compensate, Number of mentions: 10
# Area: anything, Number of mentions: 47
# Area: imagine, Number of mentions: 5
# Area: worst, Number of mentions: 81
# Area: regarding, Number of mentions: 9
# Area: care, Number of mentions: 37
# Area: money, Number of mentions: 84
# Area: rather, Number of mentions: 20
# Area: treat, Number of mentions: 8
# Area: last, Number of mentions: 72
# Area: lifetime, Number of mentions: 2
# Area: flying, Number of mentions: 70
# Area: online, Number of mentions: 72
# Area: ago, Number of mentions: 26
# Area: hitch, Number of mentions: 2
# Area: replacement, Number of mentions: 14
# Area: aircraft, Number of mentions: 78
# Area: meaning, Number of mentions: 13
# Area: chosen, Number of mentions: 9
# Area: different, Number of mentions: 51
# Area: informed, Number of mentions: 26
# Area: prior, Number of mentions: 20
# Area: amend, Number of mentions: 3
# Area: drop, Number of mentions: 11
# Area: man, Number of mentions: 7
# Area: t3, Number of mentions: 5
# Area: wasnt, Number of mentions: 17
# Area: smooth, Number of mentions: 11
# Area: suspect, Number of mentions: 3
# Area: fault, Number of mentions: 30
# Area: shuttle, Number of mentions: 5
# Area: boarding, Number of mentions: 107
# Area: rush, Number of mentions: 9
# Area: t5, Number of mentions: 19
# Area: cpt, Number of mentions: 5
# Area: left, Number of mentions: 70
# Area: le, Number of mentions: 24
# Area: cabin, Number of mentions: 135
# Area: clean, Number of mentions: 10
# Area: pe, Number of mentions: 2
# Area: sufficient, Number of mentions: 10
# Area: leg, Number of mentions: 49
# Area: arm, Number of mentions: 5
# Area: room, Number of mentions: 39
# Area: plus, Number of mentions: 23
# Area: little, Number of mentions: 24
# Area: perk, Number of mentions: 1
# Area: complaint, Number of mentions: 44
# Area: actually, Number of mentions: 16
# Area: recline, Number of mentions: 11
# Area: good, Number of mentions: 75
# Area: especially, Number of mentions: 21
# Area: george, Number of mentions: 1
# Area: quite, Number of mentions: 30
# Area: tasty, Number of mentions: 6
# Area: loaded, Number of mentions: 7
# Area: breakfast, Number of mentions: 35
# Area: also, Number of mentions: 78
# Area: landed, Number of mentions: 18
# Area: fly, Number of mentions: 113
# Area: ointment, Number of mentions: 1
# Area: case, Number of mentions: 27
# Area: late, Number of mentions: 89
# Area: carousel, Number of mentions: 2
# Area: notice, Number of mentions: 10
# Area: broken, Number of mentions: 23
# Area: likely, Number of mentions: 2
# Area: pleasant, Number of mentions: 8
# Area: infrequent, Number of mentions: 1
# Area: flyer, Number of mentions: 10
# Area: always, Number of mentions: 15
# Area: reassurance, Number of mentions: 1
# Area: comfort, Number of mentions: 11
# Area: quality, Number of mentions: 29
# Area: allowance, Number of mentions: 7
# Area: etc, Number of mentions: 26
# Area: fact, Number of mentions: 24
# Area: flown, Number of mentions: 32
# Area: changed, Number of mentions: 26
# Area: view, Number of mentions: 2
# Area: cause, Number of mentions: 4
# Area: reflect, Number of mentions: 2
# Area: getting, Number of mentions: 43
# Area: around, Number of mentions: 32
# Area: ground, Number of mentions: 37
# Area: ok., Number of mentions: 4
# Area: facility, Number of mentions: 8
# Area: disappointed, Number of mentions: 19
# Area: approx, Number of mentions: 3
# Area: half, Number of mentions: 37
# Area: thing, Number of mentions: 35
# Area: cup, Number of mentions: 13
# Area: poured, Number of mentions: 1
# Area: bite, Number of mentions: 1
# Area: sized, Number of mentions: 2
# Area: banana, Number of mentions: 1
# Area: slice, Number of mentions: 2
# Area: cake, Number of mentions: 1
# Area: journey, Number of mentions: 37
# Area: medium, Number of mentions: 4
# Area: screen, Number of mentions: 44
# Area: select, Number of mentions: 5
# Area: something, Number of mentions: 11
# Area: pas, Number of mentions: 18
# Area: away, Number of mentions: 35
# Area: obligatory, Number of mentions: 1
# Area: wifi, Number of mentions: 15
# Area: poor, Number of mentions: 84
# Area: access, Number of mentions: 10
# Area: shop, Number of mentions: 6
# Area: however, Number of mentions: 53
# Area: explains, Number of mentions: 2
# Area: record, Number of mentions: 5
# Area: profit, Number of mentions: 1
# Area: £1.52bn, Number of mentions: 1
# Area: question, Number of mentions: 12
# Area: paying, Number of mentions: 19
# Area: sure, Number of mentions: 16
# Area: opt, Number of mentions: 2
# Area: transparent, Number of mentions: 1
# Area: offer, Number of mentions: 54
# Area: decide, Number of mentions: 2
# Area: choose, Number of mentions: 15
# Area: stand, Number of mentions: 18
# Area: basic, Number of mentions: 11
# Area: go, Number of mentions: 87
# Area: elsewhere, Number of mentions: 1
# Area: cheaper, Number of mentions: 8
# Area: totally, Number of mentions: 18
# Area: unremarkable, Number of mentions: 1
# Area: comfortable, Number of mentions: 14
# Area: european, Number of mentions: 9
# Area: configuration, Number of mentions: 12
# Area: catering, Number of mentions: 10
# Area: storm, Number of mentions: 4
# Area: effect, Number of mentions: 1
# Area: greatly, Number of mentions: 2
# Area: exaggerated, Number of mentions: 1
# Area: euro, Number of mentions: 13
# Area: use, Number of mentions: 52
# Area: loss, Number of mentions: 6
# Area: 1., Number of mentions: 1
# Area: crew, Number of mentions: 142
# Area: 60, Number of mentions: 2
# Area: 2., Number of mentions: 2
# Area: behind, Number of mentions: 15
# Area: 1st, Number of mentions: 7
# Area: two, Number of mentions: 94
# Area: 3., Number of mentions: 4
# Area: 3rd, Number of mentions: 6
# Area: phone, Number of mentions: 79
# Area: hr, Number of mentions: 15
# Area: course, Number of mentions: 23
# Area: 4., Number of mentions: 1
# Area: spend, Number of mentions: 16
# Area: $, Number of mentions: 59
# Area: 500, Number of mentions: 5
# Area: health, Number of mentions: 1
# Area: beauty, Number of mentions: 1
# Area: item, Number of mentions: 9
# Area: wife, Number of mentions: 44
# Area: cruise, Number of mentions: 4
# Area: 5., Number of mentions: 2
# Area: said, Number of mentions: 103
# Area: might, Number of mentions: 17
# Area: reimburse, Number of mentions: 7
# Area: 6., Number of mentions: 1
# Area: 100, Number of mentions: 10
# Area: cab, Number of mentions: 7
# Area: fare, Number of mentions: 16
# Area: barcelona, Number of mentions: 10
# Area: bacelona, Number of mentions: 1
# Area: iberia, Number of mentions: 22
# Area: claimed, Number of mentions: 12
# Area: delivered, Number of mentions: 12
# Area: 7., Number of mentions: 2
# Area: arriving, Number of mentions: 14
# Area: back, Number of mentions: 147
# Area: ready, Number of mentions: 7
# Area: 8., Number of mentions: 1
# Area: caused, Number of mentions: 22
# Area: though, Number of mentions: 50
# Area: boarded, Number of mentions: 19
# Area: probably, Number of mentions: 14
# Area: mean, Number of mentions: 25
# Area: miss, Number of mentions: 21
# Area: connection, Number of mentions: 35
# Area: anchorage, Number of mentions: 1
# Area: clearly, Number of mentions: 16
# Area: know, Number of mentions: 37
# Area: operate, Number of mentions: 6
# Area: base, Number of mentions: 2
# Area: ..., Number of mentions: 8
# Area: embarrassed, Number of mentions: 3
# Area: cant, Number of mentions: 17
# Area: like, Number of mentions: 64
# Area: normal, Number of mentions: 10
# Area: grasp, Number of mentions: 1
# Area: concept, Number of mentions: 2
# Area: hiccup, Number of mentions: 1
# Area: mass, Number of mentions: 1
# Area: ripple, Number of mentions: 1
# Area: chaos, Number of mentions: 17
# Area: london, Number of mentions: 292
# Area: gibraltar, Number of mentions: 3
# Area: 24th, Number of mentions: 1
# Area: october, Number of mentions: 7
# Area: 2023., Number of mentions: 7
# Area: shall, Number of mentions: 3
# Area: start, Number of mentions: 16
# Area: reference, Number of mentions: 10
# Area: process, Number of mentions: 29
# Area: used, Number of mentions: 44
# Area: website, Number of mentions: 56
# Area: reserve, Number of mentions: 6
# Area: clear, Number of mentions: 10
# Area: aspect, Number of mentions: 5
# Area: depart, Number of mentions: 8
# Area: terminal, Number of mentions: 45
# Area: bussed, Number of mentions: 4
# Area: part, Number of mentions: 23
# Area: cabin-crew, Number of mentions: 1
# Area: kept, Number of mentions: 27
# Area: low, Number of mentions: 23
# Area: profile, Number of mentions: 1
# Area: maintained, Number of mentions: 2
# Area: entire, Number of mentions: 10
# Area: captain, Number of mentions: 8
# Area: brief, Number of mentions: 1
# Area: announcement, Number of mentions: 15
# Area: in-flight, Number of mentions: 6
# Area: short, Number of mentions: 27
# Area: overt, Number of mentions: 1
# Area: tiny, Number of mentions: 19
# Area: bottle, Number of mentions: 24
# Area: inedible, Number of mentions: 15
# Area: “, Number of mentions: 34
# Area: bar, Number of mentions: 13
# Area: ”, Number of mentions: 35
# Area: order, Number of mentions: 23
# Area: doe, Number of mentions: 1
# Area: seem, Number of mentions: 9
# Area: work, Number of mentions: 49
# Area: refused, Number of mentions: 25
# Area: sell, Number of mentions: 4
# Area: coffee, Number of mentions: 21
# Area: moreover, Number of mentions: 1
# Area: usb, Number of mentions: 7
# Area: charge, Number of mentions: 38
# Area: either, Number of mentions: 23
# Area: given, Number of mentions: 87
# Area: show, Number of mentions: 21
# Area: sale, Number of mentions: 1
# Area: trolley, Number of mentions: 6
# Area: on-time, Number of mentions: 2
# Area: disembarkation, Number of mentions: 3
# Area: inefficient, Number of mentions: 2
# Area: managed, Number of mentions: 24
# Area: wearing, Number of mentions: 9
# Area: new, Number of mentions: 86
# Area: uniform, Number of mentions: 2
# Area: seems, Number of mentions: 21
# Area: downward, Number of mentions: 1
# Area: trend, Number of mentions: 1
# Area: candid, Number of mentions: 1
# Area: difference, Number of mentions: 13
# Area: so-called, Number of mentions: 3
# Area: rival, Number of mentions: 4
# Area: route, Number of mentions: 35
# Area: monopoly, Number of mentions: 3
# Area: company, Number of mentions: 30
# Area: experience, Number of mentions: 110
# Area: ever, Number of mentions: 52
# Area: flew, Number of mentions: 43
# Area: three, Number of mentions: 35
# Area: extra, Number of mentions: 52
# Area: porto, Number of mentions: 4
# Area: scrambled, Number of mentions: 3
# Area: hotel, Number of mentions: 58
# Area: routed, Number of mentions: 2
# Area: madrid, Number of mentions: 19
# Area: morning, Number of mentions: 21
# Area: 1.5, Number of mentions: 9
# Area: 1300, Number of mentions: 1
# Area: finally, Number of mentions: 61
# Area: got, Number of mentions: 99
# Area: five, Number of mentions: 4
# Area: meanwhile, Number of mentions: 1
# Area: reservation, Number of mentions: 16
# Area: helpful, Number of mentions: 16
# Area: onus, Number of mentions: 1
# Area: fix, Number of mentions: 6
# Area: turn, Number of mentions: 15
# Area: ruined, Number of mentions: 12
# Area: vacation, Number of mentions: 7
# Area: dont, Number of mentions: 47
# Area: wouldnt, Number of mentions: 15
# Area: let, Number of mentions: 30
# Area: speak, Number of mentions: 25
# Area: supervisor, Number of mentions: 6
# Area: manager, Number of mentions: 17
# Area: awful, Number of mentions: 30
# Area: bordering, Number of mentions: 2
# Area: abuse, Number of mentions: 1
# Area: istanbul, Number of mentions: 7
# Area: business, Number of mentions: 205
# Area: child, Number of mentions: 15
# Area: watching, Number of mentions: 1
# Area: ipad, Number of mentions: 4
# Area: loud, Number of mentions: 1
# Area: plugged, Number of mentions: 1
# Area: row, Number of mentions: 49
# Area: front, Number of mentions: 36
# Area: disrupted, Number of mentions: 2
# Area: hear, Number of mentions: 5
# Area: headphone, Number of mentions: 6
# Area: thought, Number of mentions: 26
# Area: fine, Number of mentions: 20
# Area: tell, Number of mentions: 26
# Area: mom, Number of mentions: 1
# Area: acceptable, Number of mentions: 7
# Area: turned, Number of mentions: 19
# Area: zoo, Number of mentions: 2
# Area: training, Number of mentions: 6
# Area: allowed, Number of mentions: 16
# Area: disrupt, Number of mentions: 1
# Area: laughed, Number of mentions: 2
# Area: disgrace, Number of mentions: 8
# Area: ive, Number of mentions: 20
# Area: mentioned, Number of mentions: 2
# Area: bad, Number of mentions: 54
# Area: departed, Number of mentions: 9
# Area: inbound, Number of mentions: 11
# Area: economy, Number of mentions: 102
# Area: larger, Number of mentions: 3
# Area: baggage, Number of mentions: 83
# Area: making, Number of mentions: 16
# Area: complete, Number of mentions: 15
# Area: mockery, Number of mentions: 1
# Area: advertised, Number of mentions: 2
# Area: lot, Number of mentions: 33
# Area: stressed, Number of mentions: 2
# Area: missing, Number of mentions: 27
# Area: onwards, Number of mentions: 1
# Area: closed, Number of mentions: 24
# Area: disembarked, Number of mentions: 1
# Area: onboard, Number of mentions: 25
# Area: ok, Number of mentions: 26
# Area: minimal, Number of mentions: 7
# Area: gave, Number of mentions: 44
# Area: full-service, Number of mentions: 2
# Area: concerning, Number of mentions: 1
# Area: trying, Number of mentions: 46
# Area: hold, Number of mentions: 25
# Area: change, Number of mentions: 66
# Area: deal, Number of mentions: 8
# Area: non-existent, Number of mentions: 8
# Area: deliberately, Number of mentions: 1
# Area: hard, Number of mentions: 22
# Area: contact, Number of mentions: 34
# Area: hate, Number of mentions: 2
# Area: oct, Number of mentions: 1
# Area: line, Number of mentions: 50
# Area: 1200, Number of mentions: 2
# Area: fixed, Number of mentions: 3
# Area: everyone, Number of mentions: 22
# Area: call, Number of mentions: 119
# Area: .., Number of mentions: 3
# Area: via, Number of mentions: 77
# Area: tour, Number of mentions: 3
# Area: started, Number of mentions: 20
# Area: loading, Number of mentions: 2
# Area: explanation, Number of mentions: 27
# Area: may, Number of mentions: 26
# Area: april, Number of mentions: 8
# Area: 2022, Number of mentions: 11
# Area: operated, Number of mentions: 7
# Area: finnair, Number of mentions: 5
# Area: using, Number of mentions: 25
# Area: shortly, Number of mentions: 6
# Area: preferred, Number of mentions: 3
# Area: although, Number of mentions: 27
# Area: similar, Number of mentions: 7
# Area: layout, Number of mentions: 7
# Area: club, Number of mentions: 78
# Area: europe, Number of mentions: 25
# Area: i.e, Number of mentions: 2
# Area: middle, Number of mentions: 39
# Area: free, Number of mentions: 28
# Area: felt, Number of mentions: 19
# Area: legroom, Number of mentions: 25
# Area: slightly, Number of mentions: 3
# Area: better, Number of mentions: 47
# Area: meal, Number of mentions: 89
# Area: chose, Number of mentions: 7
# Area: beef, Number of mentions: 3
# Area: cheek, Number of mentions: 1
# Area: passed, Number of mentions: 11
# Area: passport, Number of mentions: 14
# Area: control, Number of mentions: 15
# Area: without, Number of mentions: 59
# Area: designated, Number of mentions: 2
# Area: reclaim, Number of mentions: 4
# Area: ten, Number of mentions: 7
# Area: went, Number of mentions: 45
# Area: counter, Number of mentions: 25
# Area: going, Number of mentions: 46
# Area: seemed, Number of mentions: 22
# Area: unaware, Number of mentions: 1
# Area: issue, Number of mentions: 54
# Area: find, Number of mentions: 65
# Area: various, Number of mentions: 6
# Area: requested, Number of mentions: 17
# Area: information, Number of mentions: 44
# Area: despite, Number of mentions: 43
# Area: list, Number of mentions: 3
# Area: almost, Number of mentions: 31
# Area: 2½, Number of mentions: 1
# Area: frustrating, Number of mentions: 5
# Area: say, Number of mentions: 42
# Area: least, Number of mentions: 37
# Area: subsequently, Number of mentions: 1
# Area: complained, Number of mentions: 13
# Area: automated, Number of mentions: 6
# Area: ‘, Number of mentions: 8
# Area: experiencing, Number of mentions: 2
# Area: exceptionally, Number of mentions: 4
# Area: high, Number of mentions: 11
# Area: volume, Number of mentions: 3
# Area: response, Number of mentions: 26
# Area: centre, Number of mentions: 19
# Area: atrocious, Number of mentions: 3
# Area: sometimes, Number of mentions: 4
# Area: callous, Number of mentions: 2
# Area: anybody, Number of mentions: 2
# Area: cut, Number of mentions: 13
# Area: halfway, Number of mentions: 3
# Area: resolution, Number of mentions: 5
# Area: anyway, Number of mentions: 7
# Area: nobody, Number of mentions: 6
# Area: so-so, Number of mentions: 1
# Area: haul, Number of mentions: 20
# Area: semi-low, Number of mentions: 1
# Area: cost, Number of mentions: 62
# Area: confusing, Number of mentions: 5
# Area: expect, Number of mentions: 21
# Area: snack, Number of mentions: 25
# Area: whilst, Number of mentions: 11
# Area: else, Number of mentions: 23
# Area: paid, Number of mentions: 82
# Area: yet, Number of mentions: 30
# Area: apparently, Number of mentions: 18
# Area: pre-order, Number of mentions: 2
# Area: additional, Number of mentions: 22
# Area: dependable, Number of mentions: 1
# Area: theory, Number of mentions: 2
# Area: generous, Number of mentions: 2
# Area: compared, Number of mentions: 8
# Area: competitor, Number of mentions: 3
# Area: space, Number of mentions: 21
# Area: overhead, Number of mentions: 8
# Area: leading, Number of mentions: 3
# Area: whole, Number of mentions: 27
# Area: offering, Number of mentions: 19
# Area: well, Number of mentions: 48
# Area: supply, Number of mentions: 2
# Area: throughout, Number of mentions: 14
# Area: contrary, Number of mentions: 1
# Area: seatbelt, Number of mentions: 3
# Area: sight, Number of mentions: 2
# Area: pointless, Number of mentions: 1
# Area: providing, Number of mentions: 5
# Area: socket, Number of mentions: 2
# Area: abandon, Number of mentions: 2
# Area: fail, Number of mentions: 4
# Area: deemed, Number of mentions: 1
# Area: star, Number of mentions: 4
# Area: punta, Number of mentions: 2
# Area: cana, Number of mentions: 2
# Area: trouble, Number of mentions: 4
# Area: outbound, Number of mentions: 18
# Area: gatwick, Number of mentions: 29
# Area: realised, Number of mentions: 5
# Area: sitting, Number of mentions: 20
# Area: spent, Number of mentions: 33
# Area: reserving, Number of mentions: 1
# Area: number, Number of mentions: 62
# Area: automatically, Number of mentions: 6
# Area: reallocated, Number of mentions: 1
# Area: particular, Number of mentions: 3
# Area: swapped, Number of mentions: 1
# Area: couple, Number of mentions: 19
# Area: form, Number of mentions: 22
# Area: n, Number of mentions: 1
# Area: £100, Number of mentions: 3
# Area: didnt, Number of mentions: 38
# Area: accept, Number of mentions: 15
# Area: naturally, Number of mentions: 2
# Area: wanted, Number of mentions: 23
# Area: eventually, Number of mentions: 21
# Area: fight, Number of mentions: 4
# Area: second, Number of mentions: 21
# Area: rate, Number of mentions: 8
# Area: shoddy, Number of mentions: 2
# Area: downgraded, Number of mentions: 7
# Area: premium, Number of mentions: 66
# Area: 200, Number of mentions: 4
# Area: 400, Number of mentions: 2
# Area: aud, Number of mentions: 3
# Area: 3000, Number of mentions: 2
# Area: 6500, Number of mentions: 1
# Area: owe, Number of mentions: 4
# Area: 1500, Number of mentions: 1
# Area: fair, Number of mentions: 5
# Area: 3250, Number of mentions: 1
# Area: downgrade, Number of mentions: 3
# Area: insulting, Number of mentions: 2
# Area: incredibly, Number of mentions: 7
# Area: painful, Number of mentions: 2
# Area: cancer, Number of mentions: 1
# Area: operation, Number of mentions: 2
# Area: injury, Number of mentions: 5
# Area: pointed, Number of mentions: 6
# Area: need, Number of mentions: 38
# Area: lie, Number of mentions: 14
# Area: numbing, Number of mentions: 1
# Area: insult, Number of mentions: 6
# Area: slap, Number of mentions: 1
# Area: face, Number of mentions: 13
# Area: continue, Number of mentions: 8
# Area: degradation, Number of mentions: 1
# Area: dealt, Number of mentions: 5
# Area: earth, Number of mentions: 2
# Area: honest, Number of mentions: 3
# Area: working, Number of mentions: 26
# Area: actual, Number of mentions: 3
# Area: warm, Number of mentions: 6
# Area: friendly, Number of mentions: 15
# Area: operates, Number of mentions: 3
# Area: medieval, Number of mentions: 1
# Area: torture, Number of mentions: 1
# Area: already, Number of mentions: 41
# Area: apart, Number of mentions: 10
# Area: logo, Number of mentions: 1
# Area: rear, Number of mentions: 4
# Area: fuselage, Number of mentions: 1
# Area: indication, Number of mentions: 4
# Area: carrier, Number of mentions: 18
# Area: farce, Number of mentions: 2
# Area: group, Number of mentions: 14
# Area: queue, Number of mentions: 51
# Area: wrong, Number of mentions: 26
# Area: interior, Number of mentions: 3
# Area: reminiscent, Number of mentions: 1
# Area: twenty, Number of mentions: 4
# Area: except, Number of mentions: 8
# Area: tight, Number of mentions: 7
# Area: uncomfortable, Number of mentions: 37
# Area: seating, Number of mentions: 22
# Area: feel, Number of mentions: 16
# Area: luxurious, Number of mentions: 1
# Area: unknown, Number of mentions: 1
# Area: charter, Number of mentions: 2
# Area: usual, Number of mentions: 17
# Area: ran, Number of mentions: 12
# Area: theyd, Number of mentions: 1
# Area: reached, Number of mentions: 9
# Area: 24., Number of mentions: 1
# Area: tea, Number of mentions: 19
# Area: appeared, Number of mentions: 12
# Area: thank, Number of mentions: 2
# Area: goodness, Number of mentions: 1
# Area: purchased, Number of mentions: 9
# Area: officious, Number of mentions: 1
# Area: senior, Number of mentions: 1
# Area: attendant, Number of mentions: 30
# Area: whod, Number of mentions: 1
# Area: facilitating, Number of mentions: 1
# Area: slammed, Number of mentions: 1
# Area: armrest, Number of mentions: 2
# Area: mid, Number of mentions: 3
# Area: cattle, Number of mentions: 4
# Area: definitely, Number of mentions: 8
# Area: happy, Number of mentions: 6
# Area: land, Number of mentions: 3
# Area: understatement, Number of mentions: 1
# Area: real, Number of mentions: 7
# Area: fill, Number of mentions: 7
# Area: bin, Number of mentions: 6
# Area: supposed, Number of mentions: 22
# Area: bother, Number of mentions: 6
# Area: implementing, Number of mentions: 1
# Area: rule, Number of mentions: 7
# Area: subsequent, Number of mentions: 4
# Area: mill, Number of mentions: 1
# Area: aisle, Number of mentions: 24
# Area: bumping, Number of mentions: 3
# Area: searching, Number of mentions: 3
# Area: result, Number of mentions: 15
# Area: nonsense, Number of mentions: 2
# Area: incoming, Number of mentions: 3
# Area: 90, Number of mentions: 9
# Area: glasgow, Number of mentions: 14
# Area: canceled, Number of mentions: 10
# Area: 12, Number of mentions: 24
# Area: discovered, Number of mentions: 8
# Area: soaking, Number of mentions: 2
# Area: wet, Number of mentions: 3
# Area: content, Number of mentions: 1
# Area: air, Number of mentions: 40
# Area: dried, Number of mentions: 4
# Area: allocated, Number of mentions: 5
# Area: toilet, Number of mentions: 14
# Area: galley, Number of mentions: 8
# Area: chance, Number of mentions: 6
# Area: possible, Number of mentions: 21
# Area: movement, Number of mentions: 1
# Area: ignored, Number of mentions: 10
# Area: bumped, Number of mentions: 8
# Area: walking, Number of mentions: 1
# Area: pushing, Number of mentions: 4
# Area: kart, Number of mentions: 1
# Area: apology, Number of mentions: 15
# Area: compartment, Number of mentions: 3
# Area: standard, Number of mentions: 25
# Area: decline, Number of mentions: 7
# Area: min, Number of mentions: 37
# Area: norm, Number of mentions: 3
# Area: rude, Number of mentions: 36
# Area: clueless, Number of mentions: 7
# Area: grubby, Number of mentions: 1
# Area: cleaning, Number of mentions: 3
# Area: cope, Number of mentions: 1
# Area: cutback, Number of mentions: 4
# Area: apply, Number of mentions: 1
# Area: become, Number of mentions: 11
# Area: truly, Number of mentions: 6
# Area: 35, Number of mentions: 2
# Area: veteran, Number of mentions: 1
# Area: user, Number of mentions: 2
# Area: alex, Number of mentions: 2
# Area: cruz, Number of mentions: 2
# Area: cutting, Number of mentions: 4
# Area: past, Number of mentions: 15
# Area: quickly, Number of mentions: 12
# Area: latest, Number of mentions: 5
# Area: ceo, Number of mentions: 7
# Area: read, Number of mentions: 5
# Area: occasional, Number of mentions: 1
# Area: article, Number of mentions: 1
# Area: improving, Number of mentions: 1
# Area: substantive, Number of mentions: 1
# Area: amongst, Number of mentions: 3
# Area: maybe, Number of mentions: 4
# Area: name, Number of mentions: 17
# Area: give, Number of mentions: 36
# Area: flag, Number of mentions: 3
# Area: proper, Number of mentions: 3
# Area: low-cost, Number of mentions: 2
# Area: sadly, Number of mentions: 7
# Area: declined, Number of mentions: 7
# Area: remains, Number of mentions: 5
# Area: surprised, Number of mentions: 5
# Area: &, Number of mentions: 22
# Area: co, Number of mentions: 4
# Area: produce, Number of mentions: 3
# Area: rubbish, Number of mentions: 8
# Area: sampled, Number of mentions: 1
# Area: turkish, Number of mentions: 4
# Area: equivalent, Number of mentions: 6
# Area: august, Number of mentions: 24
# Area: superb, Number of mentions: 1
# Area: guessing, Number of mentions: 1
# Area: avoided, Number of mentions: 2
# Area: staffed, Number of mentions: 5
# Area: chaotic, Number of mentions: 9
# Area: overfull, Number of mentions: 1
# Area: couldnt, Number of mentions: 27
# Area: unmanaged, Number of mentions: 1
# Area: served, Number of mentions: 36
# Area: take-off, Number of mentions: 2
# Area: race, Number of mentions: 2
# Area: bottom, Number of mentions: 6
# Area: cheapskate, Number of mentions: 1
# Area: stake, Number of mentions: 1
# Area: looking, Number of mentions: 14
# Area: forward, Number of mentions: 12
# Area: reliable, Number of mentions: 3
# Area: trust, Number of mentions: 3
# Area: timing, Number of mentions: 2
# Area: 6.45am, Number of mentions: 1
# Area: engine, Number of mentions: 3
# Area: risking, Number of mentions: 2
# Area: meeting, Number of mentions: 8
# Area: geneva, Number of mentions: 7
# Area: come, Number of mentions: 28
# Area: bring, Number of mentions: 5
# Area: funny, Number of mentions: 2
# Area: another, Number of mentions: 111
# Area: spring, Number of mentions: 1
# Area: 2023, Number of mentions: 12
# Area: amsterdam, Number of mentions: 20
# Area: put, Number of mentions: 40
# Area: several, Number of mentions: 27
# Area: stress, Number of mentions: 6
# Area: end, Number of mentions: 28
# Area: dramatic, Number of mentions: 1
# Area: unlucky, Number of mentions: 3
# Area: today, Number of mentions: 20
# Area: routine, Number of mentions: 2
# Area: reading, Number of mentions: 2
# Area: review, Number of mentions: 11
# Area: im, Number of mentions: 16
# Area: traveller, Number of mentions: 15
# Area: word, Number of mentions: 11
# Area: abysmal, Number of mentions: 3
# Area: stuck, Number of mentions: 13
# Area: athens, Number of mentions: 12
# Area: sat, Number of mentions: 19
# Area: run, Number of mentions: 17
# Area: lentil, Number of mentions: 1
# Area: pie, Number of mentions: 3
# Area: green, Number of mentions: 2
# Area: curry, Number of mentions: 2
# Area: returning, Number of mentions: 5
# Area: promised, Number of mentions: 14
# Area: 3hrs, Number of mentions: 4
# Area: overbooked, Number of mentions: 7
# Area: basically, Number of mentions: 7
# Area: fails, Number of mentions: 1
# Area: deliver, Number of mentions: 7
# Area: national, Number of mentions: 8
# Area: implore, Number of mentions: 1
# Area: alternative, Number of mentions: 28
# Area: life, Number of mentions: 15
# Area: mxp, Number of mentions: 3
# Area: train, Number of mentions: 13
# Area: heart, Number of mentions: 1
# Area: attack, Number of mentions: 1
# Area: stayed, Number of mentions: 4
# Area: upon, Number of mentions: 18
# Area: arrival, Number of mentions: 42
# Area: sjc, Number of mentions: 3
# Area: filled, Number of mentions: 7
# Area: employee, Number of mentions: 15
# Area: receipt, Number of mentions: 7
# Area: simply, Number of mentions: 23
# Area: answer, Number of mentions: 23
# Area: called, Number of mentions: 52
# Area: twice, Number of mentions: 7
# Area: toll, Number of mentions: 1
# Area: realized, Number of mentions: 3
# Area: delivery, Number of mentions: 4
# Area: address, Number of mentions: 10
# Area: enter, Number of mentions: 5
# Area: dealing, Number of mentions: 5
# Area: shitty, Number of mentions: 1
# Area: buy, Number of mentions: 17
# Area: clothes, Number of mentions: 10
# Area: expecting, Number of mentions: 4
# Area: happened, Number of mentions: 23
# Area: neither, Number of mentions: 3
# Area: positive, Number of mentions: 3
# Area: side, Number of mentions: 8
# Area: obviously, Number of mentions: 7
# Area: justify, Number of mentions: 2
# Area: treatment, Number of mentions: 6
# Area: knew, Number of mentions: 3
# Area: worn, Number of mentions: 13
# Area: dallas, Number of mentions: 3
# Area: multiple, Number of mentions: 17
# Area: electronics, Number of mentions: 2
# Area: non, Number of mentions: 10
# Area: functional, Number of mentions: 2
# Area: designed, Number of mentions: 3
# Area: dubrovnik, Number of mentions: 1
# Area: tray, Number of mentions: 13
# Area: blocking, Number of mentions: 1
# Area: coach, Number of mentions: 11
# Area: technical, Number of mentions: 10
# Area: slipped, Number of mentions: 2
# Area: 17:00, Number of mentions: 1
# Area: 20:00, Number of mentions: 1
# Area: 22:00, Number of mentions: 1
# Area: zero, Number of mentions: 7
# Area: odds, Number of mentions: 1
# Area: booted, Number of mentions: 2
# Area: uk, Number of mentions: 19
# Area: closing, Number of mentions: 3
# Area: sign, Number of mentions: 8
# Area: passing, Number of mentions: 3
# Area: engineer, Number of mentions: 4
# Area: helped, Number of mentions: 7
# Area: locate, Number of mentions: 5
# Area: washed, Number of mentions: 3
# Area: contravention, Number of mentions: 1
# Area: caa, Number of mentions: 2
# Area: slept, Number of mentions: 2
# Area: bus, Number of mentions: 27
# Area: stop, Number of mentions: 10
# Area: overnight, Number of mentions: 18
# Area: young, Number of mentions: 7
# Area: somewhere, Number of mentions: 3
# Area: stay, Number of mentions: 15
# Area: following, Number of mentions: 19
# Area: admin, Number of mentions: 1
# Area: liquid, Number of mentions: 2
# Area: 1/2, Number of mentions: 3
# Area: shockingly, Number of mentions: 3
# Area: experienced, Number of mentions: 12
# Area: miami, Number of mentions: 11
# Area: florida, Number of mentions: 2
# Area: dublin, Number of mentions: 18
# Area: ireland, Number of mentions: 1
# Area: occupied, Number of mentions: 4
# Area: total, Number of mentions: 27
# Area: roughly, Number of mentions: 2
# Area: challenge, Number of mentions: 2
# Area: 73, Number of mentions: 1
# Area: headed, Number of mentions: 2
# Area: stopped, Number of mentions: 8
# Area: security, Number of mentions: 22
# Area: personnel, Number of mentions: 5
# Area: checkpoint, Number of mentions: 2
# Area: ushered, Number of mentions: 2
# Area: rebooked, Number of mentions: 38
# Area: busy, Number of mentions: 12
# Area: weekend, Number of mentions: 5
# Area: reimbursed, Number of mentions: 8
# Area: city, Number of mentions: 15
# Area: filed, Number of mentions: 8
# Area: plenty, Number of mentions: 8
# Area: therefore, Number of mentions: 7
# Area: denied, Number of mentions: 7
# Area: 20, Number of mentions: 14
# Area: timeframe, Number of mentions: 1
# Area: person, Number of mentions: 35
# Area: policy, Number of mentions: 8
# Area: close, Number of mentions: 19
# Area: feedback, Number of mentions: 2
# Area: site, Number of mentions: 9
# Area: appears, Number of mentions: 6
# Area: overwhelming, Number of mentions: 1
# Area: sentiment, Number of mentions: 1
# Area: prague, Number of mentions: 4
# Area: came, Number of mentions: 28
# Area: unusual, Number of mentions: 1
# Area: picture, Number of mentions: 2
# Area: hardly, Number of mentions: 9
# Area: block, Number of mentions: 5
# Area: horrible, Number of mentions: 30
# Area: addition, Number of mentions: 6
# Area: clerk, Number of mentions: 3
# Area: yell, Number of mentions: 1
# Area: excused, Number of mentions: 1
# Area: bit, Number of mentions: 13
# Area: priority, Number of mentions: 11
# Area: fun, Number of mentions: 2
# Area: began, Number of mentions: 9
# Area: walk, Number of mentions: 6
# Area: asking, Number of mentions: 13
# Area: virtually, Number of mentions: 4
# Area: weather, Number of mentions: 12
# Area: comfortably, Number of mentions: 4
# Area: store, Number of mentions: 2
# Area: holder, Number of mentions: 6
# Area: keep, Number of mentions: 11
# Area: button, Number of mentions: 6
# Area: outlet, Number of mentions: 2
# Area: internet, Number of mentions: 7
# Area: heavy, Number of mentions: 4
# Area: hernia, Number of mentions: 1
# Area: weekly, Number of mentions: 1
# Area: want, Number of mentions: 29
# Area: frankly, Number of mentions: 4
# Area: someone, Number of mentions: 43
# Area: traffic, Number of mentions: 2
# Area: heard, Number of mentions: 10
# Area: understand, Number of mentions: 19
# Area: world, Number of mentions: 38
# Area: traveled, Number of mentions: 8
# Area: shame, Number of mentions: 14
# Area: watched, Number of mentions: 4
# Area: fall, Number of mentions: 3
# Area: cliff, Number of mentions: 1
# Area: advice, Number of mentions: 5
# Area: anyone, Number of mentions: 23
# Area: exercise, Number of mentions: 1
# Area: schedule, Number of mentions: 8
# Area: destination, Number of mentions: 22
# Area: everything, Number of mentions: 19
# Area: runway, Number of mentions: 6
# Area: pilot, Number of mentions: 13
# Area: announce, Number of mentions: 2
# Area: tried, Number of mentions: 53
# Area: evacuated, Number of mentions: 1
# Area: worry, Number of mentions: 2
# Area: special, Number of mentions: 8
# Area: set, Number of mentions: 5
# Area: saturday, Number of mentions: 5
# Area: 8pm, Number of mentions: 3
# Area: application, Number of mentions: 2
# Area: app, Number of mentions: 32
# Area: disassociate, Number of mentions: 1
# Area: saw, Number of mentions: 8
# Area: 10:30pm, Number of mentions: 1
# Area: 700gbp, Number of mentions: 1
# Area: 8, Number of mentions: 21
# Area: jet, Number of mentions: 4
# Area: lag, Number of mentions: 1
# Area: insane, Number of mentions: 2
# Area: reimbursement, Number of mentions: 10
# Area: havent, Number of mentions: 5
# Area: since, Number of mentions: 67
# Area: idea, Number of mentions: 8
# Area: ill, Number of mentions: 5
# Area: claiming, Number of mentions: 3
# Area: emotional, Number of mentions: 1
# Area: situation, Number of mentions: 21
# Area: indifference, Number of mentions: 5
# Area: financially, Number of mentions: 2
# Area: difficult, Number of mentions: 23
# Area: right, Number of mentions: 15
# Area: salary, Number of mentions: 2
# Area: impossible, Number of mentions: 10
# Area: reach, Number of mentions: 16
# Area: 26, Number of mentions: 7
# Area: trapped, Number of mentions: 2
# Area: solution, Number of mentions: 6
# Area: initial, Number of mentions: 3
# Area: rescheduled, Number of mentions: 3
# Area: hamburg, Number of mentions: 6
# Area: la, Number of mentions: 5
# Area: vega, Number of mentions: 5
# Area: transfer, Number of mentions: 11
# Area: dropped, Number of mentions: 3
# Area: closest, Number of mentions: 1
# Area: opened, Number of mentions: 3
# Area: single, Number of mentions: 14
# Area: future, Number of mentions: 15
# Area: share, Number of mentions: 2
# Area: story, Number of mentions: 3
# Area: july, Number of mentions: 10
# Area: lax, Number of mentions: 14
# Area: disappointing, Number of mentions: 24
# Area: refusal, Number of mentions: 2
# Area: arrangement, Number of mentions: 8
# Area: italy, Number of mentions: 6
# Area: 7, Number of mentions: 23
# Area: september, Number of mentions: 6
# Area: tambo, Number of mentions: 1
# Area: international, Number of mentions: 8
# Area: checked-in, Number of mentions: 1
# Area: previous, Number of mentions: 11
# Area: evening, Number of mentions: 18
# Area: off-loaded, Number of mentions: 1
# Area: beforehand, Number of mentions: 1
# Area: team, Number of mentions: 15
# Area: check-in, Number of mentions: 48
# Area: manage, Number of mentions: 5
# Area: lufthansa, Number of mentions: 4
# Area: frankfurt, Number of mentions: 12
# Area: moving, Number of mentions: 3
# Area: whether, Number of mentions: 8
# Area: valid, Number of mentions: 6
# Area: assured, Number of mentions: 5
# Area: correct, Number of mentions: 11
# Area: south, Number of mentions: 6
# Area: africa, Number of mentions: 4
# Area: 18, Number of mentions: 4
# Area: checking, Number of mentions: 11
# Area: noticed, Number of mentions: 3
# Area: account, Number of mentions: 9
# Area: milan, Number of mentions: 5
# Area: johannesburg, Number of mentions: 11
# Area: spending, Number of mentions: 9
# Area: helpline, Number of mentions: 5
# Area: operator, Number of mentions: 10
# Area: picked, Number of mentions: 5
# Area: instance, Number of mentions: 1
# Area: moment, Number of mentions: 9
# Area: proceed, Number of mentions: 3
# Area: currently, Number of mentions: 3
# Area: monday, Number of mentions: 5
# Area: daughter, Number of mentions: 7
# Area: march, Number of mentions: 15
# Area: 25, Number of mentions: 13
# Area: victoria, Number of mentions: 1
# Area: canada, Number of mentions: 6
# Area: agent, Number of mentions: 33
# Area: try, Number of mentions: 32
# Area: expedia, Number of mentions: 7
# Area: finding, Number of mentions: 4
# Area: 24, Number of mentions: 28
# Area: numerous, Number of mentions: 10
# Area: 9, Number of mentions: 8
# Area: unbelievable, Number of mentions: 5
# Area: best, Number of mentions: 12
# Area: allow, Number of mentions: 15
# Area: routing, Number of mentions: 1
# Area: segment, Number of mentions: 1
# Area: nine, Number of mentions: 3
# Area: major, Number of mentions: 5
# Area: school, Number of mentions: 3
# Area: penalty, Number of mentions: 4
# Area: expense, Number of mentions: 20
# Area: staying, Number of mentions: 5
# Area: submitted, Number of mentions: 5
# Area: supporting, Number of mentions: 1
# Area: document, Number of mentions: 15
# Area: reply, Number of mentions: 8
# Area: follow, Number of mentions: 10
# Area: shocking, Number of mentions: 10
# Area: thousand, Number of mentions: 3
# Area: decade, Number of mentions: 4
# Area: patient, Number of mentions: 4
# Area: commented, Number of mentions: 2
# Area: type, Number of mentions: 11
# Area: forum, Number of mentions: 1
# Area: think, Number of mentions: 10
# Area: public, Number of mentions: 3
# Area: aware, Number of mentions: 7
# Area: extremely, Number of mentions: 23
# Area: 9th, Number of mentions: 5
# Area: peak, Number of mentions: 3
# Area: holiday, Number of mentions: 27
# Area: period, Number of mentions: 4
# Area: management, Number of mentions: 10
# Area: standing, Number of mentions: 13
# Area: provide, Number of mentions: 26
# Area: 4/4, Number of mentions: 1
# ...
# Area: comprehension, Number of mentions: 1
# Area: invest, Number of mentions: 1
# Area: palma, Number of mentions: 1
# Area: presumably, Number of mentions: 3
# Area: recur, Number of mentions: 1
# Area: preferably, Number of mentions: 1
# Area: fatuously, Number of mentions: 1
# Area: interview, Number of mentions: 1
# Area: guiding, Number of mentions: 1
# Area: eco-friendly, Number of mentions: 1
# Area: consisted, Number of mentions: 1
# Area: shortbread, Number of mentions: 1
# Area: biscuit, Number of mentions: 1
# Area: firmly, Number of mentions: 1
# Area: bucket, Number of mentions: 1
# Area: beaten, Number of mentions: 1
# Area: faro, Number of mentions: 2
# Area: enjoy, Number of mentions: 2
# Area: rely, Number of mentions: 1
# Area: chilled, Number of mentions: 1
# Area: kuwait, Number of mentions: 2
# Area: lasted, Number of mentions: 2
# Area: 3am, Number of mentions: 1
# Area: grab, Number of mentions: 1
# Area: apartment, Number of mentions: 1
# Area: 777-300er, Number of mentions: 1
# Area: negatively, Number of mentions: 1
# Area: television, Number of mentions: 1
# Area: abundant, Number of mentions: 1
# Area: delicious, Number of mentions: 1
# Area: asks, Number of mentions: 2
# Area: toba, Number of mentions: 1
# Area: shrug, Number of mentions: 1
# Area: advertising, Number of mentions: 1
# Area: admits, Number of mentions: 1
# Area: advises, Number of mentions: 1
# Area: accepts, Number of mentions: 1
# Area: chatting, Number of mentions: 2
# Area: shout, Number of mentions: 1
# Area: perform, Number of mentions: 1
# Area: preparing, Number of mentions: 1
# Area: offensive, Number of mentions: 1
# Area: shocker, Number of mentions: 1
# Area: 747-400., Number of mentions: 2
# Area: collapsing, Number of mentions: 1
# Area: dozen, Number of mentions: 1
# Area: north, Number of mentions: 1
# Area: furthest, Number of mentions: 1
# Area: rugby, Number of mentions: 1
# Area: scrum, Number of mentions: 1
# Area: existence, Number of mentions: 1
# Area: toothpaste, Number of mentions: 1
# Area: toothbrush, Number of mentions: 1
# Area: invitation, Number of mentions: 1
# Area: awake, Number of mentions: 1
# Area: lisbon, Number of mentions: 1
# Area: cod, Number of mentions: 1
# Area: apologising, Number of mentions: 1
# Area: marseille, Number of mentions: 2
# Area: refunding, Number of mentions: 1
# Area: 28, Number of mentions: 1
# Area: towel, Number of mentions: 1
# Area: jacket, Number of mentions: 1
# Area: backpack, Number of mentions: 1
# Area: x2.5, Number of mentions: 1
# Area: 8.50pm, Number of mentions: 1
# Area: ❎, Number of mentions: 1
# Area: olbia, Number of mentions: 1
# Area: sardinia, Number of mentions: 3
# Area: penned, Number of mentions: 1
# Area: heat, Number of mentions: 2
# Area: overwhelmed, Number of mentions: 1
# Area: hydration, Number of mentions: 1
# Area: stage, Number of mentions: 1
# Area: perplexed, Number of mentions: 1
# Area: catching, Number of mentions: 2
# Area: worried, Number of mentions: 1
# Area: energy, Number of mentions: 1
# Area: repaired, Number of mentions: 1
# Area: 42, Number of mentions: 1
# Area: opportunity, Number of mentions: 2
# Area: fortunately, Number of mentions: 1
# Area: dirham, Number of mentions: 1
# Area: £3,8, Number of mentions: 1
# Area: seoul, Number of mentions: 1
# Area: long-hauls, Number of mentions: 1
# Area: simy, Number of mentions: 1
# Area: croweed, Number of mentions: 1
# Area: malfunction, Number of mentions: 2
# Area: unfolded, Number of mentions: 1
# Area: lay, Number of mentions: 1
# Area: 23.4kg, Number of mentions: 1
# Area: 23kg, Number of mentions: 1
# Area: repackage, Number of mentions: 1
# Area: b747, Number of mentions: 1
# Area: 20.gbp, Number of mentions: 1
# Area: exemplifies, Number of mentions: 1
# Area: nashville, Number of mentions: 3
# Area: trans-atlantic, Number of mentions: 1
# Area: ostensibly, Number of mentions: 1
# Area: ying-yang, Number of mentions: 1
# Area: seek, Number of mentions: 1
# Area: generated, Number of mentions: 1
# Area: haggle, Number of mentions: 1
# Area: woeful, Number of mentions: 2
# Area: witness, Number of mentions: 1
# Area: newcastle, Number of mentions: 1
# Area: proportion, Number of mentions: 1
# Area: adjacent, Number of mentions: 5
# Area: deigned, Number of mentions: 1
# Area: eternity, Number of mentions: 1
# Area: slower, Number of mentions: 1
# Area: jet2, Number of mentions: 1
# Area: counted, Number of mentions: 1
# Area: wording, Number of mentions: 1
# Area: cap, Number of mentions: 1
# Area: boyfriend, Number of mentions: 1
# Area: glitch, Number of mentions: 1
# Area: 275, Number of mentions: 1
# Area: 550, Number of mentions: 1
# Area: 1hr, Number of mentions: 1
# Area: slimy, Number of mentions: 1
# Area: smear, Number of mentions: 1
# Area: disclosed, Number of mentions: 1
# Area: irritating, Number of mentions: 1
# Area: sofia, Number of mentions: 3
# Area: re-enter, Number of mentions: 2
# Area: contradicted, Number of mentions: 1
# Area: derisory, Number of mentions: 1
# Area: correctly, Number of mentions: 1
# Area: occasionally, Number of mentions: 1
# Area: maximum, Number of mentions: 1
# Area: handset, Number of mentions: 1
# Area: auckland, Number of mentions: 1
# Area: lemon, Number of mentions: 1
# Area: forgot, Number of mentions: 1
# Area: helpdesk, Number of mentions: 1
# Area: nicely, Number of mentions: 1
# Area: airines, Number of mentions: 1
# Area: 39, Number of mentions: 1
# Area: tenerife, Number of mentions: 1
# Area: madness, Number of mentions: 1
# Area: self, Number of mentions: 1
# Area: destruct, Number of mentions: 1
# Area: shame.have, Number of mentions: 1
# Area: shanghai, Number of mentions: 1
# Area: crumb, Number of mentions: 1
# Area: jal, Number of mentions: 1
# Area: bedding, Number of mentions: 1
# Area: reunited, Number of mentions: 1
# Area: celebrate, Number of mentions: 1
# Area: 60th, Number of mentions: 2
# Area: birthday, Number of mentions: 2
# Area: anniversary, Number of mentions: 1
# Area: heartbreaking, Number of mentions: 1
# Area: 8am, Number of mentions: 1
# Area: 1pm, Number of mentions: 1
# Area: 2:30, Number of mentions: 2
# Area: houston, Number of mentions: 1
# Area: safely, Number of mentions: 1
# Area: buzzed, Number of mentions: 1
# Area: fetched, Number of mentions: 1
# Area: scrabbled, Number of mentions: 1
# Area: cane, Number of mentions: 1
# Area: thai, Number of mentions: 2
# Area: eva, Number of mentions: 1
# Area: surname, Number of mentions: 1
# Area: makeup, Number of mentions: 1
# Area: sponge, Number of mentions: 1
# Area: film/tv, Number of mentions: 1
# Area: congealed, Number of mentions: 1
# Area: dessert, Number of mentions: 1
# Area: expects, Number of mentions: 1
# Area: eu, Number of mentions: 1
# Area: argued, Number of mentions: 1
# Area: sickness, Number of mentions: 2
# Area: extraordinary, Number of mentions: 2
# Area: comparable, Number of mentions: 1
# Area: court, Number of mentions: 1
# Area: precedence, Number of mentions: 1
# Area: contingency, Number of mentions: 1
# Area: strategy, Number of mentions: 1
# Area: talked, Number of mentions: 1
# Area: investing, Number of mentions: 1
# Area: iag, Number of mentions: 2
# Area: integrate, Number of mentions: 1
# Area: reflected, Number of mentions: 1
# Area: rated, Number of mentions: 2
# Area: 747., Number of mentions: 1
# Area: video, Number of mentions: 2
# Area: ande, Number of mentions: 1
# Area: 1.5h, Number of mentions: 1
# Area: charm, Number of mentions: 1
# Area: cafeteria, Number of mentions: 1
# Area: orderly, Number of mentions: 1
# Area: organized, Number of mentions: 1
# Area: 788, Number of mentions: 1
# Area: experieinced, Number of mentions: 1
# Area: compete, Number of mentions: 1
# Area: insulted, Number of mentions: 1
# Area: barebones, Number of mentions: 1
# Area: angled, Number of mentions: 1
# Area: private, Number of mentions: 1
# Area: stretched, Number of mentions: 1
# Area: stowed, Number of mentions: 1
# Area: press, Number of mentions: 1
# Area: indifferent, Number of mentions: 2
# Area: unresponsive, Number of mentions: 1
# Area: nuisance, Number of mentions: 1
# Area: tourist, Number of mentions: 1
# Area: prioritize, Number of mentions: 1
# Area: hour-departure, Number of mentions: 1
# Area: 7.15, Number of mentions: 1
# Area: nearer, Number of mentions: 1
# Area: long-so, Number of mentions: 1
# Area: combination, Number of mentions: 1
# Area: eur, Number of mentions: 1
# Area: travlled, Number of mentions: 1
# Area: cyprus, Number of mentions: 1
# Area: identified, Number of mentions: 2
# Area: grace, Number of mentions: 1
# Area: crew-particularly, Number of mentions: 1
# Area: manager-who, Number of mentions: 1
# Area: ba289, Number of mentions: 1
# Area: 1835., Number of mentions: 1
# Area: 1940., Number of mentions: 1
# Area: ontario, Number of mentions: 1
# Area: california, Number of mentions: 2
# Area: 2030., Number of mentions: 1
# Area: departs, Number of mentions: 1
# Area: 2037., Number of mentions: 1
# Area: drove, Number of mentions: 1
# Area: £4000, Number of mentions: 1
# Area: cologne, Number of mentions: 1
# Area: suggests, Number of mentions: 1
# Area: caribbean, Number of mentions: 1
# Area: celebration, Number of mentions: 2
# Area: spoil, Number of mentions: 1
# Area: wed, Number of mentions: 1
# Area: overbooking, Number of mentions: 2
# Area: defending, Number of mentions: 1
# Area: fuming, Number of mentions: 1
# Area: exacerbated, Number of mentions: 1
# Area: webiste, Number of mentions: 1
# Area: rare, Number of mentions: 1
# Area: contradicts, Number of mentions: 1
# Area: season, Number of mentions: 1
# Area: higher, Number of mentions: 1
# Area: bidder, Number of mentions: 1
# Area: dramatically, Number of mentions: 1
# Area: preserve, Number of mentions: 1
# Area: gloss, Number of mentions: 1
# Area: accountant, Number of mentions: 1
# Area: win, Number of mentions: 1
# Area: vote, Number of mentions: 1
# Area: £40, Number of mentions: 1
# Area: laugh, Number of mentions: 1
# Area: performance, Number of mentions: 1
# Area: lumbar, Number of mentions: 1
# Area: seatback, Number of mentions: 1
# Area: claustrophobic, Number of mentions: 1
# Area: bottled, Number of mentions: 1
# Area: convenience, Number of mentions: 1
# Area: bos, Number of mentions: 2
# Area: edi, Number of mentions: 1
# Area: snippy, Number of mentions: 1
# Area: £56, Number of mentions: 1
# Area: bassinet, Number of mentions: 2
# Area: differed, Number of mentions: 1
# Area: condescending, Number of mentions: 1
# Area: blank, Number of mentions: 1
# Area: continuing, Number of mentions: 2
# Area: noted, Number of mentions: 1
# Area: minor, Number of mentions: 1
# Area: airworthiness, Number of mentions: 1
# Area: licensed, Number of mentions: 1
# Area: thanked, Number of mentions: 1
# Area: famed, Number of mentions: 1
# Area: 52, Number of mentions: 1
# Area: 8st, Number of mentions: 1
# Area: fashioned, Number of mentions: 1
# Area: streamed, Number of mentions: 1
# Area: loop, Number of mentions: 1
# Area: mad, Number of mentions: 1
# Area: insist, Number of mentions: 1
# Area: deplorable, Number of mentions: 1
# Area: staring, Number of mentions: 1
# Area: maneuver, Number of mentions: 1
# Area: transition, Number of mentions: 1
# Area: chest, Number of mentions: 1
# Area: circa, Number of mentions: 1
# Area: b747-400s, Number of mentions: 1
# Area: perpetuate, Number of mentions: 1
# Area: ying/yang, Number of mentions: 1
# Area: ~no, Number of mentions: 1
# Area: feat, Number of mentions: 1
# Area: dumped, Number of mentions: 1
# Area: uneaten, Number of mentions: 1
# Area: ohare, Number of mentions: 1
# Area: wilted, Number of mentions: 1
# Area: insufficient, Number of mentions: 2
# Area: modern, Number of mentions: 1
# Area: elegant, Number of mentions: 1
# Area: demonstrate, Number of mentions: 1
# Area: sophistication, Number of mentions: 1
# Area: dining, Number of mentions: 1
# Area: chain, Number of mentions: 1
# Area: rebooted, Number of mentions: 1
# Area: extraordinarily, Number of mentions: 1
# Area: concorde, Number of mentions: 1
# Area: refurbishment, Number of mentions: 1
# Area: bright, Number of mentions: 1
# Area: blanked, Number of mentions: 1
# Area: leathery, Number of mentions: 1
# Area: tissue, Number of mentions: 1
# Area: newer, Number of mentions: 1
# Area: 19.25, Number of mentions: 1
# Area: duly, Number of mentions: 1
# Area: achieved, Number of mentions: 1
# Area: negligent, Number of mentions: 1
# Area: barrage, Number of mentions: 1
# Area: tampa, Number of mentions: 1
# Area: fuss, Number of mentions: 2
# Area: abroad, Number of mentions: 2
# Area: shovel, Number of mentions: 1
# Area: black, Number of mentions: 1
# Area: hole, Number of mentions: 1
# Area: ba-228, Number of mentions: 1
# Area: reclining, Number of mentions: 1
# Area: loose, Number of mentions: 1
# Area: plug, Number of mentions: 1
# Area: conditioning, Number of mentions: 1
# Area: consistency, Number of mentions: 1
# Area: alternating, Number of mentions: 1
# Area: lit, Number of mentions: 1
# Area: abrupt, Number of mentions: 1
# Area: co-ordination, Number of mentions: 1
# Area: distributing, Number of mentions: 1
# Area: thrown, Number of mentions: 1
# Area: nervous, Number of mentions: 1
# Area: greeting, Number of mentions: 1
# Area: re-assure, Number of mentions: 1
# Area: qatar, Number of mentions: 1
# Area: etihad, Number of mentions: 1
# Area: splendid, Number of mentions: 1
# Area: classic, Number of mentions: 1
# Area: love, Number of mentions: 1
# Area: 2+, Number of mentions: 1
# Area: reduce, Number of mentions: 1
# Area: strong, Number of mentions: 1
# Area: wind, Number of mentions: 2
# Area: schiphol, Number of mentions: 1
# Area: 45-60, Number of mentions: 1
# Area: relaxed, Number of mentions: 1
# Area: warned, Number of mentions: 1
# Area: 2,5, Number of mentions: 1
# Area: overseas, Number of mentions: 1
# Area: unboarded, Number of mentions: 1
# Area: reclaiming, Number of mentions: 1
# Area: piladelphia, Number of mentions: 1
# Area: philadelphia, Number of mentions: 2
# Area: ecenomy, Number of mentions: 1
# Area: kindly, Number of mentions: 1
# Area: 2:45h, Number of mentions: 1
# Area: £5, Number of mentions: 1
# Area: chill, Number of mentions: 1
# Area: 40mins, Number of mentions: 1
# Area: 20mins, Number of mentions: 1
# Area: rushing, Number of mentions: 1
# Area: nap, Number of mentions: 1
# Area: buying, Number of mentions: 1
# Area: 350, Number of mentions: 1
# Area: cellophane, Number of mentions: 1
# Area: ate, Number of mentions: 1
# Area: unbooked, Number of mentions: 1
# Area: leaning, Number of mentions: 1
# Area: uncomfortably, Number of mentions: 1
# Area: stifling, Number of mentions: 1
# Area: hurried, Number of mentions: 1
# Area: malfunctioning, Number of mentions: 1
# Area: screw, Number of mentions: 1
# Area: driver, Number of mentions: 1
# Area: rage, Number of mentions: 1
# Area: sky, Number of mentions: 1
# Area: boac, Number of mentions: 3
# Area: humanly, Number of mentions: 1
# Area: 813, Number of mentions: 1
# Area: r/t, Number of mentions: 1
# Area: lax-buh, Number of mentions: 1
# Area: assign, Number of mentions: 2
# Area: baffling, Number of mentions: 1
# Area: oppressive, Number of mentions: 1
# Area: owed, Number of mentions: 1
# Area: £25, Number of mentions: 1
# Area: b/c, Number of mentions: 1
# Area: inop, Number of mentions: 1
# Area: twelve-hour, Number of mentions: 1
# Area: cushion, Number of mentions: 1
# Area: plumpest, Number of mentions: 1
# Area: 15., Number of mentions: 1
# Area: normal-sized, Number of mentions: 1
# Area: agonising, Number of mentions: 1
# Area: rack, Number of mentions: 2
# Area: mustve, Number of mentions: 1
# Area: patronising, Number of mentions: 1
# Area: fold, Number of mentions: 1
# Area: footstool, Number of mentions: 1
# Area: hunt, Number of mentions: 1
# Area: slow-to-react, Number of mentions: 1
# Area: validated, Number of mentions: 1
# Area: blr, Number of mentions: 1
# Area: decor, Number of mentions: 1
# Area: trim, Number of mentions: 1
# Area: rattling, Number of mentions: 1
# Area: latch, Number of mentions: 1
# Area: locking, Number of mentions: 1
# Area: vod, Number of mentions: 3
# Area: folding, Number of mentions: 1
# Area: gridlines, Number of mentions: 1
# Area: resisted, Number of mentions: 1
# Area: reset, Number of mentions: 1
# Area: await, Number of mentions: 1
# Area: outcome, Number of mentions: 1
# Area: lavatory, Number of mentions: 1
# Area: taxied, Number of mentions: 1
# Area: accompanied, Number of mentions: 1
# Area: repair, Number of mentions: 1
# Area: damaged/lost, Number of mentions: 1
# Area: replace, Number of mentions: 1
# Area: asap, Number of mentions: 1
# Area: depreciation, Number of mentions: 1
# Area: angst, Number of mentions: 1

# %%
#import nltk
#from nltk.corpus import stopwords
#from nltk.stem import WordNetLemmatizer
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#from collections import Counter, defaultdict

#nltk.download('stopwords')
#nltk.download('wordnet')

def clean_review(review):
    review = review.lower()
    review = review.replace('<br/>', '')
    review = review.replace('"', '')
    review = review.replace("'", '')
    return review

def extract_negative_words(review):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    
    tokens = nltk.word_tokenize(review)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    
    si = SentimentIntensityAnalyzer()
    sentiment = si.polarity_scores(review)
    
    negative_words = [token for token in tokens if sentiment['compound'] < 0]
    
    return negative_words

def analyze_reviews(reviews):
    negative_words = []
    for review in reviews:
        negative_words.extend(extract_negative_words(review))
    
    negative_word_counts = Counter(negative_words)
    
    top_negative_words = negative_word_counts.most_common(10)
    
    return top_negative_words

def areas_to_improve(reviews):
    areas = defaultdict(int)
    for review in reviews:
        negative_words = extract_negative_words(review)
        for word in negative_words:
            areas[word] += 1
    
    return areas

cleaned_reviews = [clean_review(review) for review in reviews]
top_negative_words = analyze_reviews(cleaned_reviews)
areas = areas_to_improve(cleaned_reviews)

print("Top 10 negative words:")
for word, count in top_negative_words:
    print(f"Word: {word}, Frequency: {count}")

print("\nAreas to improve:")
for area, count in areas.items():
    print(f"Area: {area}, Number of mentions: {count}")
# Out:
# Top 10 negative words:
# Word: ., Frequency: 4321
# Word: ,, Frequency: 2106
# Word: flight, Frequency: 1137
# Word: ba, Frequency: 632
# Word: verified, Frequency: 510
# Word: |, Frequency: 506
# Word: trip, Frequency: 470
# Word: seat, Frequency: 406
# Word: ✅, Frequency: 395
# Word: hour, Frequency: 368
#
# Areas to improve:
# Area: ✅, Number of mentions: 395
# Area: trip, Number of mentions: 470
# Area: verified, Number of mentions: 510
# Area: |, Number of mentions: 506
# Area: 4, Number of mentions: 57
# Area: hour, Number of mentions: 368
# Area: takeoff, Number of mentions: 6
# Area: received, Number of mentions: 63
# Area: mail, Number of mentions: 2
# Area: stating, Number of mentions: 5
# Area: cryptic, Number of mentions: 1
# Area: message, Number of mentions: 22
# Area: disruption, Number of mentions: 3
# Area: expected, Number of mentions: 12
# Area: limit, Number of mentions: 1
# Area: many, Number of mentions: 65
# Area: plane, Number of mentions: 151
# Area: leave, Number of mentions: 24
# Area: time, Number of mentions: 292
# Area: ., Number of mentions: 4321
# Area: capacity, Number of mentions: 1
# Area: heathrow, Number of mentions: 176
# Area: airport, Number of mentions: 161
# Area: really, Number of mentions: 55
# Area: hit, Number of mentions: 4
# Area: british, Number of mentions: 236
# Area: airway, Number of mentions: 232
# Area: surprise, Number of mentions: 5
# Area: ,, Number of mentions: 2106
# Area: 4h, Number of mentions: 3
# Area: departure, Number of mentions: 60
# Area: ?, Number of mentions: 78
# Area: anyhow, Number of mentions: 1
# Area: -, Number of mentions: 224
# Area: took, Number of mentions: 69
# Area: one, Number of mentions: 241
# Area: delay, Number of mentions: 85
# Area: forced, Number of mentions: 12
# Area: check, Number of mentions: 132
# Area: hand, Number of mentions: 29
# Area: luggage, Number of mentions: 120
# Area: travel, Number of mentions: 94
# Area: avoid, Number of mentions: 34
# Area: waiting, Number of mentions: 43
# Area: ultra, Number of mentions: 1
# Area: slow, Number of mentions: 15
# Area: processing, Number of mentions: 3
# Area: checked, Number of mentions: 36
# Area: overall, Number of mentions: 28
# Area: 2h, Number of mentions: 3
# Area: later, Number of mentions: 76
# Area: home, Number of mentions: 60
# Area: planed, Number of mentions: 1
# Area: reason, Number of mentions: 32
# Area: due, Number of mentions: 104
# Area: incompetent, Number of mentions: 8
# Area: people, Number of mentions: 96
# Area: service, Number of mentions: 362
# Area: level, Number of mentions: 22
# Area: far, Number of mentions: 33
# Area: worse, Number of mentions: 26
# Area: ryanair, Number of mentions: 12
# Area: triple, Number of mentions: 1
# Area: price, Number of mentions: 56
# Area: never, Number of mentions: 128
# Area: thanks, Number of mentions: 2
# Area: nothing, Number of mentions: 64
# Area: recently, Number of mentions: 12
# Area: bru, Number of mentions: 2
# Area: lhr, Number of mentions: 54
# Area: staff, Number of mentions: 206
# Area: shortage, Number of mentions: 4
# Area: announced, Number of mentions: 13
# Area: 2, Number of mentions: 99
# Area: holding, Number of mentions: 5
# Area: would, Number of mentions: 184
# Area: board, Number of mentions: 42
# Area: u, Number of mentions: 257
# Area: immediately, Number of mentions: 9
# Area: hope, Number of mentions: 10
# Area: clearing, Number of mentions: 4
# Area: gate, Number of mentions: 72
# Area: leaving, Number of mentions: 18
# Area: early, Number of mentions: 21
# Area: wait, Number of mentions: 57
# Area: full, Number of mentions: 61
# Area: inside, Number of mentions: 5
# Area: airplane, Number of mentions: 5
# Area: old, Number of mentions: 44
# Area: dirty, Number of mentions: 18
# Area: power, Number of mentions: 6
# Area: seat, Number of mentions: 406
# Area: provided, Number of mentions: 37
# Area: small, Number of mentions: 52
# Area: bag, Number of mentions: 149
# Area: pretzel, Number of mentions: 6
# Area: 250ml, Number of mentions: 3
# Area: water, Number of mentions: 59
# Area: passenger, Number of mentions: 149
# Area: flight, Number of mentions: 1137
# Area: option, Number of mentions: 63
# Area: purchase, Number of mentions: 16
# Area: food, Number of mentions: 182
# Area: drink, Number of mentions: 74
# Area: entertainment, Number of mentions: 38
# Area: available, Number of mentions: 62
# Area: oneworld, Number of mentions: 3
# Area: emerald, Number of mentions: 3
# Area: elite, Number of mentions: 2
# Area: member, Number of mentions: 44
# Area: upgrade, Number of mentions: 19
# Area: based, Number of mentions: 3
# Area: status, Number of mentions: 13
# Area: first, Number of mentions: 117
# Area: class, Number of mentions: 220
# Area: lounge, Number of mentions: 73
# Area: overcrowded, Number of mentions: 7
# Area: understaffed, Number of mentions: 1
# Area: poorly, Number of mentions: 5
# Area: equipped, Number of mentions: 2
# Area: help, Number of mentions: 57
# Area: desk, Number of mentions: 51
# Area: completely, Number of mentions: 20
# Area: unhelpful, Number of mentions: 5
# Area: error, Number of mentions: 14
# Area: arises, Number of mentions: 1
# Area: cancellation, Number of mentions: 32
# Area: even, Number of mentions: 160
# Area: top, Number of mentions: 21
# Area: avios, Number of mentions: 12
# Area: point, Number of mentions: 36
# Area: system, Number of mentions: 47
# Area: devalued, Number of mentions: 1
# Area: near, Number of mentions: 8
# Area: worthlessness, Number of mentions: 1
# Area: requires, Number of mentions: 2
# Area: fee, Number of mentions: 33
# Area: book, Number of mentions: 42
# Area: reward, Number of mentions: 1
# Area: nearly, Number of mentions: 12
# Area: equal, Number of mentions: 3
# Area: revenue, Number of mentions: 2
# Area: ticket, Number of mentions: 120
# Area: lost, Number of mentions: 57
# Area: way, Number of mentions: 76
# Area: recent, Number of mentions: 10
# Area: year, Number of mentions: 74
# Area: moved, Number of mentions: 15
# Area: world-class, Number of mentions: 1
# Area: airline, Number of mentions: 279
# Area: budget, Number of mentions: 31
# Area: much, Number of mentions: 54
# Area: timeliness, Number of mentions: 1
# Area: easyjet, Number of mentions: 6
# Area: 5, Number of mentions: 54
# Area: day, Number of mentions: 203
# Area: advised, Number of mentions: 21
# Area: ba, Number of mentions: 632
# Area: cancelled, Number of mentions: 160
# Area: asked, Number of mentions: 74
# Area: rebook, Number of mentions: 37
# Area: 1, Number of mentions: 36
# Area: original, Number of mentions: 24
# Area: made, Number of mentions: 71
# Area: take, Number of mentions: 74
# Area: 3, Number of mentions: 96
# Area: earlier, Number of mentions: 22
# Area: (, Number of mentions: 218
# Area: return, Number of mentions: 109
# Area: week, Number of mentions: 68
# Area: ), Number of mentions: 217
# Area: included, Number of mentions: 8
# Area: arrive, Number of mentions: 27
# Area: told, Number of mentions: 185
# Area: doesnt, Number of mentions: 6
# Area: pay, Number of mentions: 84
# Area: 75, Number of mentions: 2
# Area: pound, Number of mentions: 18
# Area: explained, Number of mentions: 15
# Area: confirmed, Number of mentions: 15
# Area: did-, Number of mentions: 1
# Area: !, Number of mentions: 145
# Area: make, Number of mentions: 90
# Area: effort, Number of mentions: 7
# Area: sort, Number of mentions: 8
# Area: remove, Number of mentions: 2
# Area: choice, Number of mentions: 53
# Area: thinking, Number of mentions: 3
# Area: pretty, Number of mentions: 14
# Area: easy, Number of mentions: 12
# Area: get, Number of mentions: 210
# Area: refund, Number of mentions: 108
# Area: 15, Number of mentions: 21
# Area: month, Number of mentions: 52
# Area: 10, Number of mentions: 36
# Area: email, Number of mentions: 74
# Area: still, Number of mentions: 94
# Area: seen, Number of mentions: 14
# Area: penny, Number of mentions: 6
# Area: every, Number of mentions: 37
# Area: ask, Number of mentions: 29
# Area: state, Number of mentions: 7
# Area: long, Number of mentions: 74
# Area: inane, Number of mentions: 1
# Area: saying, Number of mentions: 16
# Area: department, Number of mentions: 14
# Area: longer, Number of mentions: 20
# Area: others, Number of mentions: 11
# Area: respond, Number of mentions: 8
# Area: absolutely, Number of mentions: 24
# Area: hopeless, Number of mentions: 2
# Area: stuff, Number of mentions: 6
# Area: booking, Number of mentions: 67
# Area: place, Number of mentions: 15
# Area: customer, Number of mentions: 229
# Area: attempt, Number of mentions: 9
# Area: solve, Number of mentions: 5
# Area: problem, Number of mentions: 60
# Area: could, Number of mentions: 141
# Area: see, Number of mentions: 32
# Area: mistake, Number of mentions: 13
# Area: compounded, Number of mentions: 3
# Area: unable, Number of mentions: 16
# Area: investigate, Number of mentions: 1
# Area: simple, Number of mentions: 9
# Area: claim, Number of mentions: 48
# Area: 150, Number of mentions: 2
# Area: booked, Number of mentions: 129
# Area: bucharest, Number of mentions: 6
# Area: manchester, Number of mentions: 12
# Area: 45, Number of mentions: 16
# Area: ’, Number of mentions: 314
# Area: layover, Number of mentions: 13
# Area: delayed, Number of mentions: 127
# Area: atc, Number of mentions: 2
# Area: strike, Number of mentions: 9
# Area: arrived, Number of mentions: 84
# Area: 40, Number of mentions: 18
# Area: minute, Number of mentions: 109
# Area: scheduled, Number of mentions: 18
# Area: enough, Number of mentions: 43
# Area: catch, Number of mentions: 7
# Area: connecting, Number of mentions: 72
# Area: unfortunately, Number of mentions: 22
# Area: stranded, Number of mentions: 6
# Area: waited, Number of mentions: 39
# Area: disembark, Number of mentions: 3
# Area: lack, Number of mentions: 28
# Area: slot, Number of mentions: 5
# Area: common, Number of mentions: 1
# Area: missed, Number of mentions: 58
# Area: night, Number of mentions: 31
# Area: freezing, Number of mentions: 3
# Area: next, Number of mentions: 95
# Area: shameful, Number of mentions: 4
# Area: 10£, Number of mentions: 1
# Area: voucher, Number of mentions: 83
# Area: joke, Number of mentions: 15
# Area: considering, Number of mentions: 3
# Area: ridiculous, Number of mentions: 8
# Area: accommodation, Number of mentions: 15
# Area: offered, Number of mentions: 80
# Area: sleep, Number of mentions: 20
# Area: cold, Number of mentions: 15
# Area: compensation, Number of mentions: 39
# Area: sent, Number of mentions: 51
# Area: text, Number of mentions: 12
# Area: lame, Number of mentions: 1
# Area: excuse, Number of mentions: 15
# Area: sorry, Number of mentions: 14
# Area: compensate, Number of mentions: 10
# Area: anything, Number of mentions: 47
# Area: imagine, Number of mentions: 5
# Area: worst, Number of mentions: 81
# Area: regarding, Number of mentions: 9
# Area: care, Number of mentions: 37
# Area: money, Number of mentions: 84
# Area: rather, Number of mentions: 20
# Area: treat, Number of mentions: 8
# Area: last, Number of mentions: 72
# Area: lifetime, Number of mentions: 2
# Area: flying, Number of mentions: 70
# Area: online, Number of mentions: 72
# Area: ago, Number of mentions: 26
# Area: hitch, Number of mentions: 2
# Area: replacement, Number of mentions: 14
# Area: aircraft, Number of mentions: 78
# Area: meaning, Number of mentions: 13
# Area: chosen, Number of mentions: 9
# Area: different, Number of mentions: 51
# Area: informed, Number of mentions: 26
# Area: prior, Number of mentions: 20
# Area: amend, Number of mentions: 3
# Area: drop, Number of mentions: 11
# Area: man, Number of mentions: 7
# Area: t3, Number of mentions: 5
# Area: wasnt, Number of mentions: 17
# Area: smooth, Number of mentions: 11
# Area: suspect, Number of mentions: 3
# Area: fault, Number of mentions: 30
# Area: shuttle, Number of mentions: 5
# Area: boarding, Number of mentions: 107
# Area: rush, Number of mentions: 9
# Area: t5, Number of mentions: 19
# Area: cpt, Number of mentions: 5
# Area: left, Number of mentions: 70
# Area: le, Number of mentions: 24
# Area: cabin, Number of mentions: 135
# Area: clean, Number of mentions: 10
# Area: pe, Number of mentions: 2
# Area: sufficient, Number of mentions: 10
# Area: leg, Number of mentions: 49
# Area: arm, Number of mentions: 5
# Area: room, Number of mentions: 39
# Area: plus, Number of mentions: 23
# Area: little, Number of mentions: 24
# Area: perk, Number of mentions: 1
# Area: complaint, Number of mentions: 44
# Area: actually, Number of mentions: 16
# Area: recline, Number of mentions: 11
# Area: good, Number of mentions: 75
# Area: especially, Number of mentions: 21
# Area: george, Number of mentions: 1
# Area: quite, Number of mentions: 30
# Area: tasty, Number of mentions: 6
# Area: loaded, Number of mentions: 7
# Area: breakfast, Number of mentions: 35
# Area: also, Number of mentions: 78
# Area: landed, Number of mentions: 18
# Area: fly, Number of mentions: 113
# Area: ointment, Number of mentions: 1
# Area: case, Number of mentions: 27
# Area: late, Number of mentions: 89
# Area: carousel, Number of mentions: 2
# Area: notice, Number of mentions: 10
# Area: broken, Number of mentions: 23
# Area: likely, Number of mentions: 2
# Area: pleasant, Number of mentions: 8
# Area: infrequent, Number of mentions: 1
# Area: flyer, Number of mentions: 10
# Area: always, Number of mentions: 15
# Area: reassurance, Number of mentions: 1
# Area: comfort, Number of mentions: 11
# Area: quality, Number of mentions: 29
# Area: allowance, Number of mentions: 7
# Area: etc, Number of mentions: 26
# Area: fact, Number of mentions: 24
# Area: flown, Number of mentions: 32
# Area: changed, Number of mentions: 26
# Area: view, Number of mentions: 2
# Area: cause, Number of mentions: 4
# Area: reflect, Number of mentions: 2
# Area: getting, Number of mentions: 43
# Area: around, Number of mentions: 32
# Area: ground, Number of mentions: 37
# Area: ok., Number of mentions: 4
# Area: facility, Number of mentions: 8
# Area: disappointed, Number of mentions: 19
# Area: approx, Number of mentions: 3
# Area: half, Number of mentions: 37
# Area: thing, Number of mentions: 35
# Area: cup, Number of mentions: 13
# Area: poured, Number of mentions: 1
# Area: bite, Number of mentions: 1
# Area: sized, Number of mentions: 2
# Area: banana, Number of mentions: 1
# Area: slice, Number of mentions: 2
# Area: cake, Number of mentions: 1
# Area: journey, Number of mentions: 37
# Area: medium, Number of mentions: 4
# Area: screen, Number of mentions: 44
# Area: select, Number of mentions: 5
# Area: something, Number of mentions: 11
# Area: pas, Number of mentions: 18
# Area: away, Number of mentions: 35
# Area: obligatory, Number of mentions: 1
# Area: wifi, Number of mentions: 15
# Area: poor, Number of mentions: 84
# Area: access, Number of mentions: 10
# Area: shop, Number of mentions: 6
# Area: however, Number of mentions: 53
# Area: explains, Number of mentions: 2
# Area: record, Number of mentions: 5
# Area: profit, Number of mentions: 1
# Area: £1.52bn, Number of mentions: 1
# Area: question, Number of mentions: 12
# Area: paying, Number of mentions: 19
# Area: sure, Number of mentions: 16
# Area: opt, Number of mentions: 2
# Area: transparent, Number of mentions: 1
# Area: offer, Number of mentions: 54
# Area: decide, Number of mentions: 2
# Area: choose, Number of mentions: 15
# Area: stand, Number of mentions: 18
# Area: basic, Number of mentions: 11
# Area: go, Number of mentions: 87
# Area: elsewhere, Number of mentions: 1
# Area: cheaper, Number of mentions: 8
# Area: totally, Number of mentions: 18
# Area: unremarkable, Number of mentions: 1
# Area: comfortable, Number of mentions: 14
# Area: european, Number of mentions: 9
# Area: configuration, Number of mentions: 12
# Area: catering, Number of mentions: 10
# Area: storm, Number of mentions: 4
# Area: effect, Number of mentions: 1
# Area: greatly, Number of mentions: 2
# Area: exaggerated, Number of mentions: 1
# Area: euro, Number of mentions: 13
# Area: use, Number of mentions: 52
# Area: loss, Number of mentions: 6
# Area: 1., Number of mentions: 1
# Area: crew, Number of mentions: 142
# Area: 60, Number of mentions: 2
# Area: 2., Number of mentions: 2
# Area: behind, Number of mentions: 15
# Area: 1st, Number of mentions: 7
# Area: two, Number of mentions: 94
# Area: 3., Number of mentions: 4
# Area: 3rd, Number of mentions: 6
# Area: phone, Number of mentions: 79
# Area: hr, Number of mentions: 15
# Area: course, Number of mentions: 23
# Area: 4., Number of mentions: 1
# Area: spend, Number of mentions: 16
# Area: $, Number of mentions: 59
# Area: 500, Number of mentions: 5
# Area: health, Number of mentions: 1
# Area: beauty, Number of mentions: 1
# Area: item, Number of mentions: 9
# Area: wife, Number of mentions: 44
# Area: cruise, Number of mentions: 4
# Area: 5., Number of mentions: 2
# Area: said, Number of mentions: 103
# Area: might, Number of mentions: 17
# Area: reimburse, Number of mentions: 7
# Area: 6., Number of mentions: 1
# Area: 100, Number of mentions: 10
# Area: cab, Number of mentions: 7
# Area: fare, Number of mentions: 16
# Area: barcelona, Number of mentions: 10
# Area: bacelona, Number of mentions: 1
# Area: iberia, Number of mentions: 22
# Area: claimed, Number of mentions: 12
# Area: delivered, Number of mentions: 12
# Area: 7., Number of mentions: 2
# Area: arriving, Number of mentions: 14
# Area: back, Number of mentions: 147
# Area: ready, Number of mentions: 7
# Area: 8., Number of mentions: 1
# Area: caused, Number of mentions: 22
# Area: though, Number of mentions: 50
# Area: boarded, Number of mentions: 19
# Area: probably, Number of mentions: 14
# Area: mean, Number of mentions: 25
# Area: miss, Number of mentions: 21
# Area: connection, Number of mentions: 35
# Area: anchorage, Number of mentions: 1
# Area: clearly, Number of mentions: 16
# Area: know, Number of mentions: 37
# Area: operate, Number of mentions: 6
# Area: base, Number of mentions: 2
# Area: ..., Number of mentions: 8
# Area: embarrassed, Number of mentions: 3
# Area: cant, Number of mentions: 17
# Area: like, Number of mentions: 64
# Area: normal, Number of mentions: 10
# Area: grasp, Number of mentions: 1
# Area: concept, Number of mentions: 2
# Area: hiccup, Number of mentions: 1
# Area: mass, Number of mentions: 1
# Area: ripple, Number of mentions: 1
# Area: chaos, Number of mentions: 17
# Area: london, Number of mentions: 292
# Area: gibraltar, Number of mentions: 3
# Area: 24th, Number of mentions: 1
# Area: october, Number of mentions: 7
# Area: 2023., Number of mentions: 7
# Area: shall, Number of mentions: 3
# Area: start, Number of mentions: 16
# Area: reference, Number of mentions: 10
# Area: process, Number of mentions: 29
# Area: used, Number of mentions: 44
# Area: website, Number of mentions: 56
# Area: reserve, Number of mentions: 6
# Area: clear, Number of mentions: 10
# Area: aspect, Number of mentions: 5
# Area: depart, Number of mentions: 8
# Area: terminal, Number of mentions: 45
# Area: bussed, Number of mentions: 4
# Area: part, Number of mentions: 23
# Area: cabin-crew, Number of mentions: 1
# Area: kept, Number of mentions: 27
# Area: low, Number of mentions: 23
# Area: profile, Number of mentions: 1
# Area: maintained, Number of mentions: 2
# Area: entire, Number of mentions: 10
# Area: captain, Number of mentions: 8
# Area: brief, Number of mentions: 1
# Area: announcement, Number of mentions: 15
# Area: in-flight, Number of mentions: 6
# Area: short, Number of mentions: 27
# Area: overt, Number of mentions: 1
# Area: tiny, Number of mentions: 19
# Area: bottle, Number of mentions: 24
# Area: inedible, Number of mentions: 15
# Area: “, Number of mentions: 34
# Area: bar, Number of mentions: 13
# Area: ”, Number of mentions: 35
# Area: order, Number of mentions: 23
# Area: doe, Number of mentions: 1
# Area: seem, Number of mentions: 9
# Area: work, Number of mentions: 49
# Area: refused, Number of mentions: 25
# Area: sell, Number of mentions: 4
# Area: coffee, Number of mentions: 21
# Area: moreover, Number of mentions: 1
# Area: usb, Number of mentions: 7
# Area: charge, Number of mentions: 38
# Area: either, Number of mentions: 23
# Area: given, Number of mentions: 87
# Area: show, Number of mentions: 21
# Area: sale, Number of mentions: 1
# Area: trolley, Number of mentions: 6
# Area: on-time, Number of mentions: 2
# Area: disembarkation, Number of mentions: 3
# Area: inefficient, Number of mentions: 2
# Area: managed, Number of mentions: 24
# Area: wearing, Number of mentions: 9
# Area: new, Number of mentions: 86
# Area: uniform, Number of mentions: 2
# Area: seems, Number of mentions: 21
# Area: downward, Number of mentions: 1
# Area: trend, Number of mentions: 1
# Area: candid, Number of mentions: 1
# Area: difference, Number of mentions: 13
# Area: so-called, Number of mentions: 3
# Area: rival, Number of mentions: 4
# Area: route, Number of mentions: 35
# Area: monopoly, Number of mentions: 3
# Area: company, Number of mentions: 30
# Area: experience, Number of mentions: 110
# Area: ever, Number of mentions: 52
# Area: flew, Number of mentions: 43
# Area: three, Number of mentions: 35
# Area: extra, Number of mentions: 52
# Area: porto, Number of mentions: 4
# Area: scrambled, Number of mentions: 3
# Area: hotel, Number of mentions: 58
# Area: routed, Number of mentions: 2
# Area: madrid, Number of mentions: 19
# Area: morning, Number of mentions: 21
# Area: 1.5, Number of mentions: 9
# Area: 1300, Number of mentions: 1
# Area: finally, Number of mentions: 61
# Area: got, Number of mentions: 99
# Area: five, Number of mentions: 4
# Area: meanwhile, Number of mentions: 1
# Area: reservation, Number of mentions: 16
# Area: helpful, Number of mentions: 16
# Area: onus, Number of mentions: 1
# Area: fix, Number of mentions: 6
# Area: turn, Number of mentions: 15
# Area: ruined, Number of mentions: 12
# Area: vacation, Number of mentions: 7
# Area: dont, Number of mentions: 47
# Area: wouldnt, Number of mentions: 15
# Area: let, Number of mentions: 30
# Area: speak, Number of mentions: 25
# Area: supervisor, Number of mentions: 6
# Area: manager, Number of mentions: 17
# Area: awful, Number of mentions: 30
# Area: bordering, Number of mentions: 2
# Area: abuse, Number of mentions: 1
# Area: istanbul, Number of mentions: 7
# Area: business, Number of mentions: 205
# Area: child, Number of mentions: 15
# Area: watching, Number of mentions: 1
# Area: ipad, Number of mentions: 4
# Area: loud, Number of mentions: 1
# Area: plugged, Number of mentions: 1
# Area: row, Number of mentions: 49
# Area: front, Number of mentions: 36
# Area: disrupted, Number of mentions: 2
# Area: hear, Number of mentions: 5
# Area: headphone, Number of mentions: 6
# Area: thought, Number of mentions: 26
# Area: fine, Number of mentions: 20
# Area: tell, Number of mentions: 26
# Area: mom, Number of mentions: 1
# Area: acceptable, Number of mentions: 7
# Area: turned, Number of mentions: 19
# Area: zoo, Number of mentions: 2
# Area: training, Number of mentions: 6
# Area: allowed, Number of mentions: 16
# Area: disrupt, Number of mentions: 1
# Area: laughed, Number of mentions: 2
# Area: disgrace, Number of mentions: 8
# Area: ive, Number of mentions: 20
# Area: mentioned, Number of mentions: 2
# Area: bad, Number of mentions: 54
# Area: departed, Number of mentions: 9
# Area: inbound, Number of mentions: 11
# Area: economy, Number of mentions: 102
# Area: larger, Number of mentions: 3
# Area: baggage, Number of mentions: 83
# Area: making, Number of mentions: 16
# Area: complete, Number of mentions: 15
# Area: mockery, Number of mentions: 1
# Area: advertised, Number of mentions: 2
# Area: lot, Number of mentions: 33
# Area: stressed, Number of mentions: 2
# Area: missing, Number of mentions: 27
# Area: onwards, Number of mentions: 1
# Area: closed, Number of mentions: 24
# Area: disembarked, Number of mentions: 1
# Area: onboard, Number of mentions: 25
# Area: ok, Number of mentions: 26
# Area: minimal, Number of mentions: 7
# Area: gave, Number of mentions: 44
# Area: full-service, Number of mentions: 2
# Area: concerning, Number of mentions: 1
# Area: trying, Number of mentions: 46
# Area: hold, Number of mentions: 25
# Area: change, Number of mentions: 66
# Area: deal, Number of mentions: 8
# Area: non-existent, Number of mentions: 8
# Area: deliberately, Number of mentions: 1
# Area: hard, Number of mentions: 22
# Area: contact, Number of mentions: 34
# Area: hate, Number of mentions: 2
# Area: oct, Number of mentions: 1
# Area: line, Number of mentions: 50
# Area: 1200, Number of mentions: 2
# Area: fixed, Number of mentions: 3
# Area: everyone, Number of mentions: 22
# Area: call, Number of mentions: 119
# Area: .., Number of mentions: 3
# Area: via, Number of mentions: 77
# Area: tour, Number of mentions: 3
# Area: started, Number of mentions: 20
# Area: loading, Number of mentions: 2
# Area: explanation, Number of mentions: 27
# Area: may, Number of mentions: 26
# Area: april, Number of mentions: 8
# Area: 2022, Number of mentions: 11
# Area: operated, Number of mentions: 7
# Area: finnair, Number of mentions: 5
# Area: using, Number of mentions: 25
# Area: shortly, Number of mentions: 6
# Area: preferred, Number of mentions: 3
# Area: although, Number of mentions: 27
# Area: similar, Number of mentions: 7
# Area: layout, Number of mentions: 7
# Area: club, Number of mentions: 78
# Area: europe, Number of mentions: 25
# Area: i.e, Number of mentions: 2
# Area: middle, Number of mentions: 39
# Area: free, Number of mentions: 28
# Area: felt, Number of mentions: 19
# Area: legroom, Number of mentions: 25
# Area: slightly, Number of mentions: 3
# Area: better, Number of mentions: 47
# Area: meal, Number of mentions: 89
# Area: chose, Number of mentions: 7
# Area: beef, Number of mentions: 3
# Area: cheek, Number of mentions: 1
# Area: passed, Number of mentions: 11
# Area: passport, Number of mentions: 14
# Area: control, Number of mentions: 15
# Area: without, Number of mentions: 59
# Area: designated, Number of mentions: 2
# Area: reclaim, Number of mentions: 4
# Area: ten, Number of mentions: 7
# Area: went, Number of mentions: 45
# Area: counter, Number of mentions: 25
# Area: going, Number of mentions: 46
# Area: seemed, Number of mentions: 22
# Area: unaware, Number of mentions: 1
# Area: issue, Number of mentions: 54
# Area: find, Number of mentions: 65
# Area: various, Number of mentions: 6
# Area: requested, Number of mentions: 17
# Area: information, Number of mentions: 44
# Area: despite, Number of mentions: 43
# Area: list, Number of mentions: 3
# Area: almost, Number of mentions: 31
# Area: 2½, Number of mentions: 1
# Area: frustrating, Number of mentions: 5
# Area: say, Number of mentions: 42
# Area: least, Number of mentions: 37
# Area: subsequently, Number of mentions: 1
# Area: complained, Number of mentions: 13
# Area: automated, Number of mentions: 6
# Area: ‘, Number of mentions: 8
# Area: experiencing, Number of mentions: 2
# Area: exceptionally, Number of mentions: 4
# Area: high, Number of mentions: 11
# Area: volume, Number of mentions: 3
# Area: response, Number of mentions: 26
# Area: centre, Number of mentions: 19
# Area: atrocious, Number of mentions: 3
# Area: sometimes, Number of mentions: 4
# Area: callous, Number of mentions: 2
# Area: anybody, Number of mentions: 2
# Area: cut, Number of mentions: 13
# Area: halfway, Number of mentions: 3
# Area: resolution, Number of mentions: 5
# Area: anyway, Number of mentions: 7
# Area: nobody, Number of mentions: 6
# Area: so-so, Number of mentions: 1
# Area: haul, Number of mentions: 20
# Area: semi-low, Number of mentions: 1
# Area: cost, Number of mentions: 62
# Area: confusing, Number of mentions: 5
# Area: expect, Number of mentions: 21
# Area: snack, Number of mentions: 25
# Area: whilst, Number of mentions: 11
# Area: else, Number of mentions: 23
# Area: paid, Number of mentions: 82
# Area: yet, Number of mentions: 30
# Area: apparently, Number of mentions: 18
# Area: pre-order, Number of mentions: 2
# Area: additional, Number of mentions: 22
# Area: dependable, Number of mentions: 1
# Area: theory, Number of mentions: 2
# Area: generous, Number of mentions: 2
# Area: compared, Number of mentions: 8
# Area: competitor, Number of mentions: 3
# Area: space, Number of mentions: 21
# Area: overhead, Number of mentions: 8
# Area: leading, Number of mentions: 3
# Area: whole, Number of mentions: 27
# Area: offering, Number of mentions: 19
# Area: well, Number of mentions: 48
# Area: supply, Number of mentions: 2
# Area: throughout, Number of mentions: 14
# Area: contrary, Number of mentions: 1
# Area: seatbelt, Number of mentions: 3
# Area: sight, Number of mentions: 2
# Area: pointless, Number of mentions: 1
# Area: providing, Number of mentions: 5
# Area: socket, Number of mentions: 2
# Area: abandon, Number of mentions: 2
# Area: fail, Number of mentions: 4
# Area: deemed, Number of mentions: 1
# Area: star, Number of mentions: 4
# Area: punta, Number of mentions: 2
# Area: cana, Number of mentions: 2
# Area: trouble, Number of mentions: 4
# Area: outbound, Number of mentions: 18
# Area: gatwick, Number of mentions: 29
# Area: realised, Number of mentions: 5
# Area: sitting, Number of mentions: 20
# Area: spent, Number of mentions: 33
# Area: reserving, Number of mentions: 1
# Area: number, Number of mentions: 62
# Area: automatically, Number of mentions: 6
# Area: reallocated, Number of mentions: 1
# Area: particular, Number of mentions: 3
# Area: swapped, Number of mentions: 1
# Area: couple, Number of mentions: 19
# Area: form, Number of mentions: 22
# Area: n, Number of mentions: 1
# Area: £100, Number of mentions: 3
# Area: didnt, Number of mentions: 38
# Area: accept, Number of mentions: 15
# Area: naturally, Number of mentions: 2
# Area: wanted, Number of mentions: 23
# Area: eventually, Number of mentions: 21
# Area: fight, Number of mentions: 4
# Area: second, Number of mentions: 21
# Area: rate, Number of mentions: 8
# Area: shoddy, Number of mentions: 2
# Area: downgraded, Number of mentions: 7
# Area: premium, Number of mentions: 66
# Area: 200, Number of mentions: 4
# Area: 400, Number of mentions: 2
# Area: aud, Number of mentions: 3
# Area: 3000, Number of mentions: 2
# Area: 6500, Number of mentions: 1
# Area: owe, Number of mentions: 4
# Area: 1500, Number of mentions: 1
# Area: fair, Number of mentions: 5
# Area: 3250, Number of mentions: 1
# Area: downgrade, Number of mentions: 3
# Area: insulting, Number of mentions: 2
# Area: incredibly, Number of mentions: 7
# Area: painful, Number of mentions: 2
# Area: cancer, Number of mentions: 1
# Area: operation, Number of mentions: 2
# Area: injury, Number of mentions: 5
# Area: pointed, Number of mentions: 6
# Area: need, Number of mentions: 38
# Area: lie, Number of mentions: 14
# Area: numbing, Number of mentions: 1
# Area: insult, Number of mentions: 6
# Area: slap, Number of mentions: 1
# Area: face, Number of mentions: 13
# Area: continue, Number of mentions: 8
# Area: degradation, Number of mentions: 1
# Area: dealt, Number of mentions: 5
# Area: earth, Number of mentions: 2
# Area: honest, Number of mentions: 3
# Area: working, Number of mentions: 26
# Area: actual, Number of mentions: 3
# Area: warm, Number of mentions: 6
# Area: friendly, Number of mentions: 15
# Area: operates, Number of mentions: 3
# Area: medieval, Number of mentions: 1
# Area: torture, Number of mentions: 1
# Area: already, Number of mentions: 41
# Area: apart, Number of mentions: 10
# Area: logo, Number of mentions: 1
# Area: rear, Number of mentions: 4
# Area: fuselage, Number of mentions: 1
# Area: indication, Number of mentions: 4
# Area: carrier, Number of mentions: 18
# Area: farce, Number of mentions: 2
# Area: group, Number of mentions: 14
# Area: queue, Number of mentions: 51
# Area: wrong, Number of mentions: 26
# Area: interior, Number of mentions: 3
# Area: reminiscent, Number of mentions: 1
# Area: twenty, Number of mentions: 4
# Area: except, Number of mentions: 8
# Area: tight, Number of mentions: 7
# Area: uncomfortable, Number of mentions: 37
# Area: seating, Number of mentions: 22
# Area: feel, Number of mentions: 16
# Area: luxurious, Number of mentions: 1
# Area: unknown, Number of mentions: 1
# Area: charter, Number of mentions: 2
# Area: usual, Number of mentions: 17
# Area: ran, Number of mentions: 12
# Area: theyd, Number of mentions: 1
# Area: reached, Number of mentions: 9
# Area: 24., Number of mentions: 1
# Area: tea, Number of mentions: 19
# Area: appeared, Number of mentions: 12
# Area: thank, Number of mentions: 2
# Area: goodness, Number of mentions: 1
# Area: purchased, Number of mentions: 9
# Area: officious, Number of mentions: 1
# Area: senior, Number of mentions: 1
# Area: attendant, Number of mentions: 30
# Area: whod, Number of mentions: 1
# Area: facilitating, Number of mentions: 1
# Area: slammed, Number of mentions: 1
# Area: armrest, Number of mentions: 2
# Area: mid, Number of mentions: 3
# Area: cattle, Number of mentions: 4
# Area: definitely, Number of mentions: 8
# Area: happy, Number of mentions: 6
# Area: land, Number of mentions: 3
# Area: understatement, Number of mentions: 1
# Area: real, Number of mentions: 7
# Area: fill, Number of mentions: 7
# Area: bin, Number of mentions: 6
# Area: supposed, Number of mentions: 22
# Area: bother, Number of mentions: 6
# Area: implementing, Number of mentions: 1
# Area: rule, Number of mentions: 7
# Area: subsequent, Number of mentions: 4
# Area: mill, Number of mentions: 1
# Area: aisle, Number of mentions: 24
# Area: bumping, Number of mentions: 3
# Area: searching, Number of mentions: 3
# Area: result, Number of mentions: 15
# Area: nonsense, Number of mentions: 2
# Area: incoming, Number of mentions: 3
# Area: 90, Number of mentions: 9
# Area: glasgow, Number of mentions: 14
# Area: canceled, Number of mentions: 10
# Area: 12, Number of mentions: 24
# Area: discovered, Number of mentions: 8
# Area: soaking, Number of mentions: 2
# Area: wet, Number of mentions: 3
# Area: content, Number of mentions: 1
# Area: air, Number of mentions: 40
# Area: dried, Number of mentions: 4
# Area: allocated, Number of mentions: 5
# Area: toilet, Number of mentions: 14
# Area: galley, Number of mentions: 8
# Area: chance, Number of mentions: 6
# Area: possible, Number of mentions: 21
# Area: movement, Number of mentions: 1
# Area: ignored, Number of mentions: 10
# Area: bumped, Number of mentions: 8
# Area: walking, Number of mentions: 1
# Area: pushing, Number of mentions: 4
# Area: kart, Number of mentions: 1
# Area: apology, Number of mentions: 15
# Area: compartment, Number of mentions: 3
# Area: standard, Number of mentions: 25
# Area: decline, Number of mentions: 7
# Area: min, Number of mentions: 37
# Area: norm, Number of mentions: 3
# Area: rude, Number of mentions: 36
# Area: clueless, Number of mentions: 7
# Area: grubby, Number of mentions: 1
# Area: cleaning, Number of mentions: 3
# Area: cope, Number of mentions: 1
# Area: cutback, Number of mentions: 4
# Area: apply, Number of mentions: 1
# Area: become, Number of mentions: 11
# Area: truly, Number of mentions: 6
# Area: 35, Number of mentions: 2
# Area: veteran, Number of mentions: 1
# Area: user, Number of mentions: 2
# Area: alex, Number of mentions: 2
# Area: cruz, Number of mentions: 2
# Area: cutting, Number of mentions: 4
# Area: past, Number of mentions: 15
# Area: quickly, Number of mentions: 12
# Area: latest, Number of mentions: 5
# Area: ceo, Number of mentions: 7
# Area: read, Number of mentions: 5
# Area: occasional, Number of mentions: 1
# Area: article, Number of mentions: 1
# Area: improving, Number of mentions: 1
# Area: substantive, Number of mentions: 1
# Area: amongst, Number of mentions: 3
# Area: maybe, Number of mentions: 4
# Area: name, Number of mentions: 17
# Area: give, Number of mentions: 36
# Area: flag, Number of mentions: 3
# Area: proper, Number of mentions: 3
# Area: low-cost, Number of mentions: 2
# Area: sadly, Number of mentions: 7
# Area: declined, Number of mentions: 7
# Area: remains, Number of mentions: 5
# Area: surprised, Number of mentions: 5
# Area: &, Number of mentions: 22
# Area: co, Number of mentions: 4
# Area: produce, Number of mentions: 3
# Area: rubbish, Number of mentions: 8
# Area: sampled, Number of mentions: 1
# Area: turkish, Number of mentions: 4
# Area: equivalent, Number of mentions: 6
# Area: august, Number of mentions: 24
# Area: superb, Number of mentions: 1
# Area: guessing, Number of mentions: 1
# Area: avoided, Number of mentions: 2
# Area: staffed, Number of mentions: 5
# Area: chaotic, Number of mentions: 9
# Area: overfull, Number of mentions: 1
# Area: couldnt, Number of mentions: 27
# Area: unmanaged, Number of mentions: 1
# Area: served, Number of mentions: 36
# Area: take-off, Number of mentions: 2
# Area: race, Number of mentions: 2
# Area: bottom, Number of mentions: 6
# Area: cheapskate, Number of mentions: 1
# Area: stake, Number of mentions: 1
# Area: looking, Number of mentions: 14
# Area: forward, Number of mentions: 12
# Area: reliable, Number of mentions: 3
# Area: trust, Number of mentions: 3
# Area: timing, Number of mentions: 2
# Area: 6.45am, Number of mentions: 1
# Area: engine, Number of mentions: 3
# Area: risking, Number of mentions: 2
# Area: meeting, Number of mentions: 8
# Area: geneva, Number of mentions: 7
# Area: come, Number of mentions: 28
# Area: bring, Number of mentions: 5
# Area: funny, Number of mentions: 2
# Area: another, Number of mentions: 111
# Area: spring, Number of mentions: 1
# Area: 2023, Number of mentions: 12
# Area: amsterdam, Number of mentions: 20
# Area: put, Number of mentions: 40
# Area: several, Number of mentions: 27
# Area: stress, Number of mentions: 6
# Area: end, Number of mentions: 28
# Area: dramatic, Number of mentions: 1
# Area: unlucky, Number of mentions: 3
# Area: today, Number of mentions: 20
# Area: routine, Number of mentions: 2
# Area: reading, Number of mentions: 2
# Area: review, Number of mentions: 11
# Area: im, Number of mentions: 16
# Area: traveller, Number of mentions: 15
# Area: word, Number of mentions: 11
# Area: abysmal, Number of mentions: 3
# Area: stuck, Number of mentions: 13
# Area: athens, Number of mentions: 12
# Area: sat, Number of mentions: 19
# Area: run, Number of mentions: 17
# Area: lentil, Number of mentions: 1
# Area: pie, Number of mentions: 3
# Area: green, Number of mentions: 2
# Area: curry, Number of mentions: 2
# Area: returning, Number of mentions: 5
# Area: promised, Number of mentions: 14
# Area: 3hrs, Number of mentions: 4
# Area: overbooked, Number of mentions: 7
# Area: basically, Number of mentions: 7
# Area: fails, Number of mentions: 1
# Area: deliver, Number of mentions: 7
# Area: national, Number of mentions: 8
# Area: implore, Number of mentions: 1
# Area: alternative, Number of mentions: 28
# Area: life, Number of mentions: 15
# Area: mxp, Number of mentions: 3
# Area: train, Number of mentions: 13
# Area: heart, Number of mentions: 1
# Area: attack, Number of mentions: 1
# Area: stayed, Number of mentions: 4
# Area: upon, Number of mentions: 18
# Area: arrival, Number of mentions: 42
# Area: sjc, Number of mentions: 3
# Area: filled, Number of mentions: 7
# Area: employee, Number of mentions: 15
# Area: receipt, Number of mentions: 7
# Area: simply, Number of mentions: 23
# Area: answer, Number of mentions: 23
# Area: called, Number of mentions: 52
# Area: twice, Number of mentions: 7
# Area: toll, Number of mentions: 1
# Area: realized, Number of mentions: 3
# Area: delivery, Number of mentions: 4
# Area: address, Number of mentions: 10
# Area: enter, Number of mentions: 5
# Area: dealing, Number of mentions: 5
# Area: shitty, Number of mentions: 1
# Area: buy, Number of mentions: 17
# Area: clothes, Number of mentions: 10
# Area: expecting, Number of mentions: 4
# Area: happened, Number of mentions: 23
# Area: neither, Number of mentions: 3
# Area: positive, Number of mentions: 3
# Area: side, Number of mentions: 8
# Area: obviously, Number of mentions: 7
# Area: justify, Number of mentions: 2
# Area: treatment, Number of mentions: 6
# Area: knew, Number of mentions: 3
# Area: worn, Number of mentions: 13
# Area: dallas, Number of mentions: 3
# Area: multiple, Number of mentions: 17
# Area: electronics, Number of mentions: 2
# Area: non, Number of mentions: 10
# Area: functional, Number of mentions: 2
# Area: designed, Number of mentions: 3
# Area: dubrovnik, Number of mentions: 1
# Area: tray, Number of mentions: 13
# Area: blocking, Number of mentions: 1
# Area: coach, Number of mentions: 11
# Area: technical, Number of mentions: 10
# Area: slipped, Number of mentions: 2
# Area: 17:00, Number of mentions: 1
# Area: 20:00, Number of mentions: 1
# Area: 22:00, Number of mentions: 1
# Area: zero, Number of mentions: 7
# Area: odds, Number of mentions: 1
# Area: booted, Number of mentions: 2
# Area: uk, Number of mentions: 19
# Area: closing, Number of mentions: 3
# Area: sign, Number of mentions: 8
# Area: passing, Number of mentions: 3
# Area: engineer, Number of mentions: 4
# Area: helped, Number of mentions: 7
# Area: locate, Number of mentions: 5
# Area: washed, Number of mentions: 3
# Area: contravention, Number of mentions: 1
# Area: caa, Number of mentions: 2
# Area: slept, Number of mentions: 2
# Area: bus, Number of mentions: 27
# Area: stop, Number of mentions: 10
# Area: overnight, Number of mentions: 18
# Area: young, Number of mentions: 7
# Area: somewhere, Number of mentions: 3
# Area: stay, Number of mentions: 15
# Area: following, Number of mentions: 19
# Area: admin, Number of mentions: 1
# Area: liquid, Number of mentions: 2
# Area: 1/2, Number of mentions: 3
# Area: shockingly, Number of mentions: 3
# Area: experienced, Number of mentions: 12
# Area: miami, Number of mentions: 11
# Area: florida, Number of mentions: 2
# Area: dublin, Number of mentions: 18
# Area: ireland, Number of mentions: 1
# Area: occupied, Number of mentions: 4
# Area: total, Number of mentions: 27
# Area: roughly, Number of mentions: 2
# Area: challenge, Number of mentions: 2
# Area: 73, Number of mentions: 1
# Area: headed, Number of mentions: 2
# Area: stopped, Number of mentions: 8
# Area: security, Number of mentions: 22
# Area: personnel, Number of mentions: 5
# Area: checkpoint, Number of mentions: 2
# Area: ushered, Number of mentions: 2
# Area: rebooked, Number of mentions: 38
# Area: busy, Number of mentions: 12
# Area: weekend, Number of mentions: 5
# Area: reimbursed, Number of mentions: 8
# Area: city, Number of mentions: 15
# Area: filed, Number of mentions: 8
# Area: plenty, Number of mentions: 8
# Area: therefore, Number of mentions: 7
# Area: denied, Number of mentions: 7
# Area: 20, Number of mentions: 14
# Area: timeframe, Number of mentions: 1
# Area: person, Number of mentions: 35
# Area: policy, Number of mentions: 8
# Area: close, Number of mentions: 19
# Area: feedback, Number of mentions: 2
# Area: site, Number of mentions: 9
# Area: appears, Number of mentions: 6
# Area: overwhelming, Number of mentions: 1
# Area: sentiment, Number of mentions: 1
# Area: prague, Number of mentions: 4
# Area: came, Number of mentions: 28
# Area: unusual, Number of mentions: 1
# Area: picture, Number of mentions: 2
# Area: hardly, Number of mentions: 9
# Area: block, Number of mentions: 5
# Area: horrible, Number of mentions: 30
# Area: addition, Number of mentions: 6
# Area: clerk, Number of mentions: 3
# Area: yell, Number of mentions: 1
# Area: excused, Number of mentions: 1
# Area: bit, Number of mentions: 13
# Area: priority, Number of mentions: 11
# Area: fun, Number of mentions: 2
# Area: began, Number of mentions: 9
# Area: walk, Number of mentions: 6
# Area: asking, Number of mentions: 13
# Area: virtually, Number of mentions: 4
# Area: weather, Number of mentions: 12
# Area: comfortably, Number of mentions: 4
# Area: store, Number of mentions: 2
# Area: holder, Number of mentions: 6
# Area: keep, Number of mentions: 11
# Area: button, Number of mentions: 6
# Area: outlet, Number of mentions: 2
# Area: internet, Number of mentions: 7
# Area: heavy, Number of mentions: 4
# Area: hernia, Number of mentions: 1
# Area: weekly, Number of mentions: 1
# Area: want, Number of mentions: 29
# Area: frankly, Number of mentions: 4
# Area: someone, Number of mentions: 43
# Area: traffic, Number of mentions: 2
# Area: heard, Number of mentions: 10
# Area: understand, Number of mentions: 19
# Area: world, Number of mentions: 38
# Area: traveled, Number of mentions: 8
# Area: shame, Number of mentions: 14
# Area: watched, Number of mentions: 4
# Area: fall, Number of mentions: 3
# Area: cliff, Number of mentions: 1
# Area: advice, Number of mentions: 5
# Area: anyone, Number of mentions: 23
# Area: exercise, Number of mentions: 1
# Area: schedule, Number of mentions: 8
# Area: destination, Number of mentions: 22
# Area: everything, Number of mentions: 19
# Area: runway, Number of mentions: 6
# Area: pilot, Number of mentions: 13
# Area: announce, Number of mentions: 2
# Area: tried, Number of mentions: 53
# Area: evacuated, Number of mentions: 1
# Area: worry, Number of mentions: 2
# Area: special, Number of mentions: 8
# Area: set, Number of mentions: 5
# Area: saturday, Number of mentions: 5
# Area: 8pm, Number of mentions: 3
# Area: application, Number of mentions: 2
# Area: app, Number of mentions: 32
# Area: disassociate, Number of mentions: 1
# Area: saw, Number of mentions: 8
# Area: 10:30pm, Number of mentions: 1
# Area: 700gbp, Number of mentions: 1
# Area: 8, Number of mentions: 21
# Area: jet, Number of mentions: 4
# Area: lag, Number of mentions: 1
# Area: insane, Number of mentions: 2
# Area: reimbursement, Number of mentions: 10
# Area: havent, Number of mentions: 5
# Area: since, Number of mentions: 67
# Area: idea, Number of mentions: 8
# Area: ill, Number of mentions: 5
# Area: claiming, Number of mentions: 3
# Area: emotional, Number of mentions: 1
# Area: situation, Number of mentions: 21
# Area: indifference, Number of mentions: 5
# Area: financially, Number of mentions: 2
# Area: difficult, Number of mentions: 23
# Area: right, Number of mentions: 15
# Area: salary, Number of mentions: 2
# Area: impossible, Number of mentions: 10
# Area: reach, Number of mentions: 16
# Area: 26, Number of mentions: 7
# Area: trapped, Number of mentions: 2
# Area: solution, Number of mentions: 6
# Area: initial, Number of mentions: 3
# Area: rescheduled, Number of mentions: 3
# Area: hamburg, Number of mentions: 6
# Area: la, Number of mentions: 5
# Area: vega, Number of mentions: 5
# Area: transfer, Number of mentions: 11
# Area: dropped, Number of mentions: 3
# Area: closest, Number of mentions: 1
# Area: opened, Number of mentions: 3
# Area: single, Number of mentions: 14
# Area: future, Number of mentions: 15
# Area: share, Number of mentions: 2
# Area: story, Number of mentions: 3
# Area: july, Number of mentions: 10
# Area: lax, Number of mentions: 14
# Area: disappointing, Number of mentions: 24
# Area: refusal, Number of mentions: 2
# Area: arrangement, Number of mentions: 8
# Area: italy, Number of mentions: 6
# Area: 7, Number of mentions: 23
# Area: september, Number of mentions: 6
# Area: tambo, Number of mentions: 1
# Area: international, Number of mentions: 8
# Area: checked-in, Number of mentions: 1
# Area: previous, Number of mentions: 11
# Area: evening, Number of mentions: 18
# Area: off-loaded, Number of mentions: 1
# Area: beforehand, Number of mentions: 1
# Area: team, Number of mentions: 15
# Area: check-in, Number of mentions: 48
# Area: manage, Number of mentions: 5
# Area: lufthansa, Number of mentions: 4
# Area: frankfurt, Number of mentions: 12
# Area: moving, Number of mentions: 3
# Area: whether, Number of mentions: 8
# Area: valid, Number of mentions: 6
# Area: assured, Number of mentions: 5
# Area: correct, Number of mentions: 11
# Area: south, Number of mentions: 6
# Area: africa, Number of mentions: 4
# Area: 18, Number of mentions: 4
# Area: checking, Number of mentions: 11
# Area: noticed, Number of mentions: 3
# Area: account, Number of mentions: 9
# Area: milan, Number of mentions: 5
# Area: johannesburg, Number of mentions: 11
# Area: spending, Number of mentions: 9
# Area: helpline, Number of mentions: 5
# Area: operator, Number of mentions: 10
# Area: picked, Number of mentions: 5
# Area: instance, Number of mentions: 1
# Area: moment, Number of mentions: 9
# Area: proceed, Number of mentions: 3
# Area: currently, Number of mentions: 3
# Area: monday, Number of mentions: 5
# Area: daughter, Number of mentions: 7
# Area: march, Number of mentions: 15
# Area: 25, Number of mentions: 13
# Area: victoria, Number of mentions: 1
# Area: canada, Number of mentions: 6
# Area: agent, Number of mentions: 33
# Area: try, Number of mentions: 32
# Area: expedia, Number of mentions: 7
# Area: finding, Number of mentions: 4
# Area: 24, Number of mentions: 28
# Area: numerous, Number of mentions: 10
# Area: 9, Number of mentions: 8
# Area: unbelievable, Number of mentions: 5
# Area: best, Number of mentions: 12
# Area: allow, Number of mentions: 15
# Area: routing, Number of mentions: 1
# Area: segment, Number of mentions: 1
# Area: nine, Number of mentions: 3
# Area: major, Number of mentions: 5
# Area: school, Number of mentions: 3
# Area: penalty, Number of mentions: 4
# Area: expense, Number of mentions: 20
# Area: staying, Number of mentions: 5
# Area: submitted, Number of mentions: 5
# Area: supporting, Number of mentions: 1
# Area: document, Number of mentions: 15
# Area: reply, Number of mentions: 8
# Area: follow, Number of mentions: 10
# Area: shocking, Number of mentions: 10
# Area: thousand, Number of mentions: 3
# Area: decade, Number of mentions: 4
# Area: patient, Number of mentions: 4
# Area: commented, Number of mentions: 2
# Area: type, Number of mentions: 11
# Area: forum, Number of mentions: 1
# Area: think, Number of mentions: 10
# Area: public, Number of mentions: 3
# Area: aware, Number of mentions: 7
# Area: extremely, Number of mentions: 23
# Area: 9th, Number of mentions: 5
# Area: peak, Number of mentions: 3
# Area: holiday, Number of mentions: 27
# Area: period, Number of mentions: 4
# Area: management, Number of mentions: 10
# Area: standing, Number of mentions: 13
# Area: provide, Number of mentions: 26
# Area: 4/4, Number of mentions: 1
# ...
# Area: comprehension, Number of mentions: 1
# Area: invest, Number of mentions: 1
# Area: palma, Number of mentions: 1
# Area: presumably, Number of mentions: 3
# Area: recur, Number of mentions: 1
# Area: preferably, Number of mentions: 1
# Area: fatuously, Number of mentions: 1
# Area: interview, Number of mentions: 1
# Area: guiding, Number of mentions: 1
# Area: eco-friendly, Number of mentions: 1
# Area: consisted, Number of mentions: 1
# Area: shortbread, Number of mentions: 1
# Area: biscuit, Number of mentions: 1
# Area: firmly, Number of mentions: 1
# Area: bucket, Number of mentions: 1
# Area: beaten, Number of mentions: 1
# Area: faro, Number of mentions: 2
# Area: enjoy, Number of mentions: 2
# Area: rely, Number of mentions: 1
# Area: chilled, Number of mentions: 1
# Area: kuwait, Number of mentions: 2
# Area: lasted, Number of mentions: 2
# Area: 3am, Number of mentions: 1
# Area: grab, Number of mentions: 1
# Area: apartment, Number of mentions: 1
# Area: 777-300er, Number of mentions: 1
# Area: negatively, Number of mentions: 1
# Area: television, Number of mentions: 1
# Area: abundant, Number of mentions: 1
# Area: delicious, Number of mentions: 1
# Area: asks, Number of mentions: 2
# Area: toba, Number of mentions: 1
# Area: shrug, Number of mentions: 1
# Area: advertising, Number of mentions: 1
# Area: admits, Number of mentions: 1
# Area: advises, Number of mentions: 1
# Area: accepts, Number of mentions: 1
# Area: chatting, Number of mentions: 2
# Area: shout, Number of mentions: 1
# Area: perform, Number of mentions: 1
# Area: preparing, Number of mentions: 1
# Area: offensive, Number of mentions: 1
# Area: shocker, Number of mentions: 1
# Area: 747-400., Number of mentions: 2
# Area: collapsing, Number of mentions: 1
# Area: dozen, Number of mentions: 1
# Area: north, Number of mentions: 1
# Area: furthest, Number of mentions: 1
# Area: rugby, Number of mentions: 1
# Area: scrum, Number of mentions: 1
# Area: existence, Number of mentions: 1
# Area: toothpaste, Number of mentions: 1
# Area: toothbrush, Number of mentions: 1
# Area: invitation, Number of mentions: 1
# Area: awake, Number of mentions: 1
# Area: lisbon, Number of mentions: 1
# Area: cod, Number of mentions: 1
# Area: apologising, Number of mentions: 1
# Area: marseille, Number of mentions: 2
# Area: refunding, Number of mentions: 1
# Area: 28, Number of mentions: 1
# Area: towel, Number of mentions: 1
# Area: jacket, Number of mentions: 1
# Area: backpack, Number of mentions: 1
# Area: x2.5, Number of mentions: 1
# Area: 8.50pm, Number of mentions: 1
# Area: ❎, Number of mentions: 1
# Area: olbia, Number of mentions: 1
# Area: sardinia, Number of mentions: 3
# Area: penned, Number of mentions: 1
# Area: heat, Number of mentions: 2
# Area: overwhelmed, Number of mentions: 1
# Area: hydration, Number of mentions: 1
# Area: stage, Number of mentions: 1
# Area: perplexed, Number of mentions: 1
# Area: catching, Number of mentions: 2
# Area: worried, Number of mentions: 1
# Area: energy, Number of mentions: 1
# Area: repaired, Number of mentions: 1
# Area: 42, Number of mentions: 1
# Area: opportunity, Number of mentions: 2
# Area: fortunately, Number of mentions: 1
# Area: dirham, Number of mentions: 1
# Area: £3,8, Number of mentions: 1
# Area: seoul, Number of mentions: 1
# Area: long-hauls, Number of mentions: 1
# Area: simy, Number of mentions: 1
# Area: croweed, Number of mentions: 1
# Area: malfunction, Number of mentions: 2
# Area: unfolded, Number of mentions: 1
# Area: lay, Number of mentions: 1
# Area: 23.4kg, Number of mentions: 1
# Area: 23kg, Number of mentions: 1
# Area: repackage, Number of mentions: 1
# Area: b747, Number of mentions: 1
# Area: 20.gbp, Number of mentions: 1
# Area: exemplifies, Number of mentions: 1
# Area: nashville, Number of mentions: 3
# Area: trans-atlantic, Number of mentions: 1
# Area: ostensibly, Number of mentions: 1
# Area: ying-yang, Number of mentions: 1
# Area: seek, Number of mentions: 1
# Area: generated, Number of mentions: 1
# Area: haggle, Number of mentions: 1
# Area: woeful, Number of mentions: 2
# Area: witness, Number of mentions: 1
# Area: newcastle, Number of mentions: 1
# Area: proportion, Number of mentions: 1
# Area: adjacent, Number of mentions: 5
# Area: deigned, Number of mentions: 1
# Area: eternity, Number of mentions: 1
# Area: slower, Number of mentions: 1
# Area: jet2, Number of mentions: 1
# Area: counted, Number of mentions: 1
# Area: wording, Number of mentions: 1
# Area: cap, Number of mentions: 1
# Area: boyfriend, Number of mentions: 1
# Area: glitch, Number of mentions: 1
# Area: 275, Number of mentions: 1
# Area: 550, Number of mentions: 1
# Area: 1hr, Number of mentions: 1
# Area: slimy, Number of mentions: 1
# Area: smear, Number of mentions: 1
# Area: disclosed, Number of mentions: 1
# Area: irritating, Number of mentions: 1
# Area: sofia, Number of mentions: 3
# Area: re-enter, Number of mentions: 2
# Area: contradicted, Number of mentions: 1
# Area: derisory, Number of mentions: 1
# Area: correctly, Number of mentions: 1
# Area: occasionally, Number of mentions: 1
# Area: maximum, Number of mentions: 1
# Area: handset, Number of mentions: 1
# Area: auckland, Number of mentions: 1
# Area: lemon, Number of mentions: 1
# Area: forgot, Number of mentions: 1
# Area: helpdesk, Number of mentions: 1
# Area: nicely, Number of mentions: 1
# Area: airines, Number of mentions: 1
# Area: 39, Number of mentions: 1
# Area: tenerife, Number of mentions: 1
# Area: madness, Number of mentions: 1
# Area: self, Number of mentions: 1
# Area: destruct, Number of mentions: 1
# Area: shame.have, Number of mentions: 1
# Area: shanghai, Number of mentions: 1
# Area: crumb, Number of mentions: 1
# Area: jal, Number of mentions: 1
# Area: bedding, Number of mentions: 1
# Area: reunited, Number of mentions: 1
# Area: celebrate, Number of mentions: 1
# Area: 60th, Number of mentions: 2
# Area: birthday, Number of mentions: 2
# Area: anniversary, Number of mentions: 1
# Area: heartbreaking, Number of mentions: 1
# Area: 8am, Number of mentions: 1
# Area: 1pm, Number of mentions: 1
# Area: 2:30, Number of mentions: 2
# Area: houston, Number of mentions: 1
# Area: safely, Number of mentions: 1
# Area: buzzed, Number of mentions: 1
# Area: fetched, Number of mentions: 1
# Area: scrabbled, Number of mentions: 1
# Area: cane, Number of mentions: 1
# Area: thai, Number of mentions: 2
# Area: eva, Number of mentions: 1
# Area: surname, Number of mentions: 1
# Area: makeup, Number of mentions: 1
# Area: sponge, Number of mentions: 1
# Area: film/tv, Number of mentions: 1
# Area: congealed, Number of mentions: 1
# Area: dessert, Number of mentions: 1
# Area: expects, Number of mentions: 1
# Area: eu, Number of mentions: 1
# Area: argued, Number of mentions: 1
# Area: sickness, Number of mentions: 2
# Area: extraordinary, Number of mentions: 2
# Area: comparable, Number of mentions: 1
# Area: court, Number of mentions: 1
# Area: precedence, Number of mentions: 1
# Area: contingency, Number of mentions: 1
# Area: strategy, Number of mentions: 1
# Area: talked, Number of mentions: 1
# Area: investing, Number of mentions: 1
# Area: iag, Number of mentions: 2
# Area: integrate, Number of mentions: 1
# Area: reflected, Number of mentions: 1
# Area: rated, Number of mentions: 2
# Area: 747., Number of mentions: 1
# Area: video, Number of mentions: 2
# Area: ande, Number of mentions: 1
# Area: 1.5h, Number of mentions: 1
# Area: charm, Number of mentions: 1
# Area: cafeteria, Number of mentions: 1
# Area: orderly, Number of mentions: 1
# Area: organized, Number of mentions: 1
# Area: 788, Number of mentions: 1
# Area: experieinced, Number of mentions: 1
# Area: compete, Number of mentions: 1
# Area: insulted, Number of mentions: 1
# Area: barebones, Number of mentions: 1
# Area: angled, Number of mentions: 1
# Area: private, Number of mentions: 1
# Area: stretched, Number of mentions: 1
# Area: stowed, Number of mentions: 1
# Area: press, Number of mentions: 1
# Area: indifferent, Number of mentions: 2
# Area: unresponsive, Number of mentions: 1
# Area: nuisance, Number of mentions: 1
# Area: tourist, Number of mentions: 1
# Area: prioritize, Number of mentions: 1
# Area: hour-departure, Number of mentions: 1
# Area: 7.15, Number of mentions: 1
# Area: nearer, Number of mentions: 1
# Area: long-so, Number of mentions: 1
# Area: combination, Number of mentions: 1
# Area: eur, Number of mentions: 1
# Area: travlled, Number of mentions: 1
# Area: cyprus, Number of mentions: 1
# Area: identified, Number of mentions: 2
# Area: grace, Number of mentions: 1
# Area: crew-particularly, Number of mentions: 1
# Area: manager-who, Number of mentions: 1
# Area: ba289, Number of mentions: 1
# Area: 1835., Number of mentions: 1
# Area: 1940., Number of mentions: 1
# Area: ontario, Number of mentions: 1
# Area: california, Number of mentions: 2
# Area: 2030., Number of mentions: 1
# Area: departs, Number of mentions: 1
# Area: 2037., Number of mentions: 1
# Area: drove, Number of mentions: 1
# Area: £4000, Number of mentions: 1
# Area: cologne, Number of mentions: 1
# Area: suggests, Number of mentions: 1
# Area: caribbean, Number of mentions: 1
# Area: celebration, Number of mentions: 2
# Area: spoil, Number of mentions: 1
# Area: wed, Number of mentions: 1
# Area: overbooking, Number of mentions: 2
# Area: defending, Number of mentions: 1
# Area: fuming, Number of mentions: 1
# Area: exacerbated, Number of mentions: 1
# Area: webiste, Number of mentions: 1
# Area: rare, Number of mentions: 1
# Area: contradicts, Number of mentions: 1
# Area: season, Number of mentions: 1
# Area: higher, Number of mentions: 1
# Area: bidder, Number of mentions: 1
# Area: dramatically, Number of mentions: 1
# Area: preserve, Number of mentions: 1
# Area: gloss, Number of mentions: 1
# Area: accountant, Number of mentions: 1
# Area: win, Number of mentions: 1
# Area: vote, Number of mentions: 1
# Area: £40, Number of mentions: 1
# Area: laugh, Number of mentions: 1
# Area: performance, Number of mentions: 1
# Area: lumbar, Number of mentions: 1
# Area: seatback, Number of mentions: 1
# Area: claustrophobic, Number of mentions: 1
# Area: bottled, Number of mentions: 1
# Area: convenience, Number of mentions: 1
# Area: bos, Number of mentions: 2
# Area: edi, Number of mentions: 1
# Area: snippy, Number of mentions: 1
# Area: £56, Number of mentions: 1
# Area: bassinet, Number of mentions: 2
# Area: differed, Number of mentions: 1
# Area: condescending, Number of mentions: 1
# Area: blank, Number of mentions: 1
# Area: continuing, Number of mentions: 2
# Area: noted, Number of mentions: 1
# Area: minor, Number of mentions: 1
# Area: airworthiness, Number of mentions: 1
# Area: licensed, Number of mentions: 1
# Area: thanked, Number of mentions: 1
# Area: famed, Number of mentions: 1
# Area: 52, Number of mentions: 1
# Area: 8st, Number of mentions: 1
# Area: fashioned, Number of mentions: 1
# Area: streamed, Number of mentions: 1
# Area: loop, Number of mentions: 1
# Area: mad, Number of mentions: 1
# Area: insist, Number of mentions: 1
# Area: deplorable, Number of mentions: 1
# Area: staring, Number of mentions: 1
# Area: maneuver, Number of mentions: 1
# Area: transition, Number of mentions: 1
# Area: chest, Number of mentions: 1
# Area: circa, Number of mentions: 1
# Area: b747-400s, Number of mentions: 1
# Area: perpetuate, Number of mentions: 1
# Area: ying/yang, Number of mentions: 1
# Area: ~no, Number of mentions: 1
# Area: feat, Number of mentions: 1
# Area: dumped, Number of mentions: 1
# Area: uneaten, Number of mentions: 1
# Area: ohare, Number of mentions: 1
# Area: wilted, Number of mentions: 1
# Area: insufficient, Number of mentions: 2
# Area: modern, Number of mentions: 1
# Area: elegant, Number of mentions: 1
# Area: demonstrate, Number of mentions: 1
# Area: sophistication, Number of mentions: 1
# Area: dining, Number of mentions: 1
# Area: chain, Number of mentions: 1
# Area: rebooted, Number of mentions: 1
# Area: extraordinarily, Number of mentions: 1
# Area: concorde, Number of mentions: 1
# Area: refurbishment, Number of mentions: 1
# Area: bright, Number of mentions: 1
# Area: blanked, Number of mentions: 1
# Area: leathery, Number of mentions: 1
# Area: tissue, Number of mentions: 1
# Area: newer, Number of mentions: 1
# Area: 19.25, Number of mentions: 1
# Area: duly, Number of mentions: 1
# Area: achieved, Number of mentions: 1
# Area: negligent, Number of mentions: 1
# Area: barrage, Number of mentions: 1
# Area: tampa, Number of mentions: 1
# Area: fuss, Number of mentions: 2
# Area: abroad, Number of mentions: 2
# Area: shovel, Number of mentions: 1
# Area: black, Number of mentions: 1
# Area: hole, Number of mentions: 1
# Area: ba-228, Number of mentions: 1
# Area: reclining, Number of mentions: 1
# Area: loose, Number of mentions: 1
# Area: plug, Number of mentions: 1
# Area: conditioning, Number of mentions: 1
# Area: consistency, Number of mentions: 1
# Area: alternating, Number of mentions: 1
# Area: lit, Number of mentions: 1
# Area: abrupt, Number of mentions: 1
# Area: co-ordination, Number of mentions: 1
# Area: distributing, Number of mentions: 1
# Area: thrown, Number of mentions: 1
# Area: nervous, Number of mentions: 1
# Area: greeting, Number of mentions: 1
# Area: re-assure, Number of mentions: 1
# Area: qatar, Number of mentions: 1
# Area: etihad, Number of mentions: 1
# Area: splendid, Number of mentions: 1
# Area: classic, Number of mentions: 1
# Area: love, Number of mentions: 1
# Area: 2+, Number of mentions: 1
# Area: reduce, Number of mentions: 1
# Area: strong, Number of mentions: 1
# Area: wind, Number of mentions: 2
# Area: schiphol, Number of mentions: 1
# Area: 45-60, Number of mentions: 1
# Area: relaxed, Number of mentions: 1
# Area: warned, Number of mentions: 1
# Area: 2,5, Number of mentions: 1
# Area: overseas, Number of mentions: 1
# Area: unboarded, Number of mentions: 1
# Area: reclaiming, Number of mentions: 1
# Area: piladelphia, Number of mentions: 1
# Area: philadelphia, Number of mentions: 2
# Area: ecenomy, Number of mentions: 1
# Area: kindly, Number of mentions: 1
# Area: 2:45h, Number of mentions: 1
# Area: £5, Number of mentions: 1
# Area: chill, Number of mentions: 1
# Area: 40mins, Number of mentions: 1
# Area: 20mins, Number of mentions: 1
# Area: rushing, Number of mentions: 1
# Area: nap, Number of mentions: 1
# Area: buying, Number of mentions: 1
# Area: 350, Number of mentions: 1
# Area: cellophane, Number of mentions: 1
# Area: ate, Number of mentions: 1
# Area: unbooked, Number of mentions: 1
# Area: leaning, Number of mentions: 1
# Area: uncomfortably, Number of mentions: 1
# Area: stifling, Number of mentions: 1
# Area: hurried, Number of mentions: 1
# Area: malfunctioning, Number of mentions: 1
# Area: screw, Number of mentions: 1
# Area: driver, Number of mentions: 1
# Area: rage, Number of mentions: 1
# Area: sky, Number of mentions: 1
# Area: boac, Number of mentions: 3
# Area: humanly, Number of mentions: 1
# Area: 813, Number of mentions: 1
# Area: r/t, Number of mentions: 1
# Area: lax-buh, Number of mentions: 1
# Area: assign, Number of mentions: 2
# Area: baffling, Number of mentions: 1
# Area: oppressive, Number of mentions: 1
# Area: owed, Number of mentions: 1
# Area: £25, Number of mentions: 1
# Area: b/c, Number of mentions: 1
# Area: inop, Number of mentions: 1
# Area: twelve-hour, Number of mentions: 1
# Area: cushion, Number of mentions: 1
# Area: plumpest, Number of mentions: 1
# Area: 15., Number of mentions: 1
# Area: normal-sized, Number of mentions: 1
# Area: agonising, Number of mentions: 1
# Area: rack, Number of mentions: 2
# Area: mustve, Number of mentions: 1
# Area: patronising, Number of mentions: 1
# Area: fold, Number of mentions: 1
# Area: footstool, Number of mentions: 1
# Area: hunt, Number of mentions: 1
# Area: slow-to-react, Number of mentions: 1
# Area: validated, Number of mentions: 1
# Area: blr, Number of mentions: 1
# Area: decor, Number of mentions: 1
# Area: trim, Number of mentions: 1
# Area: rattling, Number of mentions: 1
# Area: latch, Number of mentions: 1
# Area: locking, Number of mentions: 1
# Area: vod, Number of mentions: 3
# Area: folding, Number of mentions: 1
# Area: gridlines, Number of mentions: 1
# Area: resisted, Number of mentions: 1
# Area: reset, Number of mentions: 1
# Area: await, Number of mentions: 1
# Area: outcome, Number of mentions: 1
# Area: lavatory, Number of mentions: 1
# Area: taxied, Number of mentions: 1
# Area: accompanied, Number of mentions: 1
# Area: repair, Number of mentions: 1
# Area: damaged/lost, Number of mentions: 1
# Area: replace, Number of mentions: 1
# Area: asap, Number of mentions: 1
# Area: depreciation, Number of mentions: 1
# Area: angst, Number of mentions: 1
